# %% [markdown]
# <a href="https://colab.research.google.com/github/scaairesearch/da_cv_fer/blob/main/da_cv_fer_sfew_expw_v12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Cloning repository
# Importing files regarding dataset, model, mains and utils

# %%
# !git clone https://github.com/scaairesearch/da_cv_fer
import os
os.getcwd()
os.chdir('da_cv_fer')
# Out:
# Cloning into 'da_cv_fer'...
# remote: Enumerating objects: 233, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 233 (delta 9), reused 0 (delta 0), pack-reused 209
# Receiving objects: 100% (233/233), 10.75 MiB | 14.82 MiB/s, done.
# Resolving deltas: 100% (123/123), done.

# %% [markdown]
# Installing dependencies

# %%
# !pip install -q -r requirements.txt # -q is for quiet install
# for some reason the below does not get installed with requirements
# !pip install -q opendatasets
# !pip install -q facenet_pytorch
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.7/133.7 kB 2.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 45.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 9.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.0/143.0 kB 18.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 23.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 kB 18.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.7/301.7 kB 29.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 64.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 58.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 90.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.7/225.7 kB 25.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.4/173.4 kB 21.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.3/45.3 kB 6.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 105.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.5/61.5 kB 9.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.3/313.3 kB 38.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.2/154.2 kB 21.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 807.0/807.0 kB 62.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 83.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.1/133.1 kB 19.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.0/104.0 kB 14.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 81.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 83.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 86.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 80.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.2/62.2 MB 10.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 99.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 65.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 385.2/385.2 kB 27.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.6/283.6 kB 22.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 502.5/502.5 kB 11.4 MB/s eta 0:00:00
# ERROR: Could not find a version that satisfies the requirement pywin32==306 (from versions: none)
# ERROR: No matching distribution found for pywin32==306

# %% [markdown]
# ## Libraries and Initializations

# %%
# Installs from files
from da_cv_fer.data_config import DataConfig
from da_cv_fer.ds_sfew import DatasetSFEW
from da_cv_fer.ds_sfew_crop import DatasetSFEWCROP
from da_cv_fer.ds_expw_crop import EXPWCROP
from da_cv_fer.ds_expw import EXPW
from da_cv_fer.utils import *
from da_cv_fer.model_DANN import DANN
from da_cv_fer.run_config import RunConfig
from da_cv_fer.train import *
import os
import zipfile

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau

from tqdm import tqdm # for beautiful model training updates

import matplotlib.pyplot as plt # for plots

import time
from pathlib import Path

from copy import deepcopy
import numpy as np

# %% [markdown]
# ### Initializing configs

# %%
#initializing dataconfig, it tells us about dataset configuration and directory structure
dataconfig = DataConfig()

# %% [markdown]
# ## SFEW Dataset
#
# Creating dataloader objects.
#
# It copies files from a google drive, unzips it and sets that for use
#
# details: da_cv_fer.ds_sfew.DatasetSFEW

# %%
# Mounting Google drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# sfew = DatasetSFEW()
sfew = DatasetSFEWCROP()
sfew_train_loader, sfew_val_loader = sfew.get_dataloader()
print(f' length of SFEW dataset : {len(sfew_train_loader.dataset)}')
# Out:
#  self.BASE_PATH -dataset,
#  self.EXTRACT_DIR-dataset/sfew,
#  self.ZIP_FILE_PATH - dataset/SFEW_2.zip
# Directory dataset/sfew created successfully.
# No files (including zip file) found in dataset/sfew.Copying file
# Starting File copying from /content/gdrive/MyDrive/CV_FER/dataset/SFEW_2.zip to dataset/sfew
# File copied successfully from /content/gdrive/MyDrive/CV_FER/dataset/SFEW_2.zip to dataset/sfew
# Initiating extraction of dataset/sfew/SFEW_2.zip to dataset/sfew
# ...completed for dataset/sfew/SFEW_2.zip
# dataset/sfew/Train Happy.zip Happy
# ...completed for dataset/sfew/Train/Happy.zip
# dataset/sfew/Train Sad.zip Sad
# ...completed for dataset/sfew/Train/Sad.zip
# dataset/sfew/Train Fear.zip Fear
# ...completed for dataset/sfew/Train/Fear.zip
# dataset/sfew/Train Surprise.zip Surprise
# ...completed for dataset/sfew/Train/Surprise.zip
# dataset/sfew/Train Neutral.zip Neutral
# ...completed for dataset/sfew/Train/Neutral.zip
# dataset/sfew/Train Disgust.zip Disgust
# ...completed for dataset/sfew/Train/Disgust.zip
# dataset/sfew/Train Angry.zip Angry
# ...completed for dataset/sfew/Train/Angry.zip
# dataset/sfew/Val Happy.zip Happy
# ...completed for dataset/sfew/Val/Happy.zip
# dataset/sfew/Val Sad.zip Sad
# ...completed for dataset/sfew/Val/Sad.zip
# dataset/sfew/Val Fear.zip Fear
# ...completed for dataset/sfew/Val/Fear.zip
# dataset/sfew/Val Surprise.zip Surprise
# ...completed for dataset/sfew/Val/Surprise.zip
# dataset/sfew/Val Neutral.zip Neutral
# ...completed for dataset/sfew/Val/Neutral.zip
# dataset/sfew/Val Disgust.zip Disgust
# ...completed for dataset/sfew/Val/Disgust.zip
# dataset/sfew/Val Angry.zip Angry
# ...completed for dataset/sfew/Val/Angry.zip
# Directory created: dataset/sfew/Train_Crop
# Directory created: dataset/sfew/Val_Crop
# 172 cropped images created in Sad
# 66 cropped images created in Disgust
# 178 cropped images created in Angry
# 198 cropped images created in Happy
# 150 cropped images created in Neutral
# 96 cropped images created in Surprise
# 98 cropped images created in Fear
# 73 cropped images created in Sad
# 23 cropped images created in Disgust
# 77 cropped images created in Angry
# 73 cropped images created in Happy
# 86 cropped images created in Neutral
# 57 cropped images created in Surprise
# 47 cropped images created in Fear
# ----------mean_ds = [0.2197, 0.1858, 0.1569], std_dev_ds = [0.181, 0.1635, 0.1511]----------
#  length of SFEW dataset : 913
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %%
show_batch(sfew_train_loader,sfew.labels,4)

# %%
show_batch(sfew_train_loader,sfew.labels,4, normalized = False)

# %% [markdown]
# ## EXPW Dataset
# Creating dataset and dataloader objects.
# Split into train and val.
#
# `details: da_cv_fer.ds_expw.EXPW`
# <br>
# Please be patient, it takes around 3 minutes to download data set

# %%
# expw_obj = EXPW()
expw_obj = EXPWCROP()

expw_train_ds, expw_val_ds = expw_obj.get_dataset()
expw_train_loader, expw_val_loader = expw_obj.get_dataloader()
print(f' length of EXPW dataset : {len(expw_train_loader.dataset)} , {len(expw_train_ds)}')
# Out:
# desitination file path = dataset/expwds/expwds.zip
# in EXPW()...
# Directory dataset/expwds created successfully.
# Downloading expwds.zip to dataset/expwds
# 100%|██████████| 7.68G/7.68G [06:24<00:00, 21.4MB/s]
# File downloaded successfully from https://www.kaggle.com/datasets/mohammedaaltaha/expwds to dataset/expwds/expwds.zip
# Unzipped Files already exist in dataset/expwds, not extracted
# Directory created: dataset/expwds/cropped
# **** dataset/expwds/cropped is empty***
#
#  WARNING: It may take a long  time to crop the images, please be patient
#
# 633 cropped images created in cropped
#  length of EXPW dataset : 646 , 646
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %%
show_batch(expw_train_loader,expw_train_ds.labels,3)

# %%
show_batch(expw_train_loader,expw_train_ds.labels,3, normalized = False)

# %% [markdown]
# ## Creating Dataloaders for source and target

# %%
sfew_loader = {'name': 'sfew',
               'train':sfew_train_loader,
               'val':sfew_val_loader
               }
data_loader = {'source' : sfew_loader}
source_name = data_loader['source']['name']

# %%
sfew_loader = {'name': 'sfew',
               'train':sfew_train_loader,
               'val':sfew_val_loader
               }

expw_loader = {'name': 'expw',
               'train':expw_train_loader,
               'val':expw_val_loader
               }

data_loader = {'source' : sfew_loader,
               'target' : expw_loader}

source_name = data_loader['source']['name']
target_name = data_loader['target']['name']

# %% [markdown]
# ## Initializing Model
# details are present in `model_DANN`

# %%
model = DANN(num_classes=7,backbone='resnet18', dropout=0.1)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 114MB/s]
# feature extractor backbone created using resnet18 model

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
print(device)
model = model.to(device)
# Out:
# cuda

# %% [markdown]
# Running model for single run. checking output shapes

# %%
for usage, dict_data_loader in data_loader.items(): ## {'source' : sfew_loader,'target' : expw_loader}
    print('-'*80)
    print(usage)
    for k, v in dict_data_loader.items(): # {'name': 'sfew','train':sfew_train_loader,'val':sfew_val_loader}
      if k == 'name':
        print (f'--------{k} of dataset : {v}--------')
      else:
        print (f'   --------type : {k}--------')
        batch = next(iter(v)) # it may be possible that some datasets have more than 2 outputs, so this strategy is safe
        images, labels = batch[0].to(device), batch[1].to(device)
        print( "Input:\n","Input Image: ",images.shape, ", labels: ",labels.shape)

        x_labels, x_domains, x_features = model(images) # forward pass
        print("Output:\n", "labels: ", x_labels.shape, ", domains: ",x_domains.shape, ", features: ", x_features.shape)
# Out:
# --------------------------------------------------------------------------------
# source
# --------name of dataset : sfew--------
#    --------type : train--------
# Input:
#  Input Image:  torch.Size([16, 3, 224, 224]) , labels:  torch.Size([16, 7])
# Output:
#  labels:  torch.Size([16, 7]) , domains:  torch.Size([16, 2]) , features:  torch.Size([16, 1000])
#    --------type : val--------
# Input:
#  Input Image:  torch.Size([16, 3, 224, 224]) , labels:  torch.Size([16, 7])
# Output:
#  labels:  torch.Size([16, 7]) , domains:  torch.Size([16, 2]) , features:  torch.Size([16, 1000])
# --------------------------------------------------------------------------------
# target
# --------name of dataset : expw--------
#    --------type : train--------
# Input:
#  Input Image:  torch.Size([16, 3, 224, 224]) , labels:  torch.Size([16, 7])
# Output:
#  labels:  torch.Size([16, 7]) , domains:  torch.Size([16, 2]) , features:  torch.Size([16, 1000])
#    --------type : val--------
# Input:
#  Input Image:  torch.Size([16, 3, 224, 224]) , labels:  torch.Size([16, 7])
# Output:
#  labels:  torch.Size([16, 7]) , domains:  torch.Size([16, 2]) , features:  torch.Size([16, 1000])

# %%
# #@title Weight Initialization

# # initializating weights using xavier normal
# def weights_init(m):
#     if isinstance(m, nn.Conv2d):
#       nn.init.xavier_normal_(m.weight)
#     elif isinstance(m, nn.Linear):
#       nn.init.xavier_normal_(m.weight)
#       nn.init.zeros_(m.bias)

# # initializating weights using xavier normal
# def weights_init(m):
#     if isinstance(m, nn.Conv2d):
#       # nn.init.xavier_normal_(m.weight)
#       pass # not initialising Conv layers as they are pretrained
#     elif isinstance(m, nn.Linear):
#       nn.init.xavier_normal_(m.weight) # Linear layers are added on
#       nn.init.zeros_(m.bias)

# %% [markdown]
# ## Non DANN: Training, Validating, Saving

# %% [markdown]
# ### Early Stopping Scheduler - ReduceLRonPlateau

# %%
# def early_stopping_difference(list_loss: list, patience = 5, difference = 0.0003):
#   if len(list_loss) > patience:
#     reverse_list_loss = list_loss[::-1]
#     reverse_list_loss = reverse_list_loss[0:patience+1]
#     for index in range(0,len(reverse_list_loss)-1):
#       if abs(reverse_list_loss[index] - reverse_list_loss[index+1]) > difference:
#         return False
#     return True
#   else:
#     return False

# %% [markdown]
# Configuration towards execution

# %%
runconfig = RunConfig()
device = runconfig.device

non_dann_model = DANN(num_classes=7, backbone = 'resnet18')
non_dann_model = non_dann_model.to(device)
best_non_dann_model = DANN(num_classes=7, backbone = 'resnet18').to(device)
# non_dann_model.apply(weights_init) # initializing model, only linear layers

#learning rate
lr = float(runconfig.inital_lr)

# Epochs
EPOCHS = runconfig.NUM_EPOCHS
# EPOCHS = 5 #override
print("EPOCHS", EPOCHS)

# ReduceLRonPlateau Scheduler Params
scheduler_patience = runconfig.scheduler_patience
scheduler_factor = runconfig.scheduler_factor
scheduler_threshold = runconfig.scheduler_threshold

# Early stopping params
early_stop_patience = runconfig.early_stop_patience
early_stop_difference = runconfig.early_stop_difference

# optimizer
optimizer = optim.SGD(non_dann_model.parameters(), lr = lr, momentum = 0.9)

# Set up the ReduceLROnPlateau scheduler
scheduler = ReduceLROnPlateau(optimizer, mode='min',
                              factor=scheduler_factor,
                              patience=scheduler_patience,
                              threshold = scheduler_threshold,
                              min_lr=1e-6,
                              verbose= True)

# Initialize variables to track the best validation loss and the best model state
best_val_loss = float('inf')
best_val_acc = 0
best_model_state = None

# loss functions
criterion_class = (runconfig.criterion_class).to(device=device)
criterion_domain = (runconfig.criterion_domain).to(device=device)

# loss accumulation
train_losses = [] # to capture train losses over training epochs
val_losses = [] # to capture validation loss over epochs
lr_schedule = [] # to capture learning rate over epochs
epoch_converge = 0 #TODO: run config based
# Out:
# feature extractor backbone created using resnet18 model
# feature extractor backbone created using resnet18 model
# EPOCHS 50

# %%
# Training block
print('------ Training started for Non DANN Model ---- ')
print(f'starting LR : {lr}')
for epoch in range(EPOCHS):
    print("EPOCH:", epoch+1, " of ", EPOCHS)

    #Train Model
    avg_epoch_loss, curr_lr = train_model(model = non_dann_model,
                                          device = device,
                                          data_loader = data_loader['source']['train'],
                                          optimizer = optimizer,
                                          epoch = epoch,
                                          class_loss_function = criterion_class)
    train_losses.append(avg_epoch_loss)
    lr_schedule.append(curr_lr)

    #Adding Scheduler #TODO: ADD SCHEDULER
    scheduler.step(avg_epoch_loss) #applying scheduler on training loss

    #Validate Model
    correct, avg_epoch_val_loss = test_model(model= non_dann_model,
                                    device= device,
                                    data_loader = data_loader['source']['val'],
                                    class_loss_function = criterion_class
                                    )

    val_losses.append(avg_epoch_val_loss)
    # # Check if the current model has the best validation loss
    # print(f'Last Epoch Val Loss = {avg_epoch_val_loss} | Best Val Loss = {best_val_loss}' )
    # if avg_epoch_val_loss < best_val_loss:
    #   best_val_loss = avg_epoch_val_loss
    #   # save the current model state as the best model state
    #   best_model_state = deepcopy(non_dann_model.state_dict())
    #   print(f'Updated the best model with validation loss: {best_val_loss}\n')

    # check if the current model has the best accuracy
    print (f'last correct ={correct} | best correct = {best_val_acc}')
    if correct > best_val_acc:
      best_val_acc = correct
      # save the current model state as the best model state
      best_model_state = deepcopy(non_dann_model.state_dict())
      print(f'Updated the best model with correct: {correct}\n')


    if early_stopping_difference(val_losses,
                                 patience = early_stop_patience,
                                 difference= early_stop_difference):
      print (f'-------Early Stopping at epoch {epoch+1}---')
      epoch_converge = epoch+1
      break

## using params of best model to update model
if best_model_state: # only update if best model has been saved, else the last one would be picked up
  # best_non_dann_model.load_state_dict(best_model_state)
  non_dann_model.load_state_dict(best_model_state)
  print('Best model loaded')


print(f'Validation results with {source_name}')

correct, test_loss_source = test_model(model= non_dann_model, #best_non_dann_model, #non_dann_model,
                                    device= device,
                                    data_loader = data_loader['source']['val'], # source val loader
                                    class_loss_function = criterion_class)

print(f'Test results with {target_name}')
correct, test_loss_target = test_model(model= non_dann_model, #best_non_dann_model, #non_dann_model,
                                    device= device,
                                    data_loader = data_loader['target']['val'], # target val loader
                                    class_loss_function = criterion_class)

dict_non_dann_losses = {'train_losses' : train_losses,
                                       'val_losses': val_losses,
                                       'test_loss_source' : test_loss_source,
                                       'test_loss_target' : test_loss_target,
                                       'epoch_convergence' : epoch_converge,
                                       'lr': lr_schedule}
# Out:
# ------ Training started for Non DANN Model ----
# starting LR : 0.005
# EPOCH: 1  of  50
# epoch = 1...in training function
# Loss=1.9607430696487427 Accuracy=228/913(24.97%) Epoch Avg loss=0.12044012 LR=0.005000: 100%|██████████| 58/58 [00:08<00:00,  7.09it/s]
# Test / Val: Average loss: 0.1252, Accuracy: 67/419 (15.99%)
#
# last correct =67 | best correct = 0
# Updated the best model with correct: 67
#
# EPOCH: 2  of  50
# epoch = 2...in training function
# Loss=1.7292392253875732 Accuracy=307/913(33.63%) Epoch Avg loss=0.11029747 LR=0.005000: 100%|██████████| 58/58 [00:08<00:00,  6.90it/s]
# Test / Val: Average loss: 0.1270, Accuracy: 107/419 (25.54%)
#
# last correct =107 | best correct = 67
# Updated the best model with correct: 107
#
# EPOCH: 3  of  50
# epoch = 3...in training function
# Loss=1.7847347259521484 Accuracy=419/913(45.89%) Epoch Avg loss=0.09634574 LR=0.005000: 100%|██████████| 58/58 [00:07<00:00,  8.04it/s]
# Test / Val: Average loss: 0.1266, Accuracy: 106/419 (25.30%)
#
# last correct =106 | best correct = 107
# EPOCH: 4  of  50
# epoch = 4...in training function
# Loss=1.5297144651412964 Accuracy=421/913(46.11%) Epoch Avg loss=0.09206530 LR=0.005000: 100%|██████████| 58/58 [00:06<00:00,  8.77it/s]
# Test / Val: Average loss: 0.1083, Accuracy: 165/419 (39.38%)
#
# last correct =165 | best correct = 107
# Updated the best model with correct: 165
#
# EPOCH: 5  of  50
# epoch = 5...in training function
# Loss=2.3269147872924805 Accuracy=486/913(53.23%) Epoch Avg loss=0.08065749 LR=0.005000: 100%|██████████| 58/58 [00:08<00:00,  6.86it/s]
# Test / Val: Average loss: 0.1190, Accuracy: 134/419 (31.98%)
#
# last correct =134 | best correct = 165
# EPOCH: 6  of  50
# epoch = 6...in training function
# Loss=2.3094639778137207 Accuracy=591/913(64.73%) Epoch Avg loss=0.06983899 LR=0.005000: 100%|██████████| 58/58 [00:08<00:00,  6.87it/s]
# Test / Val: Average loss: 0.1313, Accuracy: 157/419 (37.47%)
#
# last correct =157 | best correct = 165
# EPOCH: 7  of  50
# epoch = 7...in training function
# Loss=1.2461191415786743 Accuracy=597/913(65.39%) Epoch Avg loss=0.06487202 LR=0.005000: 100%|██████████| 58/58 [00:06<00:00,  8.61it/s]
# Test / Val: Average loss: 0.1117, Accuracy: 155/419 (36.99%)
#
# last correct =155 | best correct = 165
# EPOCH: 8  of  50
# epoch = 8...in training function
# Loss=2.219754457473755 Accuracy=598/913(65.50%) Epoch Avg loss=0.06586886 LR=0.005000: 100%|██████████| 58/58 [00:06<00:00,  8.76it/s]
# Test / Val: Average loss: 0.1259, Accuracy: 149/419 (35.56%)
#
# last correct =149 | best correct = 165
# EPOCH: 9  of  50
# epoch = 9...in training function
# Loss=1.4852056503295898 Accuracy=641/913(70.21%) Epoch Avg loss=0.05755200 LR=0.005000: 100%|██████████| 58/58 [00:08<00:00,  6.81it/s]
# Test / Val: Average loss: 0.1419, Accuracy: 169/419 (40.33%)
#
# last correct =169 | best correct = 165
# Updated the best model with correct: 169
#
# EPOCH: 10  of  50
# epoch = 10...in training function
# Loss=2.343980312347412 Accuracy=654/913(71.63%) Epoch Avg loss=0.05547404 LR=0.005000: 100%|██████████| 58/58 [00:07<00:00,  7.35it/s]
# Test / Val: Average loss: 0.1366, Accuracy: 176/419 (42.00%)
#
# last correct =176 | best correct = 169
# Updated the best model with correct: 176
#
# EPOCH: 11  of  50
# epoch = 11...in training function
# Loss=1.8730401992797852 Accuracy=681/913(74.59%) Epoch Avg loss=0.05120866 LR=0.005000: 100%|██████████| 58/58 [00:06<00:00,  8.56it/s]
# Test / Val: Average loss: 0.1223, Accuracy: 176/419 (42.00%)
#
# last correct =176 | best correct = 176
# EPOCH: 12  of  50
# epoch = 12...in training function
# Loss=1.6361184120178223 Accuracy=700/913(76.67%) Epoch Avg loss=0.04591940 LR=0.005000: 100%|██████████| 58/58 [00:07<00:00,  7.58it/s]
# Test / Val: Average loss: 0.1492, Accuracy: 148/419 (35.32%)
#
# last correct =148 | best correct = 176
# EPOCH: 13  of  50
# epoch = 13...in training function
# Loss=2.3803818225860596 Accuracy=727/913(79.63%) Epoch Avg loss=0.04074421 LR=0.005000: 100%|██████████| 58/58 [00:08<00:00,  6.98it/s]
# Test / Val: Average loss: 0.1348, Accuracy: 175/419 (41.77%)
#
# last correct =175 | best correct = 176
# EPOCH: 14  of  50
# epoch = 14...in training function
# Loss=2.3015780448913574 Accuracy=735/913(80.50%) Epoch Avg loss=0.03672716 LR=0.005000: 100%|██████████| 58/58 [00:07<00:00,  8.16it/s]
# Test / Val: Average loss: 0.1359, Accuracy: 182/419 (43.44%)
#
# last correct =182 | best correct = 176
# Updated the best model with correct: 182
#
# EPOCH: 15  of  50
# epoch = 15...in training function
# Loss=1.6614551544189453 Accuracy=731/913(80.07%) Epoch Avg loss=0.03748463 LR=0.005000: 100%|██████████| 58/58 [00:06<00:00,  8.59it/s]
# Test / Val: Average loss: 0.1167, Accuracy: 186/419 (44.39%)
#
# last correct =186 | best correct = 182
# Updated the best model with correct: 186
#
# EPOCH: 16  of  50
# epoch = 16...in training function
# Loss=2.0359933376312256 Accuracy=767/913(84.01%) Epoch Avg loss=0.03220961 LR=0.005000: 100%|██████████| 58/58 [00:08<00:00,  6.79it/s]
# Test / Val: Average loss: 0.1568, Accuracy: 164/419 (39.14%)
#
# last correct =164 | best correct = 186
# EPOCH: 17  of  50
# epoch = 17...in training function
# Loss=2.6044299602508545 Accuracy=781/913(85.54%) Epoch Avg loss=0.03144321 LR=0.005000: 100%|██████████| 58/58 [00:08<00:00,  7.07it/s]
# Test / Val: Average loss: 0.1652, Accuracy: 184/419 (43.91%)
#
# last correct =184 | best correct = 186
# EPOCH: 18  of  50
# epoch = 18...in training function
# Loss=1.7557706832885742 Accuracy=777/913(85.10%) Epoch Avg loss=0.02933700 LR=0.005000: 100%|██████████| 58/58 [00:06<00:00,  8.66it/s]
# Test / Val: Average loss: 0.1494, Accuracy: 164/419 (39.14%)
#
# last correct =164 | best correct = 186
# EPOCH: 19  of  50
# epoch = 19...in training function
# Loss=2.212965488433838 Accuracy=790/913(86.53%) Epoch Avg loss=0.02865474 LR=0.005000: 100%|██████████| 58/58 [00:07<00:00,  7.65it/s]
# Test / Val: Average loss: 0.1645, Accuracy: 176/419 (42.00%)
#
# last correct =176 | best correct = 186
# EPOCH: 20  of  50
# epoch = 20...in training function
# Loss=1.6968276500701904 Accuracy=807/913(88.39%) Epoch Avg loss=0.02666669 LR=0.005000: 100%|██████████| 58/58 [00:08<00:00,  6.85it/s]
# Test / Val: Average loss: 0.1489, Accuracy: 166/419 (39.62%)
#
# last correct =166 | best correct = 186
# EPOCH: 21  of  50
# epoch = 21...in training function
# Loss=1.9977869987487793 Accuracy=796/913(87.19%) Epoch Avg loss=0.02665794 LR=0.005000: 100%|██████████| 58/58 [00:06<00:00,  8.51it/s]
# Test / Val: Average loss: 0.1573, Accuracy: 186/419 (44.39%)
#
# last correct =186 | best correct = 186
# EPOCH: 22  of  50
# epoch = 22...in training function
# Loss=2.0152807235717773 Accuracy=810/913(88.72%) Epoch Avg loss=0.02501471 LR=0.005000: 100%|██████████| 58/58 [00:06<00:00,  8.69it/s]
# Test / Val: Average loss: 0.1784, Accuracy: 147/419 (35.08%)
#
# last correct =147 | best correct = 186
# EPOCH: 23  of  50
# epoch = 23...in training function
# Loss=1.8935701847076416 Accuracy=800/913(87.62%) Epoch Avg loss=0.02456194 LR=0.005000: 100%|██████████| 58/58 [00:08<00:00,  6.92it/s]
# Test / Val: Average loss: 0.1478, Accuracy: 180/419 (42.96%)
#
# last correct =180 | best correct = 186
# EPOCH: 24  of  50
# epoch = 24...in training function
# Loss=2.493497848510742 Accuracy=828/913(90.69%) Epoch Avg loss=0.02158361 LR=0.005000: 100%|██████████| 58/58 [00:07<00:00,  7.38it/s]
# Test / Val: Average loss: 0.1536, Accuracy: 188/419 (44.87%)
#
# last correct =188 | best correct = 186
# Updated the best model with correct: 188
#
# EPOCH: 25  of  50
# epoch = 25...in training function
# Loss=1.8058290481567383 Accuracy=824/913(90.25%) Epoch Avg loss=0.01952840 LR=0.005000: 100%|██████████| 58/58 [00:06<00:00,  8.65it/s]
# Test / Val: Average loss: 0.1969, Accuracy: 137/419 (32.70%)
#
# last correct =137 | best correct = 188
# EPOCH: 26  of  50
# epoch = 26...in training function
# Loss=2.1495885848999023 Accuracy=820/913(89.81%) Epoch Avg loss=0.02220284 LR=0.005000: 100%|██████████| 58/58 [00:07<00:00,  7.39it/s]
# Test / Val: Average loss: 0.1742, Accuracy: 188/419 (44.87%)
#
# last correct =188 | best correct = 188
# EPOCH: 27  of  50
# epoch = 27...in training function
# Loss=1.1420507431030273 Accuracy=825/913(90.36%) Epoch Avg loss=0.01965014 LR=0.005000: 100%|██████████| 58/58 [00:08<00:00,  6.98it/s]
# Test / Val: Average loss: 0.1631, Accuracy: 177/419 (42.24%)
#
# last correct =177 | best correct = 188
# EPOCH: 28  of  50
# epoch = 28...in training function
# Loss=0.8920979499816895 Accuracy=851/913(93.21%) Epoch Avg loss=0.01698086 LR=0.005000: 100%|██████████| 58/58 [00:06<00:00,  8.62it/s]
# Test / Val: Average loss: 0.1760, Accuracy: 185/419 (44.15%)
#
# last correct =185 | best correct = 188
# EPOCH: 29  of  50
# epoch = 29...in training function
# Loss=2.517437696456909 Accuracy=851/913(93.21%) Epoch Avg loss=0.01671500 LR=0.005000: 100%|██████████| 58/58 [00:06<00:00,  8.67it/s]
# Test / Val: Average loss: 0.1521, Accuracy: 181/419 (43.20%)
#
# last correct =181 | best correct = 188
# EPOCH: 30  of  50
# epoch = 30...in training function
# Loss=2.7963147163391113 Accuracy=833/913(91.24%) Epoch Avg loss=0.01985786 LR=0.005000: 100%|██████████| 58/58 [00:08<00:00,  6.90it/s]
# Test / Val: Average loss: 0.1442, Accuracy: 191/419 (45.58%)
#
# last correct =191 | best correct = 188
# Updated the best model with correct: 191
#
# EPOCH: 31  of  50
# epoch = 31...in training function
# Loss=1.9011904001235962 Accuracy=849/913(92.99%) Epoch Avg loss=0.01589672 LR=0.005000: 100%|██████████| 58/58 [00:08<00:00,  7.24it/s]
# Test / Val: Average loss: 0.1534, Accuracy: 170/419 (40.57%)
#
# last correct =170 | best correct = 191
# EPOCH: 32  of  50
# epoch = 32...in training function
# Loss=2.6068782806396484 Accuracy=857/913(93.87%) Epoch Avg loss=0.01461940 LR=0.005000: 100%|██████████| 58/58 [00:06<00:00,  8.71it/s]
# Test / Val: Average loss: 0.1732, Accuracy: 178/419 (42.48%)
#
# last correct =178 | best correct = 191
# EPOCH: 33  of  50
# epoch = 33...in training function
# Loss=2.0817365646362305 Accuracy=848/913(92.88%) Epoch Avg loss=0.01544278 LR=0.005000: 100%|██████████| 58/58 [00:07<00:00,  7.57it/s]
# Test / Val: Average loss: 0.1969, Accuracy: 177/419 (42.24%)
#
# last correct =177 | best correct = 191
# EPOCH: 34  of  50
# epoch = 34...in training function
# Loss=1.922660231590271 Accuracy=860/913(94.19%) Epoch Avg loss=0.01233957 LR=0.005000: 100%|██████████| 58/58 [00:08<00:00,  6.86it/s]
# Test / Val: Average loss: 0.1847, Accuracy: 177/419 (42.24%)
#
# last correct =177 | best correct = 191
# EPOCH: 35  of  50
# epoch = 35...in training function
# Loss=1.855970859527588 Accuracy=840/913(92.00%) Epoch Avg loss=0.01724131 LR=0.005000: 100%|██████████| 58/58 [00:07<00:00,  8.23it/s]
# Test / Val: Average loss: 0.2002, Accuracy: 154/419 (36.75%)
#
# last correct =154 | best correct = 191
# EPOCH: 36  of  50
# epoch = 36...in training function
# Loss=1.9927055835723877 Accuracy=838/913(91.79%) Epoch Avg loss=0.01826341 LR=0.005000: 100%|██████████| 58/58 [00:06<00:00,  8.83it/s]
# Test / Val: Average loss: 0.1736, Accuracy: 165/419 (39.38%)
#
# last correct =165 | best correct = 191
# EPOCH: 37  of  50
# epoch = 37...in training function
# Loss=2.5967931747436523 Accuracy=872/913(95.51%) Epoch Avg loss=0.01244643 LR=0.005000: 100%|██████████| 58/58 [00:08<00:00,  6.81it/s]
# Test / Val: Average loss: 0.1906, Accuracy: 187/419 (44.63%)
#
# last correct =187 | best correct = 191
# EPOCH: 38  of  50
# epoch = 38...in training function
# Loss=1.8804197311401367 Accuracy=863/913(94.52%) Epoch Avg loss=0.01250729 LR=0.005000: 100%|██████████| 58/58 [00:08<00:00,  7.23it/s]
# Epoch 00038: reducing learning rate of group 0 to 1.0000e-03.
# Test / Val: Average loss: 0.1761, Accuracy: 183/419 (43.68%)
#
# last correct =183 | best correct = 191
# EPOCH: 39  of  50
# epoch = 39...in training function
# Loss=1.8764045238494873 Accuracy=876/913(95.95%) Epoch Avg loss=0.00962118 LR=0.001000: 100%|██████████| 58/58 [00:06<00:00,  8.72it/s]
# Test / Val: Average loss: 0.1758, Accuracy: 192/419 (45.82%)
#
# last correct =192 | best correct = 191
# Updated the best model with correct: 192
#
# EPOCH: 40  of  50
# epoch = 40...in training function
# Loss=1.732724666595459 Accuracy=878/913(96.17%) Epoch Avg loss=0.00823367 LR=0.001000: 100%|██████████| 58/58 [00:07<00:00,  7.55it/s]
# Test / Val: Average loss: 0.1589, Accuracy: 196/419 (46.78%)
#
# last correct =196 | best correct = 192
# Updated the best model with correct: 196
#
# EPOCH: 41  of  50
# epoch = 41...in training function
# Loss=1.6515260934829712 Accuracy=891/913(97.59%) Epoch Avg loss=0.00629961 LR=0.001000: 100%|██████████| 58/58 [00:08<00:00,  6.73it/s]
# Test / Val: Average loss: 0.1761, Accuracy: 195/419 (46.54%)
#
# last correct =195 | best correct = 196
# EPOCH: 42  of  50
# epoch = 42...in training function
# Loss=1.524017095565796 Accuracy=900/913(98.58%) Epoch Avg loss=0.00452276 LR=0.001000: 100%|██████████| 58/58 [00:06<00:00,  8.62it/s]
# Test / Val: Average loss: 0.1692, Accuracy: 194/419 (46.30%)
#
# last correct =194 | best correct = 196
# EPOCH: 43  of  50
# epoch = 43...in training function
# Loss=1.7578850984573364 Accuracy=894/913(97.92%) Epoch Avg loss=0.00612962 LR=0.001000: 100%|██████████| 58/58 [00:06<00:00,  8.60it/s]
# Test / Val: Average loss: 0.1745, Accuracy: 187/419 (44.63%)
#
# last correct =187 | best correct = 196
# EPOCH: 44  of  50
# epoch = 44...in training function
# Loss=1.49831223487854 Accuracy=905/913(99.12%) Epoch Avg loss=0.00350850 LR=0.001000: 100%|██████████| 58/58 [00:08<00:00,  6.80it/s]
# Test / Val: Average loss: 0.1757, Accuracy: 188/419 (44.87%)
#
# last correct =188 | best correct = 196
# EPOCH: 45  of  50
# epoch = 45...in training function
# Loss=2.5238351821899414 Accuracy=893/913(97.81%) Epoch Avg loss=0.00625211 LR=0.001000: 100%|██████████| 58/58 [00:08<00:00,  7.02it/s]
# Test / Val: Average loss: 0.1800, Accuracy: 190/419 (45.35%)
#
# last correct =190 | best correct = 196
# EPOCH: 46  of  50
# epoch = 46...in training function
# Loss=2.3463802337646484 Accuracy=892/913(97.70%) Epoch Avg loss=0.00581697 LR=0.001000: 100%|██████████| 58/58 [00:06<00:00,  8.78it/s]
# Test / Val: Average loss: 0.2009, Accuracy: 187/419 (44.63%)
#
# last correct =187 | best correct = 196
# EPOCH: 47  of  50
# epoch = 47...in training function
# Loss=2.0265865325927734 Accuracy=897/913(98.25%) Epoch Avg loss=0.00568028 LR=0.001000: 100%|██████████| 58/58 [00:07<00:00,  7.63it/s]
# Test / Val: Average loss: 0.1915, Accuracy: 186/419 (44.39%)
#
# last correct =186 | best correct = 196
# EPOCH: 48  of  50
# epoch = 48...in training function
# Loss=1.9830715656280518 Accuracy=904/913(99.01%) Epoch Avg loss=0.00448190 LR=0.001000: 100%|██████████| 58/58 [00:08<00:00,  7.02it/s]
# Epoch 00048: reducing learning rate of group 0 to 2.0000e-04.
# Test / Val: Average loss: 0.1849, Accuracy: 185/419 (44.15%)
#
# last correct =185 | best correct = 196
# EPOCH: 49  of  50
# epoch = 49...in training function
# Loss=1.9813379049301147 Accuracy=902/913(98.80%) Epoch Avg loss=0.00412529 LR=0.000200: 100%|██████████| 58/58 [00:07<00:00,  8.18it/s]
# Test / Val: Average loss: 0.1816, Accuracy: 188/419 (44.87%)
#
# last correct =188 | best correct = 196
# EPOCH: 50  of  50
# epoch = 50...in training function
# Loss=1.8494524955749512 Accuracy=898/913(98.36%) Epoch Avg loss=0.00458829 LR=0.000200: 100%|██████████| 58/58 [00:06<00:00,  8.56it/s]
# Test / Val: Average loss: 0.1739, Accuracy: 181/419 (43.20%)
#
# last correct =181 | best correct = 196
# Best model loaded
# Validation results with sfew
# Test / Val: Average loss: 0.1602, Accuracy: 196/419 (46.78%)
#
# Test results with expw
# Test / Val: Average loss: 0.4151, Accuracy: 5/34 (14.71%)

# %%
#checking if the models are same weights, i.e. copy has worked fine
for p1, p2 in zip(non_dann_model.parameters(), best_non_dann_model.parameters()):
    if p1.data.ne(p2.data).sum() > 0:
        print ('False')
        break
print ('True')
# Out:
# False
# True

# %%
print(dict_non_dann_losses)
# Out:
# {'train_losses': [0.12044012, 0.11029747, 0.09634574, 0.0920653, 0.08065749, 0.06983899, 0.06487202, 0.06586886, 0.057552, 0.05547404, 0.05120866, 0.0459194, 0.04074421, 0.03672716, 0.03748463, 0.03220961, 0.03144321, 0.029337, 0.02865474, 0.02666669, 0.02665794, 0.02501471, 0.02456194, 0.02158361, 0.0195284, 0.02220284, 0.01965014, 0.01698086, 0.016715, 0.01985786, 0.01589672, 0.0146194, 0.01544278, 0.01233957, 0.01724131, 0.01826341, 0.01244643, 0.01250729, 0.00962118, 0.00823367, 0.00629961, 0.00452276, 0.00612962, 0.0035085, 0.00625211, 0.00581697, 0.00568028, 0.0044819, 0.00412529, 0.00458829], 'val_losses': [0.12522013745046173, 0.1269543105491875, 0.12656967053834464, 0.1082971608155098, 0.11896142100377413, 0.1313302639276145, 0.11172180670826987, 0.1258853870246177, 0.14187587161052767, 0.13660467865927975, 0.1222998330587419, 0.14916410281151746, 0.1347974516042377, 0.1358980296050734, 0.11670805616993324, 0.15678234942488567, 0.16517548259516604, 0.14940600178975763, 0.16445198295935812, 0.14887311065965164, 0.1573075835630831, 0.17842634111144948, 0.1478343951673667, 0.15362383144283068, 0.1969449224221678, 0.17423813752741119, 0.16308694480427124, 0.176012818028079, 0.15207965647121602, 0.14415921544687277, 0.1533968558174898, 0.17316291838670972, 0.19688174007616066, 0.18471501095482729, 0.2001870207684137, 0.17364414210535745, 0.190584299672475, 0.17614772837600162, 0.1757904020869362, 0.15887845757468502, 0.17612155468196458, 0.169223730881345, 0.17447674416699102, 0.17571630796555404, 0.17998504780926397, 0.20086621669141091, 0.19145159875009396, 0.18488051327998997, 0.18157729812339837, 0.1738734990713989], 'test_loss_source': 0.16018768398175662, 'test_loss_target': 0.4151405565002385, 'epoch_convergence': 0, 'lr': [0.005, 0.005, 0.005, 0.005, 0.005, 0.005, 0.005, 0.005, 0.005, 0.005, 0.005, 0.005, 0.005, 0.005, 0.005, 0.005, 0.005, 0.005, 0.005, 0.005, 0.005, 0.005, 0.005, 0.005, 0.005, 0.005, 0.005, 0.005, 0.005, 0.005, 0.005, 0.005, 0.005, 0.005, 0.005, 0.005, 0.005, 0.005, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.0002, 0.0002]}

# %%
# #@title Plotting Training and Validation Loss Function
# def plot_loss_curves(dict_losses, mode = "train_losses"):
#     fig=plt.figure(figsize=(10,20))
#     fig.add_subplot(5, 1, 2)
#     # for embedding in dict_emb_file.keys():
#     list1_to_plot= dict_losses[mode]
#     plt.plot(range(1,len(list1_to_plot)+1),list1_to_plot, label = 'Non DANN ' + 'SFEW')
#     plt.xlabel('number of epochs', fontsize=10)
#     plt.ylabel(str(mode), fontsize=10)
#     plt.legend(loc = 'upper right')
#     plt.title(" "+mode)
#     plt.show()

# %%
plot_loss_curves(dict_non_dann_losses,mode='train_losses')
plot_loss_curves(dict_non_dann_losses,mode='val_losses')
plot_loss_curves(dict_non_dann_losses,mode='lr')

# %% [markdown]
# ### Saving NON DANN Model

# %%
MODEL_DIR = dataconfig.MODEL_DIR
NON_DANN_SFEW_DIR = dataconfig.NON_DANN_SFEW_DIR
SPECIFIC_MODEL_DIR = Path(os.path.join(MODEL_DIR, f'non_dann_{source_name}_{target_name}'))
print(MODEL_DIR, NON_DANN_SFEW_DIR, SPECIFIC_MODEL_DIR)
# Out:
# /content/gdrive/MyDrive/CV_FER/models /content/gdrive/MyDrive/CV_FER/models/non_dann_sfew /content/gdrive/MyDrive/CV_FER/models/non_dann_sfew_expw

# %%
model_name = f'non_dann_{source_name}_{target_name}_{str(time.strftime("%d_%m"))}.pt' #"non_dann_sfew_" +str(time.strftime("%d_%m"))+ ".pt"
# dataconfig = DataConfig()
# NON_DANN_SFEW_DIR = dataconfig.NON_DANN_SFEW_DIR
if not SPECIFIC_MODEL_DIR.exists():
    # Create the directory
    SPECIFIC_MODEL_DIR.mkdir(parents=True, exist_ok=True)
    print(f'Directory {SPECIFIC_MODEL_DIR} created successfully.')
else:
    print(f'Directory {SPECIFIC_MODEL_DIR} already exists.')

torch.save(non_dann_model.state_dict(), Path(SPECIFIC_MODEL_DIR,model_name))
# Out:
# Directory /content/gdrive/MyDrive/CV_FER/models/non_dann_sfew_expw already exists.

# %%
# #@title Plotting Training and Validation Loss Function
# def plot_loss_curves(dict_non_dann_losses_list, mode = "train_losses"):
#     fig=plt.figure(figsize=(10,20))
#     fig.add_subplot(5, 1, 2)
#     # for embedding in dict_emb_file.keys():
#     list1_to_plot= dict_non_dann_losses_list[mode]
#     plt.plot(range(1,len(list1_to_plot)+1),list1_to_plot, label = 'Non DANN ' + 'SFEW')
#     plt.xlabel('number of epochs', fontsize=10)
#     plt.ylabel(str(mode), fontsize=10)
#     plt.legend(loc = 'upper right')
#     plt.title(" "+mode)
#     plt.show()

# %%
# plot_loss_curves(dict_non_dann_losses_list,mode='train_losses')
# plot_loss_curves(dict_non_dann_losses_list,mode='val_losses')
# plot_loss_curves(dict_non_dann_losses_list,mode='lr')

# %%
# model_name = model_name #"non_dann_sfew_19_12.pt"

# %% [markdown]
# ## Loading NON DANN Model for DANN and DANN EWC

# %%
model_name = f'non_dann_{source_name}_{target_name}_{str(time.strftime("%d_%m"))}.pt' # Typical - non_dann_sfew_expw_30_01.pt This may change, use specific model name if required4
model_name
# Out:
# 'non_dann_sfew_expw_04_02.pt'

# %%
# best_model_dann = DANN(num_classes=7, backbone = 'resnet18').to(device) # skeleton copy
# best_model_dann_ewc = DANN(num_classes=7, backbone = 'resnet18').to(device) # skeleton copy
# model_dann = deepcopy(non_dann_model) # saves training time - check with all
# model_dann_ewc = deepcopy(non_dann_model) # saves training time - check with all

# %%
# from data_config import DataConfig
dataconfig_1 = DataConfig()
MODEL_DIR = dataconfig_1.MODEL_DIR

MODEL_PATH = Path(os.path.join(MODEL_DIR, f'non_dann_{source_name}_{target_name}', model_name))

loaded_model_non_dann = DANN(num_classes=7, backbone = 'resnet18') # skeleton copy
best_model_dann = DANN(num_classes=7, backbone = 'resnet18').to(device) # skeleton copy
best_model_dann_ewc = DANN(num_classes=7, backbone = 'resnet18').to(device) # skeleton copy

loaded_model_non_dann.load_state_dict(torch.load(MODEL_PATH,map_location=torch.device(device)))

# loaded_model_non_dann.load_state_dict(torch.load(Path(NON_DANN_SFEW_DIR, model_name),map_location=torch.device(device)))
model_dann = deepcopy(loaded_model_non_dann) # saves training time - check with all
model_dann_ewc = deepcopy(loaded_model_non_dann) # saves training time - check with all


# print(model_dann)
# Out:
# feature extractor backbone created using resnet18 model
# feature extractor backbone created using resnet18 model
# feature extractor backbone created using resnet18 model

# %%
# #checking if the models are same weights, i.e. copy has worked fine
# for p1, p2 in zip(non_dann_model.parameters(), model_dann.parameters()):
#     if p1.data.ne(p2.data).sum() > 0:
#         print ('False')
# print ('True')

# %% [markdown]
# ## DANN Execution :  Training, Validating, Saving

# %% [markdown]
# ### DANN Execution Function

# %%
def execute_dann(model,
                 device,
                 source_train_loader, source_val_loader,
                 target_train_loader, target_val_loader,
                 optimizer,
                 n_epochs, # total number of epochs (different from individual epoch)
                 class_loss_function = nn.CrossEntropyLoss(),
                 domain_loss_function = nn.BCEWithLogitsLoss(),
                 scheduler = None,
                 early_stop_patience = None,
                 early_stop_difference = None
                 ):

    train_losses = [] # to capture train losses over training epochs
    val_losses = [] # to capture validation loss over epochs
    list_lr =[] # to capture lr over epochs
    epoch_converge = 0
    max_batches = min(len(source_train_loader), len(target_train_loader)) # Trying to check which is having less batches.
    model = model.to(device)

    # model.apply(weights_init) # TODO: skipping weights update - we can experimentation later on, and see if this helps
    list_alpha =[]


    # for best model
    best_model = deepcopy(model).to(device) # for best model
    best_val_loss = float('inf') # Initialize variables to track the best validation loss
    best_val_acc = 0 # Initialize variable to track best accuracy
    best_model_state = None # Initialize variables to track the best model state


    for epoch_idx in range(n_epochs):
        print(f'epoch = {epoch_idx+1}...in DANN execution function')
        source_iterator = iter(source_train_loader)
        target_iterator = iter (target_train_loader)
        epoch_task_loss = 0
        epoch_domain_loss =  0
        epoch_total_loss = 0
        processed = 0

        for batch_idx in range(max_batches-1):
            p = float(batch_idx + epoch_idx * max_batches) / (n_epochs * max_batches)
            alpha = 2. / (1. + np.exp(-10 * p)) - 1
            list_alpha.append(alpha)
            alpha = torch.tensor(alpha)

            model.train() # everytime ?
            optimizer.zero_grad() # flushing out the accumulated gradients

            #---------------------Source Dataset Training ------------------------#
            source_batch = next(source_iterator)
            source_images, source_labels = source_batch[0].to(device), source_batch[1].to(device) # getting images and labels, on device
            source_class_outputs, source_domain_outputs, _ = model(source_images, alpha=alpha) # forward pass, output = {class, domain, feature}


            loss_source_class = class_loss_function(source_class_outputs, source_labels) # calculating class loss

            source_domain_inputs = torch.tensor([1., 0.]*len(source_batch[0])).view(-1,2).to(device) # Source Image == [1., 0.]

            loss_source_domain = domain_loss_function(source_domain_outputs, source_domain_inputs) # calculating domain loss

            processed += len(source_batch[0])

            #---------------------Target Dataset Training ------------------------#
            target_batch = next (target_iterator)
            target_images = target_batch[0].to(device) # getting images, on device. There are no labels for target
            _, target_domain_outputs, _ = model(target_images, alpha=alpha) # forward pass, output = {class, domain, feature}

            target_domain_inputs = torch.tensor([0., 1.]*len(source_batch[0])).view(-1,2).to(device)  # Target Image == [0., 1.]
            # print(f' target domain input shape {target_domain_inputs.shape}, output shape {target_domain_outputs.shape}')

            loss_target_domain = domain_loss_function(target_domain_outputs,target_domain_inputs)  # calculating domain loss


            #---------------------Combining Loss ------------------------#
            total_loss = loss_source_class + loss_source_domain + loss_target_domain
            total_loss.backward() #backpropogation, creating gradients
            optimizer.step() # updating the params

            epoch_task_loss += loss_source_class.item()
            epoch_domain_loss += loss_source_domain.item() + loss_target_domain.item()
            epoch_total_loss += total_loss.item()

            curr_lr = optimizer.param_groups[0]['lr'] # current learning rate
            list_lr.append(curr_lr)

            # after 10 batches
            if (batch_idx % 10 == 0):
                print("Epoch[{}/{}] Step[{}/{}]: loss_total={:.4f} / domain_loss_target={:.4f} / domain_loss_source={:.4f} / task_loss={:.4f} / domain_loss={:.4f} / alpha={:.2f} / lr={:.6f}"
              .format(epoch_idx + 1,
                      n_epochs,
                      batch_idx + 1,
                      max_batches,
                      total_loss.item(),
                      loss_target_domain.item()
                      ,loss_source_domain.item()
                      ,loss_source_class.item()
                      ,loss_source_domain.item()+loss_source_class.item(),
                      alpha,
                      curr_lr
                      ))
        # After every epoch
        avg_train_task_loss =  float("{:.6f}".format(epoch_task_loss/processed))
        train_losses.append(avg_train_task_loss)

        #Scheduler
        if scheduler:
          scheduler.step(avg_train_task_loss) ## applying scheduler on training loss

        #Validate Model after every epoch
        correct, avg_val_task_loss = test_model(model= model,
                                                device= device,
                                                data_loader = source_val_loader,
                                                class_loss_function = class_loss_function)
        val_losses.append(avg_val_task_loss)

        # # Check if the current model has the best validation loss
        # print(f'Last Epoch Val Loss = {avg_val_task_loss} | Best Val Loss = {best_val_loss}' )
        # if avg_val_task_loss < best_val_loss:
        #   best_val_loss = avg_val_task_loss
        #   # save the current model state as the best model state
        #   best_model_state = deepcopy(model.state_dict())
        #   print(f'Updated the best model with validation loss: {best_val_loss}\n')

        # check if the current model has the best accuracy
        print (f'last correct ={correct} | best correct = {best_val_acc}')
        if correct > best_val_acc:
          best_val_acc = correct
          # save the current model state as the best model state
          best_model_state = deepcopy(non_dann_model.state_dict())
          print(f'Updated the best model with correct: {correct}\n')



        #TODO: Early Stopping
        if early_stop_patience and early_stop_difference: # early stopping required
          if early_stopping_difference(val_losses,
                                       patience = early_stop_patience,
                                       difference= early_stop_difference):
            print (f'-------Early Stopping at epoch {epoch+1}---')
            epoch_converge = epoch+1
            break # break from epoch loop


    # Testing when the training is over - completed or early stopped
    ## using params of best model to update model
    if best_model_state: # only update if best model has been saved, else the last one would be picked up
      model.load_state_dict(best_model_state)
      print('Best model loaded')

    correct, test_loss_source = test_model(model= model,
                            device= device,
                            data_loader = source_val_loader, # source val loader
                            class_loss_function = class_loss_function)

    correct, test_loss_target = test_model(model= model,
                            device= device,
                            data_loader = target_val_loader, # target val loader
                            class_loss_function = class_loss_function)

    dict_dann_losses = {'train_losses' : train_losses,
                        'val_losses': val_losses,
                        'test_loss_source' : test_loss_source,
                        'test_loss_target' : test_loss_target,
                        'epoch_convergence' : epoch_converge,
                        'list_alpha' : list_alpha,
                        'lr':list_lr}

    print(f'alpha list \n {list_alpha}')
    return model, dict_dann_losses

# %%
lr_dann = runconfig.inital_lr
lr_dann = lr_dann / 5.0 # OVERRIDE
optimizer_dann = optim.SGD(model_dann.parameters(), lr = lr_dann, momentum = 0.9)
n_epochs = runconfig.EPOCHS

# ReduceLRonPlateau Scheduler Params
scheduler_patience = runconfig.scheduler_patience
scheduler_factor = runconfig.scheduler_factor
scheduler_threshold = runconfig.scheduler_threshold

# Early stopping params
early_stop_patience = runconfig.early_stop_patience
early_stop_difference = runconfig.early_stop_difference

# Set up the ReduceLROnPlateau scheduler
scheduler = ReduceLROnPlateau(optimizer_dann,
                              mode='min',
                              factor=scheduler_factor,
                              patience=scheduler_patience,
                              threshold = scheduler_threshold,
                              min_lr=1e-6,
                              verbose= True)

print(f'------------training started for DANN Model ------------------')

dann_model_trained, dict_dann_losses = execute_dann(model=model_dann,
                                                    device=device,
                                                    source_train_loader = data_loader['source']['train'], #sfew_train_loader,
                                                    source_val_loader = data_loader['source']['val'], #sfew_val_loader,
                                                    target_train_loader = data_loader['target']['train'], #expw_train_loader,
                                                    target_val_loader = data_loader['target']['val'], #expw_val_loader,
                                                    optimizer = optimizer_dann,
                                                    n_epochs = n_epochs,
                                                    class_loss_function = runconfig.criterion_class,
                                                    domain_loss_function = runconfig.criterion_domain,
                                                    scheduler = scheduler,
                                                    early_stop_patience = early_stop_patience,
                                                    early_stop_difference = early_stop_difference
                                                    )
# Out:
# ------------training started for DANN Model ------------------
# epoch = 1...in DANN execution function
# Epoch[1/50] Step[1/41]: loss_total=1.4407 / domain_loss_target=0.6875 / domain_loss_source=0.7381 / task_loss=0.0151 / domain_loss=0.7532 / alpha=0.00 / lr=0.001000
# Epoch[1/50] Step[11/41]: loss_total=1.4901 / domain_loss_target=0.7064 / domain_loss_source=0.6856 / task_loss=0.0982 / domain_loss=0.7838 / alpha=0.02 / lr=0.001000
# Epoch[1/50] Step[21/41]: loss_total=1.7739 / domain_loss_target=0.7292 / domain_loss_source=0.6497 / task_loss=0.3950 / domain_loss=1.0447 / alpha=0.05 / lr=0.001000
# Epoch[1/50] Step[31/41]: loss_total=1.4082 / domain_loss_target=0.7408 / domain_loss_source=0.6138 / task_loss=0.0536 / domain_loss=0.6674 / alpha=0.07 / lr=0.001000
# Test / Val: Average loss: 0.1614, Accuracy: 192/419 (45.82%)
#
# last correct =192 | best correct = 0
# Updated the best model with correct: 192
#
# epoch = 2...in DANN execution function
# Epoch[2/50] Step[1/41]: loss_total=1.3595 / domain_loss_target=0.7609 / domain_loss_source=0.5968 / task_loss=0.0018 / domain_loss=0.5986 / alpha=0.10 / lr=0.001000
# Epoch[2/50] Step[11/41]: loss_total=1.3295 / domain_loss_target=0.7549 / domain_loss_source=0.5667 / task_loss=0.0079 / domain_loss=0.5746 / alpha=0.12 / lr=0.001000
# Epoch[2/50] Step[21/41]: loss_total=1.3489 / domain_loss_target=0.7395 / domain_loss_source=0.5789 / task_loss=0.0305 / domain_loss=0.6094 / alpha=0.15 / lr=0.001000
# Epoch[2/50] Step[31/41]: loss_total=1.5006 / domain_loss_target=0.7813 / domain_loss_source=0.5708 / task_loss=0.1485 / domain_loss=0.7193 / alpha=0.17 / lr=0.001000
# Test / Val: Average loss: 0.1654, Accuracy: 188/419 (44.87%)
#
# last correct =188 | best correct = 192
# epoch = 3...in DANN execution function
# Epoch[3/50] Step[1/41]: loss_total=1.2954 / domain_loss_target=0.7327 / domain_loss_source=0.5567 / task_loss=0.0060 / domain_loss=0.5627 / alpha=0.20 / lr=0.001000
# Epoch[3/50] Step[11/41]: loss_total=1.4474 / domain_loss_target=0.7653 / domain_loss_source=0.5908 / task_loss=0.0913 / domain_loss=0.6821 / alpha=0.22 / lr=0.001000
# Epoch[3/50] Step[21/41]: loss_total=1.3912 / domain_loss_target=0.7526 / domain_loss_source=0.5981 / task_loss=0.0405 / domain_loss=0.6386 / alpha=0.24 / lr=0.001000
# Epoch[3/50] Step[31/41]: loss_total=1.3810 / domain_loss_target=0.7699 / domain_loss_source=0.5407 / task_loss=0.0704 / domain_loss=0.6111 / alpha=0.27 / lr=0.001000
# Test / Val: Average loss: 0.1724, Accuracy: 193/419 (46.06%)
#
# last correct =193 | best correct = 192
# Updated the best model with correct: 193
#
# epoch = 4...in DANN execution function
# Epoch[4/50] Step[1/41]: loss_total=1.3654 / domain_loss_target=0.7722 / domain_loss_source=0.5739 / task_loss=0.0193 / domain_loss=0.5932 / alpha=0.29 / lr=0.001000
# Epoch[4/50] Step[11/41]: loss_total=1.3515 / domain_loss_target=0.7410 / domain_loss_source=0.5543 / task_loss=0.0562 / domain_loss=0.6106 / alpha=0.31 / lr=0.001000
# Epoch[4/50] Step[21/41]: loss_total=1.3816 / domain_loss_target=0.7611 / domain_loss_source=0.5530 / task_loss=0.0675 / domain_loss=0.6205 / alpha=0.34 / lr=0.001000
# Epoch[4/50] Step[31/41]: loss_total=1.3119 / domain_loss_target=0.7520 / domain_loss_source=0.5338 / task_loss=0.0260 / domain_loss=0.5599 / alpha=0.36 / lr=0.001000
# Test / Val: Average loss: 0.1704, Accuracy: 192/419 (45.82%)
#
# last correct =192 | best correct = 193
# epoch = 5...in DANN execution function
# Epoch[5/50] Step[1/41]: loss_total=1.4185 / domain_loss_target=0.7561 / domain_loss_source=0.6010 / task_loss=0.0614 / domain_loss=0.6624 / alpha=0.38 / lr=0.001000
# Epoch[5/50] Step[11/41]: loss_total=1.2583 / domain_loss_target=0.6851 / domain_loss_source=0.5326 / task_loss=0.0406 / domain_loss=0.5732 / alpha=0.40 / lr=0.001000
# Epoch[5/50] Step[21/41]: loss_total=1.2493 / domain_loss_target=0.6957 / domain_loss_source=0.5443 / task_loss=0.0093 / domain_loss=0.5536 / alpha=0.42 / lr=0.001000
# Epoch[5/50] Step[31/41]: loss_total=1.2036 / domain_loss_target=0.7047 / domain_loss_source=0.4958 / task_loss=0.0031 / domain_loss=0.4989 / alpha=0.44 / lr=0.001000
# Test / Val: Average loss: 0.1778, Accuracy: 193/419 (46.06%)
#
# last correct =193 | best correct = 193
# epoch = 6...in DANN execution function
# Epoch[6/50] Step[1/41]: loss_total=1.2950 / domain_loss_target=0.7388 / domain_loss_source=0.5287 / task_loss=0.0275 / domain_loss=0.5562 / alpha=0.46 / lr=0.001000
# Epoch[6/50] Step[11/41]: loss_total=1.1520 / domain_loss_target=0.7180 / domain_loss_source=0.4325 / task_loss=0.0015 / domain_loss=0.4340 / alpha=0.48 / lr=0.001000
# Epoch[6/50] Step[21/41]: loss_total=1.4539 / domain_loss_target=0.7802 / domain_loss_source=0.5246 / task_loss=0.1491 / domain_loss=0.6737 / alpha=0.50 / lr=0.001000
# Epoch[6/50] Step[31/41]: loss_total=1.2346 / domain_loss_target=0.6988 / domain_loss_source=0.5342 / task_loss=0.0016 / domain_loss=0.5358 / alpha=0.52 / lr=0.001000
# Test / Val: Average loss: 0.1695, Accuracy: 191/419 (45.58%)
#
# last correct =191 | best correct = 193
# epoch = 7...in DANN execution function
# Epoch[7/50] Step[1/41]: loss_total=1.2760 / domain_loss_target=0.6962 / domain_loss_source=0.5375 / task_loss=0.0423 / domain_loss=0.5798 / alpha=0.54 / lr=0.001000
# Epoch[7/50] Step[11/41]: loss_total=1.1688 / domain_loss_target=0.6255 / domain_loss_source=0.5355 / task_loss=0.0078 / domain_loss=0.5434 / alpha=0.55 / lr=0.001000
# Epoch[7/50] Step[21/41]: loss_total=1.2211 / domain_loss_target=0.6504 / domain_loss_source=0.5685 / task_loss=0.0022 / domain_loss=0.5707 / alpha=0.57 / lr=0.001000
# Epoch[7/50] Step[31/41]: loss_total=1.2574 / domain_loss_target=0.6744 / domain_loss_source=0.5776 / task_loss=0.0054 / domain_loss=0.5830 / alpha=0.59 / lr=0.001000
# Test / Val: Average loss: 0.1795, Accuracy: 192/419 (45.82%)
#
# last correct =192 | best correct = 193
# epoch = 8...in DANN execution function
# Epoch[8/50] Step[1/41]: loss_total=1.1452 / domain_loss_target=0.6180 / domain_loss_source=0.5155 / task_loss=0.0118 / domain_loss=0.5273 / alpha=0.60 / lr=0.001000
# Epoch[8/50] Step[11/41]: loss_total=1.1535 / domain_loss_target=0.6791 / domain_loss_source=0.4654 / task_loss=0.0089 / domain_loss=0.4743 / alpha=0.62 / lr=0.001000
# Epoch[8/50] Step[21/41]: loss_total=1.1529 / domain_loss_target=0.6375 / domain_loss_source=0.5129 / task_loss=0.0025 / domain_loss=0.5154 / alpha=0.63 / lr=0.001000
# Epoch[8/50] Step[31/41]: loss_total=1.1452 / domain_loss_target=0.6466 / domain_loss_source=0.4930 / task_loss=0.0056 / domain_loss=0.4986 / alpha=0.65 / lr=0.001000
# Test / Val: Average loss: 0.1864, Accuracy: 196/419 (46.78%)
#
# last correct =196 | best correct = 193
# Updated the best model with correct: 196
#
# epoch = 9...in DANN execution function
# Epoch[9/50] Step[1/41]: loss_total=1.1737 / domain_loss_target=0.6814 / domain_loss_source=0.4905 / task_loss=0.0018 / domain_loss=0.4924 / alpha=0.66 / lr=0.001000
# Epoch[9/50] Step[11/41]: loss_total=1.1654 / domain_loss_target=0.6909 / domain_loss_source=0.4734 / task_loss=0.0011 / domain_loss=0.4745 / alpha=0.68 / lr=0.001000
# Epoch[9/50] Step[21/41]: loss_total=1.3855 / domain_loss_target=0.6857 / domain_loss_source=0.6726 / task_loss=0.0271 / domain_loss=0.6998 / alpha=0.69 / lr=0.001000
# Epoch[9/50] Step[31/41]: loss_total=1.2876 / domain_loss_target=0.6923 / domain_loss_source=0.5844 / task_loss=0.0109 / domain_loss=0.5953 / alpha=0.70 / lr=0.001000
# Test / Val: Average loss: 0.1763, Accuracy: 192/419 (45.82%)
#
# last correct =192 | best correct = 196
# epoch = 10...in DANN execution function
# Epoch[10/50] Step[1/41]: loss_total=1.1387 / domain_loss_target=0.6799 / domain_loss_source=0.4397 / task_loss=0.0191 / domain_loss=0.4588 / alpha=0.72 / lr=0.001000
# Epoch[10/50] Step[11/41]: loss_total=1.3154 / domain_loss_target=0.6294 / domain_loss_source=0.5851 / task_loss=0.1009 / domain_loss=0.6859 / alpha=0.73 / lr=0.001000
# Epoch[10/50] Step[21/41]: loss_total=1.2584 / domain_loss_target=0.6638 / domain_loss_source=0.5758 / task_loss=0.0187 / domain_loss=0.5946 / alpha=0.74 / lr=0.001000
# Epoch[10/50] Step[31/41]: loss_total=1.2543 / domain_loss_target=0.6544 / domain_loss_source=0.5105 / task_loss=0.0894 / domain_loss=0.5999 / alpha=0.75 / lr=0.001000
# Test / Val: Average loss: 0.1770, Accuracy: 183/419 (43.68%)
#
# last correct =183 | best correct = 196
# epoch = 11...in DANN execution function
# Epoch[11/50] Step[1/41]: loss_total=1.2409 / domain_loss_target=0.6381 / domain_loss_source=0.5871 / task_loss=0.0157 / domain_loss=0.6028 / alpha=0.76 / lr=0.001000
# Epoch[11/50] Step[11/41]: loss_total=1.1555 / domain_loss_target=0.6270 / domain_loss_source=0.5236 / task_loss=0.0049 / domain_loss=0.5285 / alpha=0.77 / lr=0.001000
# Epoch[11/50] Step[21/41]: loss_total=1.1112 / domain_loss_target=0.6087 / domain_loss_source=0.4909 / task_loss=0.0116 / domain_loss=0.5025 / alpha=0.78 / lr=0.001000
# Epoch[11/50] Step[31/41]: loss_total=1.3288 / domain_loss_target=0.6562 / domain_loss_source=0.6218 / task_loss=0.0508 / domain_loss=0.6726 / alpha=0.79 / lr=0.001000
# Test / Val: Average loss: 0.1815, Accuracy: 181/419 (43.20%)
#
# last correct =181 | best correct = 196
# epoch = 12...in DANN execution function
# Epoch[12/50] Step[1/41]: loss_total=1.3368 / domain_loss_target=0.7152 / domain_loss_source=0.5664 / task_loss=0.0552 / domain_loss=0.6216 / alpha=0.80 / lr=0.001000
# Epoch[12/50] Step[11/41]: loss_total=1.1854 / domain_loss_target=0.6214 / domain_loss_source=0.5602 / task_loss=0.0038 / domain_loss=0.5640 / alpha=0.81 / lr=0.001000
# Epoch[12/50] Step[21/41]: loss_total=1.3344 / domain_loss_target=0.7628 / domain_loss_source=0.5073 / task_loss=0.0643 / domain_loss=0.5716 / alpha=0.82 / lr=0.001000
# Epoch[12/50] Step[31/41]: loss_total=1.1368 / domain_loss_target=0.6121 / domain_loss_source=0.5216 / task_loss=0.0031 / domain_loss=0.5247 / alpha=0.83 / lr=0.001000
# Epoch 00012: reducing learning rate of group 0 to 2.0000e-04.
# Test / Val: Average loss: 0.1849, Accuracy: 180/419 (42.96%)
#
# last correct =180 | best correct = 196
# epoch = 13...in DANN execution function
# Epoch[13/50] Step[1/41]: loss_total=1.3286 / domain_loss_target=0.6487 / domain_loss_source=0.5934 / task_loss=0.0865 / domain_loss=0.6799 / alpha=0.83 / lr=0.000200
# Epoch[13/50] Step[11/41]: loss_total=1.2292 / domain_loss_target=0.6584 / domain_loss_source=0.5677 / task_loss=0.0031 / domain_loss=0.5709 / alpha=0.84 / lr=0.000200
# Epoch[13/50] Step[21/41]: loss_total=1.5446 / domain_loss_target=0.6348 / domain_loss_source=0.6312 / task_loss=0.2786 / domain_loss=0.9098 / alpha=0.85 / lr=0.000200
# Epoch[13/50] Step[31/41]: loss_total=1.1644 / domain_loss_target=0.5988 / domain_loss_source=0.5379 / task_loss=0.0277 / domain_loss=0.5657 / alpha=0.85 / lr=0.000200
# Test / Val: Average loss: 0.1850, Accuracy: 182/419 (43.44%)
#
# last correct =182 | best correct = 196
# epoch = 14...in DANN execution function
# Epoch[14/50] Step[1/41]: loss_total=1.5231 / domain_loss_target=0.7223 / domain_loss_source=0.6499 / task_loss=0.1509 / domain_loss=0.8007 / alpha=0.86 / lr=0.000200
# Epoch[14/50] Step[11/41]: loss_total=1.3044 / domain_loss_target=0.6270 / domain_loss_source=0.6239 / task_loss=0.0535 / domain_loss=0.6774 / alpha=0.87 / lr=0.000200
# Epoch[14/50] Step[21/41]: loss_total=1.2126 / domain_loss_target=0.6595 / domain_loss_source=0.5328 / task_loss=0.0203 / domain_loss=0.5531 / alpha=0.87 / lr=0.000200
# Epoch[14/50] Step[31/41]: loss_total=1.2551 / domain_loss_target=0.6243 / domain_loss_source=0.6073 / task_loss=0.0235 / domain_loss=0.6308 / alpha=0.88 / lr=0.000200
# Test / Val: Average loss: 0.1861, Accuracy: 181/419 (43.20%)
#
# last correct =181 | best correct = 196
# epoch = 15...in DANN execution function
# Epoch[15/50] Step[1/41]: loss_total=1.3545 / domain_loss_target=0.6841 / domain_loss_source=0.6642 / task_loss=0.0062 / domain_loss=0.6704 / alpha=0.89 / lr=0.000200
# Epoch[15/50] Step[11/41]: loss_total=1.3106 / domain_loss_target=0.7017 / domain_loss_source=0.6053 / task_loss=0.0036 / domain_loss=0.6090 / alpha=0.89 / lr=0.000200
# Epoch[15/50] Step[21/41]: loss_total=1.3505 / domain_loss_target=0.6436 / domain_loss_source=0.6651 / task_loss=0.0418 / domain_loss=0.7069 / alpha=0.90 / lr=0.000200
# Epoch[15/50] Step[31/41]: loss_total=1.2945 / domain_loss_target=0.6387 / domain_loss_source=0.6348 / task_loss=0.0210 / domain_loss=0.6558 / alpha=0.90 / lr=0.000200
# Test / Val: Average loss: 0.1851, Accuracy: 179/419 (42.72%)
#
# last correct =179 | best correct = 196
# epoch = 16...in DANN execution function
# Epoch[16/50] Step[1/41]: loss_total=1.4478 / domain_loss_target=0.8520 / domain_loss_source=0.5895 / task_loss=0.0063 / domain_loss=0.5958 / alpha=0.91 / lr=0.000200
# Epoch[16/50] Step[11/41]: loss_total=1.4479 / domain_loss_target=0.6419 / domain_loss_source=0.6198 / task_loss=0.1863 / domain_loss=0.8060 / alpha=0.91 / lr=0.000200
# Epoch[16/50] Step[21/41]: loss_total=1.2848 / domain_loss_target=0.7418 / domain_loss_source=0.5362 / task_loss=0.0068 / domain_loss=0.5429 / alpha=0.91 / lr=0.000200
# Epoch[16/50] Step[31/41]: loss_total=1.3145 / domain_loss_target=0.6587 / domain_loss_source=0.6139 / task_loss=0.0418 / domain_loss=0.6558 / alpha=0.92 / lr=0.000200
# Epoch 00016: reducing learning rate of group 0 to 4.0000e-05.
# Test / Val: Average loss: 0.1878, Accuracy: 176/419 (42.00%)
#
# last correct =176 | best correct = 196
# epoch = 17...in DANN execution function
# Epoch[17/50] Step[1/41]: loss_total=1.1972 / domain_loss_target=0.5826 / domain_loss_source=0.5980 / task_loss=0.0166 / domain_loss=0.6146 / alpha=0.92 / lr=0.000040
# Epoch[17/50] Step[11/41]: loss_total=1.3058 / domain_loss_target=0.6058 / domain_loss_source=0.6826 / task_loss=0.0173 / domain_loss=0.6999 / alpha=0.93 / lr=0.000040
# Epoch[17/50] Step[21/41]: loss_total=1.5117 / domain_loss_target=0.7491 / domain_loss_source=0.6728 / task_loss=0.0897 / domain_loss=0.7626 / alpha=0.93 / lr=0.000040
# Epoch[17/50] Step[31/41]: loss_total=1.2615 / domain_loss_target=0.6740 / domain_loss_source=0.5807 / task_loss=0.0068 / domain_loss=0.5875 / alpha=0.93 / lr=0.000040
# Test / Val: Average loss: 0.1820, Accuracy: 182/419 (43.44%)
#
# last correct =182 | best correct = 196
# epoch = 18...in DANN execution function
# Epoch[18/50] Step[1/41]: loss_total=1.5159 / domain_loss_target=0.7392 / domain_loss_source=0.6261 / task_loss=0.1506 / domain_loss=0.7767 / alpha=0.94 / lr=0.000040
# Epoch[18/50] Step[11/41]: loss_total=1.3096 / domain_loss_target=0.6361 / domain_loss_source=0.6498 / task_loss=0.0237 / domain_loss=0.6735 / alpha=0.94 / lr=0.000040
# Epoch[18/50] Step[21/41]: loss_total=1.4415 / domain_loss_target=0.7380 / domain_loss_source=0.6803 / task_loss=0.0232 / domain_loss=0.7035 / alpha=0.94 / lr=0.000040
# Epoch[18/50] Step[31/41]: loss_total=1.4525 / domain_loss_target=0.6005 / domain_loss_source=0.7094 / task_loss=0.1427 / domain_loss=0.8521 / alpha=0.94 / lr=0.000040
# Test / Val: Average loss: 0.1802, Accuracy: 183/419 (43.68%)
#
# last correct =183 | best correct = 196
# epoch = 19...in DANN execution function
# Epoch[19/50] Step[1/41]: loss_total=1.3510 / domain_loss_target=0.6453 / domain_loss_source=0.5985 / task_loss=0.1072 / domain_loss=0.7057 / alpha=0.95 / lr=0.000040
# Epoch[19/50] Step[11/41]: loss_total=1.3528 / domain_loss_target=0.6268 / domain_loss_source=0.5954 / task_loss=0.1306 / domain_loss=0.7260 / alpha=0.95 / lr=0.000040
# Epoch[19/50] Step[21/41]: loss_total=1.2516 / domain_loss_target=0.6786 / domain_loss_source=0.5683 / task_loss=0.0046 / domain_loss=0.5730 / alpha=0.95 / lr=0.000040
# Epoch[19/50] Step[31/41]: loss_total=1.3066 / domain_loss_target=0.7497 / domain_loss_source=0.5531 / task_loss=0.0038 / domain_loss=0.5569 / alpha=0.95 / lr=0.000040
# Test / Val: Average loss: 0.1817, Accuracy: 183/419 (43.68%)
#
# last correct =183 | best correct = 196
# epoch = 20...in DANN execution function
# Epoch[20/50] Step[1/41]: loss_total=1.3833 / domain_loss_target=0.7584 / domain_loss_source=0.6214 / task_loss=0.0036 / domain_loss=0.6250 / alpha=0.96 / lr=0.000040
# Epoch[20/50] Step[11/41]: loss_total=1.3308 / domain_loss_target=0.7669 / domain_loss_source=0.5556 / task_loss=0.0083 / domain_loss=0.5640 / alpha=0.96 / lr=0.000040
# Epoch[20/50] Step[21/41]: loss_total=1.1489 / domain_loss_target=0.6307 / domain_loss_source=0.5128 / task_loss=0.0054 / domain_loss=0.5182 / alpha=0.96 / lr=0.000040
# Epoch[20/50] Step[31/41]: loss_total=1.3543 / domain_loss_target=0.7107 / domain_loss_source=0.6417 / task_loss=0.0019 / domain_loss=0.6436 / alpha=0.96 / lr=0.000040
# Epoch 00020: reducing learning rate of group 0 to 8.0000e-06.
# Test / Val: Average loss: 0.1793, Accuracy: 182/419 (43.44%)
#
# last correct =182 | best correct = 196
# epoch = 21...in DANN execution function
# Epoch[21/50] Step[1/41]: loss_total=1.3413 / domain_loss_target=0.6268 / domain_loss_source=0.7022 / task_loss=0.0123 / domain_loss=0.7144 / alpha=0.96 / lr=0.000008
# Epoch[21/50] Step[11/41]: loss_total=1.4609 / domain_loss_target=0.6700 / domain_loss_source=0.6676 / task_loss=0.1233 / domain_loss=0.7910 / alpha=0.97 / lr=0.000008
# Epoch[21/50] Step[21/41]: loss_total=1.4108 / domain_loss_target=0.7775 / domain_loss_source=0.6124 / task_loss=0.0208 / domain_loss=0.6332 / alpha=0.97 / lr=0.000008
# Epoch[21/50] Step[31/41]: loss_total=1.4813 / domain_loss_target=0.6871 / domain_loss_source=0.6437 / task_loss=0.1505 / domain_loss=0.7942 / alpha=0.97 / lr=0.000008
# Test / Val: Average loss: 0.1733, Accuracy: 177/419 (42.24%)
#
# last correct =177 | best correct = 196
# epoch = 22...in DANN execution function
# Epoch[22/50] Step[1/41]: loss_total=1.3175 / domain_loss_target=0.7890 / domain_loss_source=0.5272 / task_loss=0.0014 / domain_loss=0.5285 / alpha=0.97 / lr=0.000008
# Epoch[22/50] Step[11/41]: loss_total=1.3388 / domain_loss_target=0.6594 / domain_loss_source=0.6117 / task_loss=0.0677 / domain_loss=0.6794 / alpha=0.97 / lr=0.000008
# Epoch[22/50] Step[21/41]: loss_total=1.4793 / domain_loss_target=0.7967 / domain_loss_source=0.6238 / task_loss=0.0588 / domain_loss=0.6826 / alpha=0.97 / lr=0.000008
# Epoch[22/50] Step[31/41]: loss_total=1.2183 / domain_loss_target=0.6654 / domain_loss_source=0.5521 / task_loss=0.0008 / domain_loss=0.5529 / alpha=0.97 / lr=0.000008
# Test / Val: Average loss: 0.1868, Accuracy: 180/419 (42.96%)
#
# last correct =180 | best correct = 196
# epoch = 23...in DANN execution function
# Epoch[23/50] Step[1/41]: loss_total=1.4878 / domain_loss_target=0.7494 / domain_loss_source=0.7336 / task_loss=0.0047 / domain_loss=0.7383 / alpha=0.98 / lr=0.000008
# Epoch[23/50] Step[11/41]: loss_total=1.4712 / domain_loss_target=0.6867 / domain_loss_source=0.7629 / task_loss=0.0216 / domain_loss=0.7845 / alpha=0.98 / lr=0.000008
# Epoch[23/50] Step[21/41]: loss_total=1.2099 / domain_loss_target=0.6822 / domain_loss_source=0.5268 / task_loss=0.0009 / domain_loss=0.5277 / alpha=0.98 / lr=0.000008
# Epoch[23/50] Step[31/41]: loss_total=1.4174 / domain_loss_target=0.7360 / domain_loss_source=0.5963 / task_loss=0.0851 / domain_loss=0.6813 / alpha=0.98 / lr=0.000008
# Test / Val: Average loss: 0.1808, Accuracy: 182/419 (43.44%)
#
# last correct =182 | best correct = 196
# epoch = 24...in DANN execution function
# Epoch[24/50] Step[1/41]: loss_total=1.5034 / domain_loss_target=0.7628 / domain_loss_source=0.6504 / task_loss=0.0901 / domain_loss=0.7405 / alpha=0.98 / lr=0.000008
# Epoch[24/50] Step[11/41]: loss_total=1.1716 / domain_loss_target=0.6223 / domain_loss_source=0.5490 / task_loss=0.0003 / domain_loss=0.5493 / alpha=0.98 / lr=0.000008
# Epoch[24/50] Step[21/41]: loss_total=1.4515 / domain_loss_target=0.7182 / domain_loss_source=0.6841 / task_loss=0.0491 / domain_loss=0.7333 / alpha=0.98 / lr=0.000008
# Epoch[24/50] Step[31/41]: loss_total=1.3037 / domain_loss_target=0.5853 / domain_loss_source=0.6978 / task_loss=0.0205 / domain_loss=0.7183 / alpha=0.98 / lr=0.000008
# Epoch 00024: reducing learning rate of group 0 to 1.6000e-06.
# Test / Val: Average loss: 0.1901, Accuracy: 179/419 (42.72%)
#
# last correct =179 | best correct = 196
# epoch = 25...in DANN execution function
# Epoch[25/50] Step[1/41]: loss_total=1.4771 / domain_loss_target=0.8056 / domain_loss_source=0.5816 / task_loss=0.0898 / domain_loss=0.6714 / alpha=0.98 / lr=0.000002
# Epoch[25/50] Step[11/41]: loss_total=1.1452 / domain_loss_target=0.6360 / domain_loss_source=0.5083 / task_loss=0.0009 / domain_loss=0.5092 / alpha=0.98 / lr=0.000002
# Epoch[25/50] Step[21/41]: loss_total=1.2857 / domain_loss_target=0.6371 / domain_loss_source=0.6023 / task_loss=0.0464 / domain_loss=0.6486 / alpha=0.99 / lr=0.000002
# Epoch[25/50] Step[31/41]: loss_total=1.3661 / domain_loss_target=0.6853 / domain_loss_source=0.6376 / task_loss=0.0432 / domain_loss=0.6808 / alpha=0.99 / lr=0.000002
# Test / Val: Average loss: 0.1929, Accuracy: 181/419 (43.20%)
#
# last correct =181 | best correct = 196
# epoch = 26...in DANN execution function
# Epoch[26/50] Step[1/41]: loss_total=1.3231 / domain_loss_target=0.6812 / domain_loss_source=0.6369 / task_loss=0.0050 / domain_loss=0.6419 / alpha=0.99 / lr=0.000002
# Epoch[26/50] Step[11/41]: loss_total=1.2422 / domain_loss_target=0.6586 / domain_loss_source=0.5800 / task_loss=0.0036 / domain_loss=0.5835 / alpha=0.99 / lr=0.000002
# Epoch[26/50] Step[21/41]: loss_total=1.2847 / domain_loss_target=0.6381 / domain_loss_source=0.5815 / task_loss=0.0652 / domain_loss=0.6467 / alpha=0.99 / lr=0.000002
# Epoch[26/50] Step[31/41]: loss_total=1.2658 / domain_loss_target=0.6455 / domain_loss_source=0.6163 / task_loss=0.0040 / domain_loss=0.6203 / alpha=0.99 / lr=0.000002
# Test / Val: Average loss: 0.1757, Accuracy: 180/419 (42.96%)
#
# last correct =180 | best correct = 196
# epoch = 27...in DANN execution function
# Epoch[27/50] Step[1/41]: loss_total=1.1418 / domain_loss_target=0.5859 / domain_loss_source=0.5394 / task_loss=0.0166 / domain_loss=0.5560 / alpha=0.99 / lr=0.000002
# Epoch[27/50] Step[11/41]: loss_total=1.3129 / domain_loss_target=0.6962 / domain_loss_source=0.5910 / task_loss=0.0257 / domain_loss=0.6167 / alpha=0.99 / lr=0.000002
# Epoch[27/50] Step[21/41]: loss_total=1.2278 / domain_loss_target=0.6814 / domain_loss_source=0.5329 / task_loss=0.0135 / domain_loss=0.5464 / alpha=0.99 / lr=0.000002
# Epoch[27/50] Step[31/41]: loss_total=1.4051 / domain_loss_target=0.7202 / domain_loss_source=0.6288 / task_loss=0.0561 / domain_loss=0.6849 / alpha=0.99 / lr=0.000002
# Test / Val: Average loss: 0.1813, Accuracy: 180/419 (42.96%)
#
# last correct =180 | best correct = 196
# epoch = 28...in DANN execution function
# Epoch[28/50] Step[1/41]: loss_total=1.3653 / domain_loss_target=0.7449 / domain_loss_source=0.6188 / task_loss=0.0017 / domain_loss=0.6204 / alpha=0.99 / lr=0.000002
# Epoch[28/50] Step[11/41]: loss_total=1.3926 / domain_loss_target=0.7636 / domain_loss_source=0.6190 / task_loss=0.0100 / domain_loss=0.6290 / alpha=0.99 / lr=0.000002
# Epoch[28/50] Step[21/41]: loss_total=1.2258 / domain_loss_target=0.6786 / domain_loss_source=0.5441 / task_loss=0.0031 / domain_loss=0.5472 / alpha=0.99 / lr=0.000002
# Epoch[28/50] Step[31/41]: loss_total=1.1806 / domain_loss_target=0.5927 / domain_loss_source=0.5867 / task_loss=0.0012 / domain_loss=0.5879 / alpha=0.99 / lr=0.000002
# Epoch 00028: reducing learning rate of group 0 to 1.0000e-06.
# Test / Val: Average loss: 0.1848, Accuracy: 181/419 (43.20%)
#
# last correct =181 | best correct = 196
# epoch = 29...in DANN execution function
# Epoch[29/50] Step[1/41]: loss_total=1.6389 / domain_loss_target=0.6334 / domain_loss_source=0.6947 / task_loss=0.3109 / domain_loss=1.0055 / alpha=0.99 / lr=0.000001
# Epoch[29/50] Step[11/41]: loss_total=1.4997 / domain_loss_target=0.7916 / domain_loss_source=0.6834 / task_loss=0.0247 / domain_loss=0.7081 / alpha=0.99 / lr=0.000001
# Epoch[29/50] Step[21/41]: loss_total=1.2447 / domain_loss_target=0.6439 / domain_loss_source=0.5484 / task_loss=0.0524 / domain_loss=0.6008 / alpha=0.99 / lr=0.000001
# Epoch[29/50] Step[31/41]: loss_total=1.4868 / domain_loss_target=0.7146 / domain_loss_source=0.6232 / task_loss=0.1490 / domain_loss=0.7722 / alpha=0.99 / lr=0.000001
# Test / Val: Average loss: 0.1872, Accuracy: 182/419 (43.44%)
#
# last correct =182 | best correct = 196
# epoch = 30...in DANN execution function
# Epoch[30/50] Step[1/41]: loss_total=1.4444 / domain_loss_target=0.8039 / domain_loss_source=0.6263 / task_loss=0.0142 / domain_loss=0.6404 / alpha=0.99 / lr=0.000001
# Epoch[30/50] Step[11/41]: loss_total=1.1711 / domain_loss_target=0.6491 / domain_loss_source=0.5039 / task_loss=0.0181 / domain_loss=0.5220 / alpha=0.99 / lr=0.000001
# Epoch[30/50] Step[21/41]: loss_total=1.3859 / domain_loss_target=0.7554 / domain_loss_source=0.6004 / task_loss=0.0301 / domain_loss=0.6305 / alpha=0.99 / lr=0.000001
# Epoch[30/50] Step[31/41]: loss_total=1.3845 / domain_loss_target=0.6807 / domain_loss_source=0.7001 / task_loss=0.0037 / domain_loss=0.7038 / alpha=0.99 / lr=0.000001
# Test / Val: Average loss: 0.1823, Accuracy: 182/419 (43.44%)
#
# last correct =182 | best correct = 196
# epoch = 31...in DANN execution function
# Epoch[31/50] Step[1/41]: loss_total=1.0784 / domain_loss_target=0.5311 / domain_loss_source=0.5415 / task_loss=0.0058 / domain_loss=0.5473 / alpha=1.00 / lr=0.000001
# Epoch[31/50] Step[11/41]: loss_total=1.3705 / domain_loss_target=0.6741 / domain_loss_source=0.6815 / task_loss=0.0149 / domain_loss=0.6964 / alpha=1.00 / lr=0.000001
# Epoch[31/50] Step[21/41]: loss_total=1.5539 / domain_loss_target=0.6387 / domain_loss_source=0.7158 / task_loss=0.1994 / domain_loss=0.9152 / alpha=1.00 / lr=0.000001
# Epoch[31/50] Step[31/41]: loss_total=1.5740 / domain_loss_target=0.6420 / domain_loss_source=0.7044 / task_loss=0.2276 / domain_loss=0.9320 / alpha=1.00 / lr=0.000001
# Test / Val: Average loss: 0.1824, Accuracy: 180/419 (42.96%)
#
# last correct =180 | best correct = 196
# epoch = 32...in DANN execution function
# Epoch[32/50] Step[1/41]: loss_total=1.3939 / domain_loss_target=0.7404 / domain_loss_source=0.5968 / task_loss=0.0567 / domain_loss=0.6535 / alpha=1.00 / lr=0.000001
# Epoch[32/50] Step[11/41]: loss_total=1.2812 / domain_loss_target=0.6287 / domain_loss_source=0.6160 / task_loss=0.0366 / domain_loss=0.6525 / alpha=1.00 / lr=0.000001
# Epoch[32/50] Step[21/41]: loss_total=1.3047 / domain_loss_target=0.6413 / domain_loss_source=0.6533 / task_loss=0.0101 / domain_loss=0.6634 / alpha=1.00 / lr=0.000001
# Epoch[32/50] Step[31/41]: loss_total=1.3832 / domain_loss_target=0.7561 / domain_loss_source=0.6165 / task_loss=0.0106 / domain_loss=0.6271 / alpha=1.00 / lr=0.000001
# Test / Val: Average loss: 0.1837, Accuracy: 180/419 (42.96%)
#
# last correct =180 | best correct = 196
# epoch = 33...in DANN execution function
# Epoch[33/50] Step[1/41]: loss_total=1.4755 / domain_loss_target=0.6344 / domain_loss_source=0.6724 / task_loss=0.1687 / domain_loss=0.8411 / alpha=1.00 / lr=0.000001
# Epoch[33/50] Step[11/41]: loss_total=1.1191 / domain_loss_target=0.5706 / domain_loss_source=0.5366 / task_loss=0.0119 / domain_loss=0.5485 / alpha=1.00 / lr=0.000001
# Epoch[33/50] Step[21/41]: loss_total=1.2843 / domain_loss_target=0.7034 / domain_loss_source=0.5684 / task_loss=0.0125 / domain_loss=0.5809 / alpha=1.00 / lr=0.000001
# Epoch[33/50] Step[31/41]: loss_total=1.3916 / domain_loss_target=0.7674 / domain_loss_source=0.6061 / task_loss=0.0181 / domain_loss=0.6242 / alpha=1.00 / lr=0.000001
# Test / Val: Average loss: 0.1804, Accuracy: 180/419 (42.96%)
#
# last correct =180 | best correct = 196
# epoch = 34...in DANN execution function
# Epoch[34/50] Step[1/41]: loss_total=1.3083 / domain_loss_target=0.7689 / domain_loss_source=0.5327 / task_loss=0.0067 / domain_loss=0.5394 / alpha=1.00 / lr=0.000001
# Epoch[34/50] Step[11/41]: loss_total=1.2939 / domain_loss_target=0.7194 / domain_loss_source=0.5720 / task_loss=0.0025 / domain_loss=0.5745 / alpha=1.00 / lr=0.000001
# Epoch[34/50] Step[21/41]: loss_total=1.3909 / domain_loss_target=0.7461 / domain_loss_source=0.5935 / task_loss=0.0513 / domain_loss=0.6448 / alpha=1.00 / lr=0.000001
# Epoch[34/50] Step[31/41]: loss_total=1.2383 / domain_loss_target=0.6833 / domain_loss_source=0.5523 / task_loss=0.0027 / domain_loss=0.5550 / alpha=1.00 / lr=0.000001
# Test / Val: Average loss: 0.1808, Accuracy: 181/419 (43.20%)
#
# last correct =181 | best correct = 196
# epoch = 35...in DANN execution function
# Epoch[35/50] Step[1/41]: loss_total=1.4119 / domain_loss_target=0.7939 / domain_loss_source=0.5896 / task_loss=0.0284 / domain_loss=0.6180 / alpha=1.00 / lr=0.000001
# Epoch[35/50] Step[11/41]: loss_total=1.4146 / domain_loss_target=0.7032 / domain_loss_source=0.6210 / task_loss=0.0904 / domain_loss=0.7114 / alpha=1.00 / lr=0.000001
# Epoch[35/50] Step[21/41]: loss_total=1.3150 / domain_loss_target=0.7181 / domain_loss_source=0.5549 / task_loss=0.0419 / domain_loss=0.5968 / alpha=1.00 / lr=0.000001
# Epoch[35/50] Step[31/41]: loss_total=1.4214 / domain_loss_target=0.6828 / domain_loss_source=0.5727 / task_loss=0.1658 / domain_loss=0.7386 / alpha=1.00 / lr=0.000001
# Test / Val: Average loss: 0.1964, Accuracy: 177/419 (42.24%)
#
# last correct =177 | best correct = 196
# epoch = 36...in DANN execution function
# Epoch[36/50] Step[1/41]: loss_total=1.4141 / domain_loss_target=0.7667 / domain_loss_source=0.6225 / task_loss=0.0249 / domain_loss=0.6474 / alpha=1.00 / lr=0.000001
# Epoch[36/50] Step[11/41]: loss_total=1.4086 / domain_loss_target=0.7600 / domain_loss_source=0.6447 / task_loss=0.0040 / domain_loss=0.6486 / alpha=1.00 / lr=0.000001
# Epoch[36/50] Step[21/41]: loss_total=1.5393 / domain_loss_target=0.7607 / domain_loss_source=0.6534 / task_loss=0.1252 / domain_loss=0.7786 / alpha=1.00 / lr=0.000001
# Epoch[36/50] Step[31/41]: loss_total=1.3900 / domain_loss_target=0.6804 / domain_loss_source=0.6812 / task_loss=0.0284 / domain_loss=0.7096 / alpha=1.00 / lr=0.000001
# Test / Val: Average loss: 0.1799, Accuracy: 180/419 (42.96%)
#
# last correct =180 | best correct = 196
# epoch = 37...in DANN execution function
# Epoch[37/50] Step[1/41]: loss_total=1.3702 / domain_loss_target=0.7577 / domain_loss_source=0.5978 / task_loss=0.0147 / domain_loss=0.6125 / alpha=1.00 / lr=0.000001
# Epoch[37/50] Step[11/41]: loss_total=1.3041 / domain_loss_target=0.7097 / domain_loss_source=0.5828 / task_loss=0.0116 / domain_loss=0.5944 / alpha=1.00 / lr=0.000001
# Epoch[37/50] Step[21/41]: loss_total=1.3451 / domain_loss_target=0.6451 / domain_loss_source=0.6791 / task_loss=0.0209 / domain_loss=0.7000 / alpha=1.00 / lr=0.000001
# Epoch[37/50] Step[31/41]: loss_total=1.4715 / domain_loss_target=0.7292 / domain_loss_source=0.7258 / task_loss=0.0164 / domain_loss=0.7422 / alpha=1.00 / lr=0.000001
# Test / Val: Average loss: 0.1790, Accuracy: 179/419 (42.72%)
#
# last correct =179 | best correct = 196
# epoch = 38...in DANN execution function
# Epoch[38/50] Step[1/41]: loss_total=1.3677 / domain_loss_target=0.6985 / domain_loss_source=0.6262 / task_loss=0.0430 / domain_loss=0.6692 / alpha=1.00 / lr=0.000001
# Epoch[38/50] Step[11/41]: loss_total=1.3583 / domain_loss_target=0.6327 / domain_loss_source=0.7217 / task_loss=0.0039 / domain_loss=0.7256 / alpha=1.00 / lr=0.000001
# Epoch[38/50] Step[21/41]: loss_total=1.5362 / domain_loss_target=0.8279 / domain_loss_source=0.5949 / task_loss=0.1134 / domain_loss=0.7082 / alpha=1.00 / lr=0.000001
# Epoch[38/50] Step[31/41]: loss_total=1.1629 / domain_loss_target=0.6389 / domain_loss_source=0.5147 / task_loss=0.0093 / domain_loss=0.5240 / alpha=1.00 / lr=0.000001
# Test / Val: Average loss: 0.1901, Accuracy: 177/419 (42.24%)
#
# last correct =177 | best correct = 196
# epoch = 39...in DANN execution function
# Epoch[39/50] Step[1/41]: loss_total=1.6735 / domain_loss_target=0.7283 / domain_loss_source=0.7130 / task_loss=0.2322 / domain_loss=0.9451 / alpha=1.00 / lr=0.000001
# Epoch[39/50] Step[11/41]: loss_total=1.3716 / domain_loss_target=0.7729 / domain_loss_source=0.5920 / task_loss=0.0067 / domain_loss=0.5988 / alpha=1.00 / lr=0.000001
# Epoch[39/50] Step[21/41]: loss_total=1.1412 / domain_loss_target=0.5881 / domain_loss_source=0.5465 / task_loss=0.0066 / domain_loss=0.5531 / alpha=1.00 / lr=0.000001
# Epoch[39/50] Step[31/41]: loss_total=1.0837 / domain_loss_target=0.6127 / domain_loss_source=0.4689 / task_loss=0.0021 / domain_loss=0.4710 / alpha=1.00 / lr=0.000001
# Test / Val: Average loss: 0.1801, Accuracy: 185/419 (44.15%)
#
# last correct =185 | best correct = 196
# epoch = 40...in DANN execution function
# Epoch[40/50] Step[1/41]: loss_total=1.4649 / domain_loss_target=0.7016 / domain_loss_source=0.6254 / task_loss=0.1380 / domain_loss=0.7633 / alpha=1.00 / lr=0.000001
# Epoch[40/50] Step[11/41]: loss_total=1.3970 / domain_loss_target=0.7235 / domain_loss_source=0.6658 / task_loss=0.0077 / domain_loss=0.6735 / alpha=1.00 / lr=0.000001
# Epoch[40/50] Step[21/41]: loss_total=1.2641 / domain_loss_target=0.6459 / domain_loss_source=0.5898 / task_loss=0.0283 / domain_loss=0.6181 / alpha=1.00 / lr=0.000001
# Epoch[40/50] Step[31/41]: loss_total=1.2795 / domain_loss_target=0.7101 / domain_loss_source=0.5690 / task_loss=0.0004 / domain_loss=0.5694 / alpha=1.00 / lr=0.000001
# Test / Val: Average loss: 0.1797, Accuracy: 181/419 (43.20%)
#
# last correct =181 | best correct = 196
# epoch = 41...in DANN execution function
# Epoch[41/50] Step[1/41]: loss_total=1.4029 / domain_loss_target=0.7328 / domain_loss_source=0.6489 / task_loss=0.0212 / domain_loss=0.6701 / alpha=1.00 / lr=0.000001
# Epoch[41/50] Step[11/41]: loss_total=1.4294 / domain_loss_target=0.6465 / domain_loss_source=0.6141 / task_loss=0.1688 / domain_loss=0.7829 / alpha=1.00 / lr=0.000001
# Epoch[41/50] Step[21/41]: loss_total=1.3292 / domain_loss_target=0.7233 / domain_loss_source=0.5976 / task_loss=0.0082 / domain_loss=0.6058 / alpha=1.00 / lr=0.000001
# Epoch[41/50] Step[31/41]: loss_total=1.5291 / domain_loss_target=0.8423 / domain_loss_source=0.6790 / task_loss=0.0079 / domain_loss=0.6869 / alpha=1.00 / lr=0.000001
# Test / Val: Average loss: 0.1836, Accuracy: 179/419 (42.72%)
#
# last correct =179 | best correct = 196
# epoch = 42...in DANN execution function
# Epoch[42/50] Step[1/41]: loss_total=1.2904 / domain_loss_target=0.7086 / domain_loss_source=0.5656 / task_loss=0.0161 / domain_loss=0.5817 / alpha=1.00 / lr=0.000001
# Epoch[42/50] Step[11/41]: loss_total=1.2044 / domain_loss_target=0.6167 / domain_loss_source=0.5741 / task_loss=0.0135 / domain_loss=0.5876 / alpha=1.00 / lr=0.000001
# Epoch[42/50] Step[21/41]: loss_total=2.0405 / domain_loss_target=0.7277 / domain_loss_source=0.7108 / task_loss=0.6020 / domain_loss=1.3128 / alpha=1.00 / lr=0.000001
# Epoch[42/50] Step[31/41]: loss_total=1.2495 / domain_loss_target=0.6332 / domain_loss_source=0.6101 / task_loss=0.0062 / domain_loss=0.6164 / alpha=1.00 / lr=0.000001
# Test / Val: Average loss: 0.1800, Accuracy: 182/419 (43.44%)
#
# last correct =182 | best correct = 196
# epoch = 43...in DANN execution function
# Epoch[43/50] Step[1/41]: loss_total=1.3024 / domain_loss_target=0.6491 / domain_loss_source=0.6071 / task_loss=0.0462 / domain_loss=0.6533 / alpha=1.00 / lr=0.000001
# Epoch[43/50] Step[11/41]: loss_total=1.2442 / domain_loss_target=0.6646 / domain_loss_source=0.5771 / task_loss=0.0025 / domain_loss=0.5796 / alpha=1.00 / lr=0.000001
# Epoch[43/50] Step[21/41]: loss_total=1.2267 / domain_loss_target=0.6541 / domain_loss_source=0.5664 / task_loss=0.0062 / domain_loss=0.5726 / alpha=1.00 / lr=0.000001
# Epoch[43/50] Step[31/41]: loss_total=1.5585 / domain_loss_target=0.7942 / domain_loss_source=0.5972 / task_loss=0.1671 / domain_loss=0.7643 / alpha=1.00 / lr=0.000001
# Test / Val: Average loss: 0.1917, Accuracy: 180/419 (42.96%)
#
# last correct =180 | best correct = 196
# epoch = 44...in DANN execution function
# Epoch[44/50] Step[1/41]: loss_total=1.4389 / domain_loss_target=0.7499 / domain_loss_source=0.6712 / task_loss=0.0179 / domain_loss=0.6890 / alpha=1.00 / lr=0.000001
# Epoch[44/50] Step[11/41]: loss_total=1.3253 / domain_loss_target=0.6790 / domain_loss_source=0.5761 / task_loss=0.0702 / domain_loss=0.6463 / alpha=1.00 / lr=0.000001
# Epoch[44/50] Step[21/41]: loss_total=1.2282 / domain_loss_target=0.6894 / domain_loss_source=0.5242 / task_loss=0.0146 / domain_loss=0.5388 / alpha=1.00 / lr=0.000001
# Epoch[44/50] Step[31/41]: loss_total=1.3604 / domain_loss_target=0.6731 / domain_loss_source=0.5861 / task_loss=0.1012 / domain_loss=0.6873 / alpha=1.00 / lr=0.000001
# Test / Val: Average loss: 0.1823, Accuracy: 180/419 (42.96%)
#
# last correct =180 | best correct = 196
# epoch = 45...in DANN execution function
# Epoch[45/50] Step[1/41]: loss_total=1.2806 / domain_loss_target=0.6770 / domain_loss_source=0.5923 / task_loss=0.0113 / domain_loss=0.6036 / alpha=1.00 / lr=0.000001
# Epoch[45/50] Step[11/41]: loss_total=1.4701 / domain_loss_target=0.8422 / domain_loss_source=0.6204 / task_loss=0.0075 / domain_loss=0.6279 / alpha=1.00 / lr=0.000001
# Epoch[45/50] Step[21/41]: loss_total=1.2559 / domain_loss_target=0.5978 / domain_loss_source=0.6535 / task_loss=0.0046 / domain_loss=0.6580 / alpha=1.00 / lr=0.000001
# Epoch[45/50] Step[31/41]: loss_total=1.3090 / domain_loss_target=0.7270 / domain_loss_source=0.5754 / task_loss=0.0066 / domain_loss=0.5820 / alpha=1.00 / lr=0.000001
# Test / Val: Average loss: 0.1848, Accuracy: 182/419 (43.44%)
#
# last correct =182 | best correct = 196
# epoch = 46...in DANN execution function
# Epoch[46/50] Step[1/41]: loss_total=1.2696 / domain_loss_target=0.5945 / domain_loss_source=0.6630 / task_loss=0.0121 / domain_loss=0.6751 / alpha=1.00 / lr=0.000001
# Epoch[46/50] Step[11/41]: loss_total=1.2620 / domain_loss_target=0.7142 / domain_loss_source=0.5464 / task_loss=0.0013 / domain_loss=0.5477 / alpha=1.00 / lr=0.000001
# Epoch[46/50] Step[21/41]: loss_total=1.4454 / domain_loss_target=0.7748 / domain_loss_source=0.5996 / task_loss=0.0711 / domain_loss=0.6706 / alpha=1.00 / lr=0.000001
# Epoch[46/50] Step[31/41]: loss_total=1.3147 / domain_loss_target=0.6747 / domain_loss_source=0.5946 / task_loss=0.0454 / domain_loss=0.6401 / alpha=1.00 / lr=0.000001
# Test / Val: Average loss: 0.1899, Accuracy: 179/419 (42.72%)
#
# last correct =179 | best correct = 196
# epoch = 47...in DANN execution function
# Epoch[47/50] Step[1/41]: loss_total=1.3127 / domain_loss_target=0.7401 / domain_loss_source=0.5284 / task_loss=0.0443 / domain_loss=0.5727 / alpha=1.00 / lr=0.000001
# Epoch[47/50] Step[11/41]: loss_total=1.3538 / domain_loss_target=0.6388 / domain_loss_source=0.6391 / task_loss=0.0758 / domain_loss=0.7150 / alpha=1.00 / lr=0.000001
# Epoch[47/50] Step[21/41]: loss_total=1.2870 / domain_loss_target=0.6819 / domain_loss_source=0.5995 / task_loss=0.0056 / domain_loss=0.6051 / alpha=1.00 / lr=0.000001
# Epoch[47/50] Step[31/41]: loss_total=1.2518 / domain_loss_target=0.5314 / domain_loss_source=0.7144 / task_loss=0.0060 / domain_loss=0.7204 / alpha=1.00 / lr=0.000001
# Test / Val: Average loss: 0.1891, Accuracy: 181/419 (43.20%)
#
# last correct =181 | best correct = 196
# epoch = 48...in DANN execution function
# Epoch[48/50] Step[1/41]: loss_total=1.7433 / domain_loss_target=0.6612 / domain_loss_source=0.6659 / task_loss=0.4162 / domain_loss=1.0821 / alpha=1.00 / lr=0.000001
# Epoch[48/50] Step[11/41]: loss_total=1.3540 / domain_loss_target=0.7318 / domain_loss_source=0.5752 / task_loss=0.0470 / domain_loss=0.6223 / alpha=1.00 / lr=0.000001
# Epoch[48/50] Step[21/41]: loss_total=1.4953 / domain_loss_target=0.7356 / domain_loss_source=0.5542 / task_loss=0.2056 / domain_loss=0.7598 / alpha=1.00 / lr=0.000001
# Epoch[48/50] Step[31/41]: loss_total=1.4445 / domain_loss_target=0.7064 / domain_loss_source=0.6759 / task_loss=0.0623 / domain_loss=0.7381 / alpha=1.00 / lr=0.000001
# Test / Val: Average loss: 0.1846, Accuracy: 179/419 (42.72%)
#
# last correct =179 | best correct = 196
# epoch = 49...in DANN execution function
# Epoch[49/50] Step[1/41]: loss_total=1.4989 / domain_loss_target=0.7970 / domain_loss_source=0.6448 / task_loss=0.0572 / domain_loss=0.7020 / alpha=1.00 / lr=0.000001
# Epoch[49/50] Step[11/41]: loss_total=1.3889 / domain_loss_target=0.6907 / domain_loss_source=0.6710 / task_loss=0.0272 / domain_loss=0.6982 / alpha=1.00 / lr=0.000001
# Epoch[49/50] Step[21/41]: loss_total=1.3824 / domain_loss_target=0.7195 / domain_loss_source=0.6483 / task_loss=0.0147 / domain_loss=0.6630 / alpha=1.00 / lr=0.000001
# Epoch[49/50] Step[31/41]: loss_total=1.4649 / domain_loss_target=0.7827 / domain_loss_source=0.6694 / task_loss=0.0128 / domain_loss=0.6823 / alpha=1.00 / lr=0.000001
# Test / Val: Average loss: 0.1865, Accuracy: 184/419 (43.91%)
#
# last correct =184 | best correct = 196
# epoch = 50...in DANN execution function
# Epoch[50/50] Step[1/41]: loss_total=1.3599 / domain_loss_target=0.7306 / domain_loss_source=0.6227 / task_loss=0.0066 / domain_loss=0.6293 / alpha=1.00 / lr=0.000001
# Epoch[50/50] Step[11/41]: loss_total=1.2067 / domain_loss_target=0.6240 / domain_loss_source=0.5590 / task_loss=0.0237 / domain_loss=0.5827 / alpha=1.00 / lr=0.000001
# Epoch[50/50] Step[21/41]: loss_total=1.4309 / domain_loss_target=0.6128 / domain_loss_source=0.6860 / task_loss=0.1321 / domain_loss=0.8181 / alpha=1.00 / lr=0.000001
# Epoch[50/50] Step[31/41]: loss_total=1.4199 / domain_loss_target=0.6643 / domain_loss_source=0.6659 / task_loss=0.0896 / domain_loss=0.7556 / alpha=1.00 / lr=0.000001
# Test / Val: Average loss: 0.1813, Accuracy: 183/419 (43.68%)
#
# last correct =183 | best correct = 196
# Best model loaded
# Test / Val: Average loss: 0.1560, Accuracy: 196/419 (46.78%)
#
# Test / Val: Average loss: 0.6086, Accuracy: 5/34 (14.71%)
#
# alpha list
#  [0.0, 0.0024390195537999926, 0.004878010089213847, 0.007316942589236097, 0.009755788039622848, 0.012194517430273333, 0.01463310175660859, 0.017071512020952362, 0.01950971923390843, 0.021947694415740848, 0.024385408597748626, 0.026822832823643727, 0.02925993815092398, 0.03169669565224753, 0.034133076416805075, 0.036569051551688325, 0.03900459218325936, 0.04143966945851729, 0.04387425454646143, 0.04630831863945506, 0.048741832954582565, 0.05117476873500948, 0.05360709725133517, 0.0560387898029453, 0.05846981771936077, 0.060900152361583304, 0.06332976512343902, 0.06575862743291672, 0.06818671075350435, 0.07061398658552243, 0.0730404264674509, 0.0754660019772555, 0.07789068473370886, 0.08031444639770635, 0.08273725867357906, 0.08515909331040339, 0.08757992210330268, 0.08999971689474906, 0.09241844957585577, 0.0948360920876683, 0.0996679946249559, 0.10208219879371794, 0.10449520108230437, 0.10690697370058766, 0.10931748891600157, 0.11172671905479481, 0.11413463650327582, 0.11654121370905557, 0.11894642318227966, 0.12135023749685914, 0.12375262929169173, 0.1261535712718771, 0.1285530362099272, 0.13095099694696843, 0.13334742639393804, 0.1357422975327729, 0.1381355834175917, 0.1405272571758709, 0.14291729200961223, 0.14530566119650334, 0.14769233809107174, 0.15007729612583098, 0.15246050881241868, 0.15484194974272758, 0.15722159259002866, 0.1595994111100869, 0.16197537914226734, 0.16434947061063587, 0.16672165952504958, 0.16909191998223982, 0.1714602261668874, 0.17382655235268762, 0.17619087290340985, 0.17855316227394558, 0.18091339501134884, 0.18327154575586935, 0.18562758924197387, 0.18798150029936256, 0.19033325385397148, 0.19268282492897115, 0.19737532022490423, 0.19971819498718246, 0.20205878835447, 0.20439707585072475, 0.20673303310292113, 0.20906663584198082, 0.21139785990369409, 0.2137266812296299, 0.21605307586804057, 0.2183770199747499, 0.22069848981403872, 0.22301746175951465, 0.22533391229497646, 0.22764781801526368, 0.229959155627101, 0.2322679019499292, 0.2345740339167266, 0.23687752857482147, 0.23917836308669216, 0.24147651473075937, 0.2437719609021658, 0.2460646791135459, 0.24835464699578735, 0.2506418422987773, 0.2529262428921437, 0.2552078267659825, 0.25748657203157443, 0.25976245692209265, 0.26203545979329834, 0.26430555912422626, 0.2665727335178598, 0.26883696170179494, 0.27109822252889204, 0.27335649497792036, 0.2756117581541879, 0.2778639912901628, 0.28011317374608224, 0.2823592850105532, 0.2846023047011379, 0.2868422125649326, 0.2913126124515908, 0.2935430646213546, 0.2957703252592059, 0.297994374768181, 0.3002151936840811, 0.30243276267597374, 0.3046470625466806, 0.30685807423325695, 0.30906577880745867, 0.3112701574761976, 0.31347119158198833, 0.31566886260338034, 0.31786315215538274, 0.3200540419898765, 0.3222415139960153, 0.3244255502006148, 0.32660613276853456, 0.3287832440030434, 0.33095686634617905, 0.3331269823790943, 0.3352935748223911, 0.3374566265364476, 0.33961612052173007, 0.3417720399190973, 0.3439243680100921, 0.3460730882172218, 0.34821818410423155, 0.35035963937636105, 0.3524974378805956, 0.3546315636059041, 0.3567620006834664, 0.3588887333868902, 0.36101174613241915, 0.3631310234791263, 0.3652465501291011, 0.36735831092762417, 0.3694662908633304, 0.3715704750683646, 0.3736708488185232, 0.37576739753338884, 0.379948962255225, 0.38203394982134187, 0.38411505547065294, 0.3861922653433052, 0.388265565723815, 0.39033494304112826, 0.39240038386867404, 0.3944618749244053, 0.39651940307083056, 0.3985729553150359, 0.40062251880869826, 0.4026680808480858, 0.40470962887405193, 0.40674715047201726, 0.40878063337194503, 0.410810065448302, 0.4128354347200147, 0.4148567293504144, 0.41687393764717084, 0.41888704806222066, 0.42089604919168266, 0.4229009297757662, 0.4249016786986701, 0.4268982849884708, 0.4288907378170044, 0.4308790264997373, 0.4328631404956287, 0.4348430694069849, 0.4368188029793043, 0.43879033110111365, 0.44075764380379523, 0.44272073126140654, 0.44467958379049155, 0.44663419184988173, 0.448 ...

# %%
# dict_dann_losses

# %% [markdown]
# ### DANN Plotting and Validation

# %%
plot_loss_curves(dict_dann_losses,mode='train_losses')
plot_loss_curves(dict_dann_losses,mode='val_losses')
plot_loss_curves(dict_dann_losses,mode='lr')
# plot_loss_curves(dict_dann_losses,mode='list_alpha')

# %% [markdown]
# ### Saving DANN Model

# %%
model_dann
# Out:
# DANN(
#   (feature_extractor): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Linear(in_features=512, out_features=1000, bias=True)
#   )
#   (class_classifier): Sequential(
#     (0): ReLU()
#     (1): Dropout(p=0.1, inplace=False)
#     (2): Linear(in_features=1000, out_features=100, bias=True)
#     (3): ReLU()
#     (4): Dropout(p=0.1, inplace=False)
#     (5): Linear(in_features=100, out_features=7, bias=True)
#   )
#   (domain_classifier): Sequential(
#     (0): ReLU()
#     (1): Dropout(p=0.1, inplace=False)
#     (2): Linear(in_features=1000, out_features=100, bias=True)
#     (3): ReLU()
#     (4): Dropout(p=0.1, inplace=False)
#     (5): Linear(in_features=100, out_features=2, bias=True)
#   )
# )

# %%
dataconfig_1 = DataConfig()
MODEL_DIR = dataconfig_1.MODEL_DIR
MODEL_DIR
# Out:
# PosixPath('/content/gdrive/MyDrive/CV_FER/models')

# %%
dann_model_name = f'dann_{source_name}_{target_name}_{str(time.strftime("%d_%m"))}.pt' # "dann_sfew_expw_" + str(time.strftime("%d_%m")) + ".pt"
print(dann_model_name)

# from data_config import DataConfig
dataconfig_1 = DataConfig()
MODEL_DIR = dataconfig_1.MODEL_DIR

DANN_MODEL_DIR =  Path(os.path.join(MODEL_DIR, f'dann_{source_name}_{target_name}'))
# try:
#     DANN_SFEW_EXPW_DIR = Path(dataconfig_1.DANN_SFEW_EXPW_DIR)
# except:
#     DANN_SFEW_EXPW_DIR =Path(dataconfig_1.MODEL_DIR,"dann_sfew_expw")


if not DANN_MODEL_DIR.exists():
    # Create the directory
    DANN_MODEL_DIR.mkdir(parents=True, exist_ok=True)
    print(f'Directory {DANN_MODEL_DIR} created successfully.')
else:
    print(f'Directory {DANN_MODEL_DIR} already exists.')


try:
    torch.save(model_dann.state_dict(), Path(DANN_MODEL_DIR,dann_model_name))
    print(f'{dann_model_name} SAVED at {Path(DANN_MODEL_DIR,dann_model_name)}!')
except:
    print(f'Problem in saving {dann_model_name}, NOT SAVED!')
# Out:
# dann_sfew_expw_04_02.pt
# Directory /content/gdrive/MyDrive/CV_FER/models/dann_sfew_expw already exists.
# dann_sfew_expw_04_02.pt SAVED at /content/gdrive/MyDrive/CV_FER/models/dann_sfew_expw/dann_sfew_expw_04_02.pt!

# %% [markdown]
# ## DANN EWC : Training, Validating, Saving

# %%
# dataconfig_inference = DataConfig()

# # NON DANN
# non_dann_model_sfew_name = 'non_dann_sfew_20_01.pt'
# non_dann_model_inference = DANN(num_classes=7) # skeleton copy
# NON_DANN_SFEW_DIR = dataconfig_inference.NON_DANN_SFEW_DIR # Path(self.MODEL_DIR,"non_dann_sfew")

# try:
#     non_dann_model.load_state_dict(torch.load(Path(NON_DANN_SFEW_DIR, non_dann_model_sfew_name),
#                                                         map_location=torch.device(device)))
#     print(f'{non_dann_model_sfew_name} locked and loaded')
# except:
#     print(f' problem in loading {non_dann_model_sfew_name}')

# %%
# model_dann_ewc = non_dann_model # saves training time - check with all

# %%
model_dann_ewc
# Out:
# DANN(
#   (feature_extractor): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Linear(in_features=512, out_features=1000, bias=True)
#   )
#   (class_classifier): Sequential(
#     (0): ReLU()
#     (1): Dropout(p=0.1, inplace=False)
#     (2): Linear(in_features=1000, out_features=100, bias=True)
#     (3): ReLU()
#     (4): Dropout(p=0.1, inplace=False)
#     (5): Linear(in_features=100, out_features=7, bias=True)
#   )
#   (domain_classifier): Sequential(
#     (0): ReLU()
#     (1): Dropout(p=0.1, inplace=False)
#     (2): Linear(in_features=1000, out_features=100, bias=True)
#     (3): ReLU()
#     (4): Dropout(p=0.1, inplace=False)
#     (5): Linear(in_features=100, out_features=2, bias=True)
#   )
# )

# %% [markdown]
# ### EWC Code
# Regularization Penalty

# %%
from torch.autograd import Variable
from torch.autograd import Function
from da_cv_fer.run_config import RunConfig

runconfig = RunConfig()
def variable(t: torch.Tensor, use_cuda=True, **kwargs):
    if torch.cuda.is_available() and use_cuda:
        t = t.cuda()
    return Variable(t, **kwargs)

class EWC(object):
    def __init__(self, model: nn.Module,
                 data_loader: torch.utils.data.DataLoader
                #  dataset: list
                 ,device=device
                 , class_loss_function = runconfig.criterion_class):

        self.model = model
        # print("----------MODEL--------\n",self.model)
        self.dataset = data_loader
        self.device = device
        self.class_loss_function = class_loss_function

        # creating dictionary of params which required grad
        self.params = {n: p for n, p in self.model.named_parameters() if p.requires_grad}

        self._means = {}
        for n, p in deepcopy(self.params).items():
            self._means[n] = variable(p.data)

        # print("--------self._means----------------\n", self._means)

        self._precision_matrices = self._diag_fisher()

    def _diag_fisher(self):
        precision_matrices = {}
        for n, p in deepcopy(self.params).items():
            p.data.zero_()
            precision_matrices[n] = variable(p.data)
        # print("--------PRECISION MATRICES----------------\n", precision_matrices)

        self.model.eval()
        for batch in self.dataset:
            self.model.zero_grad()
            images, labels  = variable(batch[0].to(device)), variable(batch[1].to(device))
            class_ouputs, _ , _ = model(images) # class_output, domain_output, features
            task_loss =  self.class_loss_function(class_ouputs,labels)
            task_loss.backward() # only calculating the gradients, not updating it
            # print("--------task loss----------------\n", task_loss)

            for n, p in self.model.named_parameters():
              # if type(p.grad)
              if isinstance(p.grad, type(None)):
                pass # parameter value would remain as it is
              else:
                # print(n,":", type(p.grad))
                precision_matrices[n].data += p.grad.data ** 2 / len(self.dataset)

        precision_matrices = {n: p for n, p in precision_matrices.items()}
        return precision_matrices

    def penalty(self, model: nn.Module):
        loss = 0
        for n, p in model.named_parameters():
            _loss = self._precision_matrices[n] * (p - self._means[n]) ** 2
            loss += _loss.sum()
        return loss

# %% [markdown]
# **DANN EWC Object.**

# %%
# ewc_object = EWC(deepcopy(model_dann_ewc),
#                  data_loader=data_loader['source']['train'],#sfew_train_loader,
#                  device=device,
#                  class_loss_function=runconfig.criterion_class)

# %% [markdown]
# ### DANN EWC Execution (training and testing) Function without Learning rate
# Training Function

# %%
def execute_dann_ewc(model,
                     device,
                     source_train_loader, source_val_loader,
                     target_train_loader, target_val_loader,
                     optimizer,
                     n_epochs, # total number of epochs (different from individual epoch)
                     class_loss_function = nn.CrossEntropyLoss(),
                     domain_loss_function = nn.BCEWithLogitsLoss(),
                     EWC_LAMBDA = 0.4, # to understand regularlization
                     scheduler = None,
                     early_stop_patience = None,
                     early_stop_difference = None
                     ):

    train_losses = [] # to capture train losses over training epochs
    val_losses = [] # to capture validation loss over epochs
    list_lr = [] # to capture lr changes across epochs
    epoch_converge = 0
    max_batches = min(len(source_train_loader), len(target_train_loader)) # Trying to check which is having less batches.
    existing_model = deepcopy(model)
    model = deepcopy(model).to(device) # copies params from existing model to another one https://discuss.pytorch.org/t/copying-weights-from-one-net-to-another/1492/2
    # model.apply(weights_init) # TODO: skipping weights update - we can experimentation later on, and see if this helps
    list_alpha =[]
    #TODO: Scheduler
    # scheduler = ReduceLROnPlateau(optimizer, factor = 0.1, patience = 5, threshold =  0.0005, verbose = True)

    ewc_object = EWC(deepcopy(model),
                     data_loader=source_train_loader,
                     device=device,
                     class_loss_function=class_loss_function) # instantiating EWC object, we would use this object for understanding penalty


    # for best model
    best_model = deepcopy(model).to(device) # for best model
    best_val_loss = float('inf') # Initialize variables to track the best validation loss
    best_model_state = None # Initialize variables to track the best model state
    best_val_acc = 0 # Initialize variables to track the best accuracy


    for epoch_idx in range(n_epochs):
        print(f'epoch = {epoch_idx+1}...in EWC DANN execution function')
        source_iterator = iter(source_train_loader)
        target_iterator = iter(target_train_loader)
        epoch_task_loss = 0
        epoch_domain_loss =  0
        epoch_total_loss = 0
        processed = 0

        for batch_idx in range(max_batches-1):
            p = float(batch_idx + epoch_idx * max_batches) / (n_epochs * max_batches)
            alpha = 2. / (1. + np.exp(-10 * p)) - 1
            list_alpha.append(alpha)
            alpha = torch.tensor(alpha)

            model.train() # everytime ?
            optimizer.zero_grad() # flushing out the accumulated gradients

            #---------------------Source Dataset Training ------------------------#
            source_batch = next(source_iterator)
            source_images, source_labels = source_batch[0].to(device), source_batch[1].to(device) # getting images and labels, on device
            source_class_outputs, source_domain_outputs, _ = model(source_images, alpha=alpha) # forward pass, output = {class, domain, feature}

            # Calculating source class loss, regularlized by EWC
            loss_source_class = class_loss_function(source_class_outputs, source_labels) + EWC_LAMBDA * ewc_object.penalty(model)# calculating class loss

            source_domain_inputs = torch.tensor([1., 0.]*len(source_batch[0])).view(-1,2).to(device) # Source Image == [1., 0.]

            loss_source_domain = domain_loss_function(source_domain_outputs, source_domain_inputs) # calculating domain loss

            processed += len(source_batch[0])

            #---------------------Target Dataset Training ------------------------#
            target_batch = next (target_iterator)
            target_images = target_batch[0].to(device) # getting images, on device. There are no labels for target
            _, target_domain_outputs, _ = model(target_images, alpha=alpha) # forward pass, output = {class, domain, feature}

            target_domain_inputs = torch.tensor([0., 1.]*len(source_batch[0])).view(-1,2).to(device) # Target Image == [0., 1.]

            loss_target_domain = domain_loss_function(target_domain_outputs,target_domain_inputs)  # calculating domain loss


            #---------------------Combining Loss ------------------------#
            total_loss = loss_source_class + loss_source_domain + loss_target_domain
            total_loss.backward() #backpropogation, creating gradients
            optimizer.step() # updating the params

            epoch_task_loss += loss_source_class.item()
            epoch_domain_loss += loss_source_domain.item() + loss_target_domain.item()
            epoch_total_loss += total_loss.item()

            curr_lr = optimizer.param_groups[0]['lr'] # current learning rate
            list_lr.append(curr_lr)


            # after 10 batches
            if (batch_idx % 50 == 0):
                print("Epoch [{}/{}] Step [{}/{}]: loss_total={:.4f} / domain_loss_target={:.4f} / domain_loss_source={:.4f} / task_loss={:.4f} / domain_loss={:.4f} / alpha={:.4f} / lr={:.6f}"
              .format(epoch_idx + 1,
                      n_epochs,
                      batch_idx + 1,
                      max_batches,
                      total_loss.item(),
                      loss_target_domain.item()
                      ,loss_source_domain.item()
                      ,loss_source_class.item()
                      ,loss_source_domain.item()+loss_source_class.item(),
                      alpha,
                      curr_lr
                      ))
        # After every epoch
        avg_train_task_loss =  float("{:.6f}".format(epoch_task_loss/processed))
        train_losses.append(avg_train_task_loss)

        #Scheduler
        if scheduler:
          scheduler.step(avg_train_task_loss) ## applying scheduler on training loss

        #Validate Model after every epoch
        correct, avg_val_task_loss = test_model(model= model,
                                                device= device,
                                                data_loader = source_val_loader,
                                                class_loss_function = class_loss_function)
        val_losses.append(avg_val_task_loss)

        # # Check if the current model has the best validation loss
        # print(f'Last Epoch Val Loss = {avg_val_task_loss} | Best Val Loss = {best_val_loss}' )
        # if avg_val_task_loss < best_val_loss:
        #   best_val_loss = avg_val_task_loss
        #   # save the current model state as the best model state
        #   best_model_state = deepcopy(model.state_dict())
        #   print(f'Updated the best model with validation loss: {best_val_loss}\n')

        # check if the current model has the best accuracy
        print (f'last correct ={correct} | best correct = {best_val_acc}')
        if correct > best_val_acc:
          best_val_acc = correct
          # save the current model state as the best model state
          best_model_state = deepcopy(non_dann_model.state_dict())
          print(f'Updated the best model with correct: {correct}\n')

        #TODO: Early Stopping
        if early_stop_patience and early_stop_difference: # early stopping required
          if early_stopping_difference(val_losses,
                                       patience = early_stop_patience,
                                       difference= early_stop_difference):
            print (f'-------Early Stopping at epoch {epoch+1}---')
            epoch_converge = epoch+1
            break # break from epoch loop

    # Testing when the training is over - completed or early stopped

    ## using params of best model to update model
    if best_model_state: # only update if best model has been saved, else the last one would be picked up
      model.load_state_dict(best_model_state)
      print('Best model loaded')

    correct_source, test_loss_source = test_model(model= model,
                            device= device,
                            data_loader = source_val_loader, # source val loader
                            class_loss_function = class_loss_function)

    accuracy_source = correct_source / len(source_val_loader.dataset)

    correct_target, test_loss_target = test_model(model= model,
                            device= device,
                            data_loader = target_val_loader, # target val loader
                            class_loss_function = class_loss_function)

    accuracy_target = correct_target / len(target_val_loader.dataset)


    dict_ewc_dann_losses = {'train_losses' : train_losses,
                        'val_losses': val_losses,
                        'test_loss_source' : test_loss_source,
                        'test_loss_target' : test_loss_target,
                        'epoch_convergence' : epoch_converge,
                        'list_alpha' : list_alpha,
                        'test_accuracy_source' : accuracy_source,
                        'test_accuracy_target':accuracy_target,
                            'lr':list_lr}

    print(f'alpha list \n {list_alpha}')
    return model, dict_ewc_dann_losses

# %% [markdown]
# ### DANN EWC Execute

# %%
runconfig = RunConfig()
lr_ewc_dann = runconfig.inital_lr/5.0 #override
optimizer_ewc_dann = optim.SGD(model_dann.parameters(), lr = lr_ewc_dann, momentum = 0.9)
n_epochs = runconfig.EPOCHS
# n_epochs = 5 # override

# ReduceLRonPlateau Scheduler Params
scheduler_patience = runconfig.scheduler_patience
scheduler_factor = runconfig.scheduler_factor
scheduler_threshold = runconfig.scheduler_threshold

# Early stopping params
early_stop_patience = runconfig.early_stop_patience
early_stop_difference = runconfig.early_stop_difference

# Set up the ReduceLROnPlateau scheduler
scheduler = ReduceLROnPlateau(optimizer_ewc_dann,
                              mode='min',
                              factor=scheduler_factor,
                              patience=scheduler_patience,
                              threshold = scheduler_threshold,
                              min_lr=1e-6,
                              verbose= True)

try:
    EWC_LAMBDA = runconfig.EWC_LAMBDA
except:
    EWC_LAMBDA = 0.4

print(EWC_LAMBDA)

print(f'------------training started for EWC DANN Model ------------------')

ewc_dann_model , dict_ewc_dann_losses = execute_dann_ewc(model=model_dann,
                                                          device=device,
                                                          source_train_loader = data_loader['source']['train'], #sfew_train_loader,
                                                          source_val_loader = data_loader['source']['val'], #sfew_val_loader,
                                                          target_train_loader = data_loader['target']['train'], #expw_train_loader,
                                                          target_val_loader = data_loader['target']['val'], #expw_val_loader,
                                                          optimizer = optimizer_ewc_dann,
                                                          n_epochs = n_epochs,
                                                          class_loss_function = runconfig.criterion_class,
                                                          domain_loss_function = runconfig.criterion_domain,
                                                          EWC_LAMBDA=EWC_LAMBDA, # Hyperparameter about penalty relevance
                                                          scheduler = None,
                                                          early_stop_patience = None,
                                                          early_stop_difference = None)
# Out:
# 0.4
# ------------training started for EWC DANN Model ------------------
# epoch = 1...in EWC DANN execution function
# Epoch [1/50] Step [1/41]: loss_total=1.4475 / domain_loss_target=0.6911 / domain_loss_source=0.7430 / task_loss=0.0134 / domain_loss=0.7564 / alpha=0.0000 / lr=0.001000
# Test / Val: Average loss: 0.1674, Accuracy: 192/419 (45.82%)
#
# last correct =192 | best correct = 0
# Updated the best model with correct: 192
#
# epoch = 2...in EWC DANN execution function
# Epoch [2/50] Step [1/41]: loss_total=1.6561 / domain_loss_target=0.6904 / domain_loss_source=0.7193 / task_loss=0.2464 / domain_loss=0.9657 / alpha=0.0997 / lr=0.001000
# Test / Val: Average loss: 0.1643, Accuracy: 190/419 (45.35%)
#
# last correct =190 | best correct = 192
# epoch = 3...in EWC DANN execution function
# Epoch [3/50] Step [1/41]: loss_total=1.4208 / domain_loss_target=0.6805 / domain_loss_source=0.7101 / task_loss=0.0302 / domain_loss=0.7403 / alpha=0.1974 / lr=0.001000
# Test / Val: Average loss: 0.1589, Accuracy: 191/419 (45.58%)
#
# last correct =191 | best correct = 192
# epoch = 4...in EWC DANN execution function
# Epoch [4/50] Step [1/41]: loss_total=1.4279 / domain_loss_target=0.6829 / domain_loss_source=0.7096 / task_loss=0.0354 / domain_loss=0.7450 / alpha=0.2913 / lr=0.001000
# Test / Val: Average loss: 0.1623, Accuracy: 195/419 (46.54%)
#
# last correct =195 | best correct = 192
# Updated the best model with correct: 195
#
# epoch = 5...in EWC DANN execution function
# Epoch [5/50] Step [1/41]: loss_total=1.4285 / domain_loss_target=0.6859 / domain_loss_source=0.7277 / task_loss=0.0149 / domain_loss=0.7426 / alpha=0.3799 / lr=0.001000
# Test / Val: Average loss: 0.1645, Accuracy: 195/419 (46.54%)
#
# last correct =195 | best correct = 195
# epoch = 6...in EWC DANN execution function
# Epoch [6/50] Step [1/41]: loss_total=1.4310 / domain_loss_target=0.6839 / domain_loss_source=0.7079 / task_loss=0.0392 / domain_loss=0.7471 / alpha=0.4621 / lr=0.001000
# Test / Val: Average loss: 0.1635, Accuracy: 194/419 (46.30%)
#
# last correct =194 | best correct = 195
# epoch = 7...in EWC DANN execution function
# Epoch [7/50] Step [1/41]: loss_total=1.3907 / domain_loss_target=0.6837 / domain_loss_source=0.6967 / task_loss=0.0103 / domain_loss=0.7070 / alpha=0.5370 / lr=0.001000
# Test / Val: Average loss: 0.1642, Accuracy: 192/419 (45.82%)
#
# last correct =192 | best correct = 195
# epoch = 8...in EWC DANN execution function
# Epoch [8/50] Step [1/41]: loss_total=1.4416 / domain_loss_target=0.7053 / domain_loss_source=0.7197 / task_loss=0.0166 / domain_loss=0.7363 / alpha=0.6044 / lr=0.001000
# Test / Val: Average loss: 0.1614, Accuracy: 192/419 (45.82%)
#
# last correct =192 | best correct = 195
# epoch = 9...in EWC DANN execution function
# Epoch [9/50] Step [1/41]: loss_total=1.4560 / domain_loss_target=0.6954 / domain_loss_source=0.7168 / task_loss=0.0438 / domain_loss=0.7607 / alpha=0.6640 / lr=0.001000
# Test / Val: Average loss: 0.1586, Accuracy: 194/419 (46.30%)
#
# last correct =194 | best correct = 195
# epoch = 10...in EWC DANN execution function
# Epoch [10/50] Step [1/41]: loss_total=1.5194 / domain_loss_target=0.7014 / domain_loss_source=0.7246 / task_loss=0.0934 / domain_loss=0.8180 / alpha=0.7163 / lr=0.001000
# Test / Val: Average loss: 0.1590, Accuracy: 190/419 (45.35%)
#
# last correct =190 | best correct = 195
# epoch = 11...in EWC DANN execution function
# Epoch [11/50] Step [1/41]: loss_total=1.6794 / domain_loss_target=0.6848 / domain_loss_source=0.7288 / task_loss=0.2658 / domain_loss=0.9946 / alpha=0.7616 / lr=0.001000
# Test / Val: Average loss: 0.1717, Accuracy: 191/419 (45.58%)
#
# last correct =191 | best correct = 195
# epoch = 12...in EWC DANN execution function
# Epoch [12/50] Step [1/41]: loss_total=1.8950 / domain_loss_target=0.6774 / domain_loss_source=0.7124 / task_loss=0.5052 / domain_loss=1.2175 / alpha=0.8005 / lr=0.001000
# Test / Val: Average loss: 0.1638, Accuracy: 195/419 (46.54%)
#
# last correct =195 | best correct = 195
# epoch = 13...in EWC DANN execution function
# Epoch [13/50] Step [1/41]: loss_total=1.4456 / domain_loss_target=0.6850 / domain_loss_source=0.7049 / task_loss=0.0557 / domain_loss=0.7606 / alpha=0.8337 / lr=0.001000
# Test / Val: Average loss: 0.1650, Accuracy: 191/419 (45.58%)
#
# last correct =191 | best correct = 195
# epoch = 14...in EWC DANN execution function
# Epoch [14/50] Step [1/41]: loss_total=1.7573 / domain_loss_target=0.6842 / domain_loss_source=0.7053 / task_loss=0.3678 / domain_loss=1.0731 / alpha=0.8617 / lr=0.001000
# Test / Val: Average loss: 0.1638, Accuracy: 195/419 (46.54%)
#
# last correct =195 | best correct = 195
# epoch = 15...in EWC DANN execution function
# Epoch [15/50] Step [1/41]: loss_total=1.4180 / domain_loss_target=0.6827 / domain_loss_source=0.7286 / task_loss=0.0067 / domain_loss=0.7353 / alpha=0.8854 / lr=0.001000
# Test / Val: Average loss: 0.1616, Accuracy: 196/419 (46.78%)
#
# last correct =196 | best correct = 195
# Updated the best model with correct: 196
#
# epoch = 16...in EWC DANN execution function
# Epoch [16/50] Step [1/41]: loss_total=1.5435 / domain_loss_target=0.6844 / domain_loss_source=0.7159 / task_loss=0.1432 / domain_loss=0.8591 / alpha=0.9051 / lr=0.001000
# Test / Val: Average loss: 0.1615, Accuracy: 194/419 (46.30%)
#
# last correct =194 | best correct = 196
# epoch = 17...in EWC DANN execution function
# Epoch [17/50] Step [1/41]: loss_total=1.6019 / domain_loss_target=0.6753 / domain_loss_source=0.7078 / task_loss=0.2187 / domain_loss=0.9266 / alpha=0.9217 / lr=0.001000
# Test / Val: Average loss: 0.1635, Accuracy: 193/419 (46.06%)
#
# last correct =193 | best correct = 196
# epoch = 18...in EWC DANN execution function
# Epoch [18/50] Step [1/41]: loss_total=1.4445 / domain_loss_target=0.6946 / domain_loss_source=0.6915 / task_loss=0.0584 / domain_loss=0.7499 / alpha=0.9354 / lr=0.001000
# Test / Val: Average loss: 0.1609, Accuracy: 194/419 (46.30%)
#
# last correct =194 | best correct = 196
# epoch = 19...in EWC DANN execution function
# Epoch [19/50] Step [1/41]: loss_total=1.4505 / domain_loss_target=0.6800 / domain_loss_source=0.7114 / task_loss=0.0590 / domain_loss=0.7704 / alpha=0.9468 / lr=0.001000
# Test / Val: Average loss: 0.1671, Accuracy: 193/419 (46.06%)
#
# last correct =193 | best correct = 196
# epoch = 20...in EWC DANN execution function
# Epoch [20/50] Step [1/41]: loss_total=1.4208 / domain_loss_target=0.6980 / domain_loss_source=0.7031 / task_loss=0.0197 / domain_loss=0.7228 / alpha=0.9562 / lr=0.001000
# Test / Val: Average loss: 0.1624, Accuracy: 192/419 (45.82%)
#
# last correct =192 | best correct = 196
# epoch = 21...in EWC DANN execution function
# Epoch [21/50] Step [1/41]: loss_total=1.4998 / domain_loss_target=0.6704 / domain_loss_source=0.7033 / task_loss=0.1261 / domain_loss=0.8294 / alpha=0.9640 / lr=0.001000
# Test / Val: Average loss: 0.1605, Accuracy: 194/419 (46.30%)
#
# last correct =194 | best correct = 196
# epoch = 22...in EWC DANN execution function
# Epoch [22/50] Step [1/41]: loss_total=1.4197 / domain_loss_target=0.6898 / domain_loss_source=0.7217 / task_loss=0.0082 / domain_loss=0.7299 / alpha=0.9705 / lr=0.001000
# Test / Val: Average loss: 0.1620, Accuracy: 191/419 (45.58%)
#
# last correct =191 | best correct = 196
# epoch = 23...in EWC DANN execution function
# Epoch [23/50] Step [1/41]: loss_total=1.4222 / domain_loss_target=0.6832 / domain_loss_source=0.7131 / task_loss=0.0259 / domain_loss=0.7390 / alpha=0.9757 / lr=0.001000
# Test / Val: Average loss: 0.1646, Accuracy: 193/419 (46.06%)
#
# last correct =193 | best correct = 196
# epoch = 24...in EWC DANN execution function
# Epoch [24/50] Step [1/41]: loss_total=1.4784 / domain_loss_target=0.7012 / domain_loss_source=0.7214 / task_loss=0.0558 / domain_loss=0.7772 / alpha=0.9801 / lr=0.001000
# Test / Val: Average loss: 0.1579, Accuracy: 195/419 (46.54%)
#
# last correct =195 | best correct = 196
# epoch = 25...in EWC DANN execution function
# Epoch [25/50] Step [1/41]: loss_total=1.3995 / domain_loss_target=0.6769 / domain_loss_source=0.7198 / task_loss=0.0028 / domain_loss=0.7226 / alpha=0.9837 / lr=0.001000
# Test / Val: Average loss: 0.1620, Accuracy: 194/419 (46.30%)
#
# last correct =194 | best correct = 196
# epoch = 26...in EWC DANN execution function
# Epoch [26/50] Step [1/41]: loss_total=1.5543 / domain_loss_target=0.7151 / domain_loss_source=0.6961 / task_loss=0.1431 / domain_loss=0.8392 / alpha=0.9866 / lr=0.001000
# Test / Val: Average loss: 0.1595, Accuracy: 192/419 (45.82%)
#
# last correct =192 | best correct = 196
# epoch = 27...in EWC DANN execution function
# Epoch [27/50] Step [1/41]: loss_total=1.4040 / domain_loss_target=0.6785 / domain_loss_source=0.6977 / task_loss=0.0278 / domain_loss=0.7255 / alpha=0.9890 / lr=0.001000
# Test / Val: Average loss: 0.1634, Accuracy: 194/419 (46.30%)
#
# last correct =194 | best correct = 196
# epoch = 28...in EWC DANN execution function
# Epoch [28/50] Step [1/41]: loss_total=1.5802 / domain_loss_target=0.6712 / domain_loss_source=0.7061 / task_loss=0.2029 / domain_loss=0.9090 / alpha=0.9910 / lr=0.001000
# Test / Val: Average loss: 0.1604, Accuracy: 192/419 (45.82%)
#
# last correct =192 | best correct = 196
# epoch = 29...in EWC DANN execution function
# Epoch [29/50] Step [1/41]: loss_total=1.6474 / domain_loss_target=0.6828 / domain_loss_source=0.7167 / task_loss=0.2479 / domain_loss=0.9646 / alpha=0.9926 / lr=0.001000
# Test / Val: Average loss: 0.1661, Accuracy: 194/419 (46.30%)
#
# last correct =194 | best correct = 196
# epoch = 30...in EWC DANN execution function
# Epoch [30/50] Step [1/41]: loss_total=1.5174 / domain_loss_target=0.6901 / domain_loss_source=0.7130 / task_loss=0.1143 / domain_loss=0.8273 / alpha=0.9940 / lr=0.001000
# Test / Val: Average loss: 0.1621, Accuracy: 193/419 (46.06%)
#
# last correct =193 | best correct = 196
# epoch = 31...in EWC DANN execution function
# Epoch [31/50] Step [1/41]: loss_total=1.4067 / domain_loss_target=0.6770 / domain_loss_source=0.7150 / task_loss=0.0147 / domain_loss=0.7298 / alpha=0.9951 / lr=0.001000
# Test / Val: Average loss: 0.1665, Accuracy: 190/419 (45.35%)
#
# last correct =190 | best correct = 196
# epoch = 32...in EWC DANN execution function
# Epoch [32/50] Step [1/41]: loss_total=1.5336 / domain_loss_target=0.6769 / domain_loss_source=0.7153 / task_loss=0.1414 / domain_loss=0.8567 / alpha=0.9959 / lr=0.001000
# Test / Val: Average loss: 0.1603, Accuracy: 193/419 (46.06%)
#
# last correct =193 | best correct = 196
# epoch = 33...in EWC DANN execution function
# Epoch [33/50] Step [1/41]: loss_total=1.4542 / domain_loss_target=0.6897 / domain_loss_source=0.7104 / task_loss=0.0540 / domain_loss=0.7645 / alpha=0.9967 / lr=0.001000
# Test / Val: Average loss: 0.1600, Accuracy: 193/419 (46.06%)
#
# last correct =193 | best correct = 196
# epoch = 34...in EWC DANN execution function
# Epoch [34/50] Step [1/41]: loss_total=1.4082 / domain_loss_target=0.6841 / domain_loss_source=0.7096 / task_loss=0.0146 / domain_loss=0.7241 / alpha=0.9973 / lr=0.001000
# Test / Val: Average loss: 0.1673, Accuracy: 191/419 (45.58%)
#
# last correct =191 | best correct = 196
# epoch = 35...in EWC DANN execution function
# Epoch [35/50] Step [1/41]: loss_total=1.4946 / domain_loss_target=0.6704 / domain_loss_source=0.7022 / task_loss=0.1220 / domain_loss=0.8242 / alpha=0.9978 / lr=0.001000
# Test / Val: Average loss: 0.1665, Accuracy: 194/419 (46.30%)
#
# last correct =194 | best correct = 196
# epoch = 36...in EWC DANN execution function
# Epoch [36/50] Step [1/41]: loss_total=1.5045 / domain_loss_target=0.6776 / domain_loss_source=0.7247 / task_loss=0.1021 / domain_loss=0.8269 / alpha=0.9982 / lr=0.001000
# Test / Val: Average loss: 0.1651, Accuracy: 192/419 (45.82%)
#
# last correct =192 | best correct = 196
# epoch = 37...in EWC DANN execution function
# Epoch [37/50] Step [1/41]: loss_total=1.4273 / domain_loss_target=0.6879 / domain_loss_source=0.7216 / task_loss=0.0178 / domain_loss=0.7394 / alpha=0.9985 / lr=0.001000
# Test / Val: Average loss: 0.1641, Accuracy: 192/419 (45.82%)
#
# last correct =192 | best correct = 196
# epoch = 38...in EWC DANN execution function
# Epoch [38/50] Step [1/41]: loss_total=1.4285 / domain_loss_target=0.6820 / domain_loss_source=0.7101 / task_loss=0.0364 / domain_loss=0.7465 / alpha=0.9988 / lr=0.001000
# Test / Val: Average loss: 0.1573, Accuracy: 191/419 (45.58%)
#
# last correct =191 | best correct = 196
# epoch = 39...in EWC DANN execution function
# Epoch [39/50] Step [1/41]: loss_total=1.4193 / domain_loss_target=0.6939 / domain_loss_source=0.7146 / task_loss=0.0109 / domain_loss=0.7254 / alpha=0.9990 / lr=0.001000
# Test / Val: Average loss: 0.1627, Accuracy: 195/419 (46.54%)
#
# last correct =195 | best correct = 196
# epoch = 40...in EWC DANN execution function
# Epoch [40/50] Step [1/41]: loss_total=1.4300 / domain_loss_target=0.6873 / domain_loss_source=0.7194 / task_loss=0.0233 / domain_loss=0.7427 / alpha=0.9992 / lr=0.001000
# Test / Val: Average loss: 0.1614, Accuracy: 192/419 (45.82%)
#
# last correct =192 | best correct = 196
# epoch = 41...in EWC DANN execution function
# Epoch [41/50] Step [1/41]: loss_total=1.4263 / domain_loss_target=0.6848 / domain_loss_source=0.7395 / task_loss=0.0020 / domain_loss=0.7415 / alpha=0.9993 / lr=0.001000
# Test / Val: Average loss: 0.1586, Accuracy: 194/419 (46.30%)
#
# last correct =194 | best correct = 196
# epoch = 42...in EWC DANN execution function
# Epoch [42/50] Step [1/41]: loss_total=1.4006 / domain_loss_target=0.6817 / domain_loss_source=0.7187 / task_loss=0.0002 / domain_loss=0.7189 / alpha=0.9995 / lr=0.001000
# Test / Val: Average loss: 0.1608, Accuracy: 196/419 (46.78%)
#
# last correct =196 | best correct = 196
# epoch = 43...in EWC DANN execution function
# Epoch [43/50] Step [1/41]: loss_total=1.5616 / domain_loss_target=0.6863 / domain_loss_source=0.7137 / task_loss=0.1616 / domain_loss=0.8753 / alpha=0.9996 / lr=0.001000
# Test / Val: Average loss: 0.1663, Accuracy: 193/419 (46.06%)
#
# last correct =193 | best correct = 196
# epoch = 44...in EWC DANN execution function
# Epoch [44/50] Step [1/41]: loss_total=1.4292 / domain_loss_target=0.6936 / domain_loss_source=0.7343 / task_loss=0.0013 / domain_loss=0.7356 / alpha=0.9996 / lr=0.001000
# Test / Val: Average loss: 0.1627, Accuracy: 192/419 (45.82%)
#
# last correct =192 | best correct = 196
# epoch = 45...in EWC DANN execution function
# Epoch [45/50] Step [1/41]: loss_total=1.4357 / domain_loss_target=0.6854 / domain_loss_source=0.7313 / task_loss=0.0189 / domain_loss=0.7502 / alpha=0.9997 / lr=0.001000
# Test / Val: Average loss: 0.1609, Accuracy: 193/419 (46.06%)
#
# last correct =193 | best correct = 196
# epoch = 46...in EWC DANN execution function
# Epoch [46/50] Step [1/41]: loss_total=1.5078 / domain_loss_target=0.6940 / domain_loss_source=0.6944 / task_loss=0.1194 / domain_loss=0.8138 / alpha=0.9998 / lr=0.001000
# Test / Val: Average loss: 0.1711, Accuracy: 195/419 (46.54%)
#
# last correct =195 | best correct = 196
# epoch = 47...in EWC DANN execution function
# Epoch [47/50] Step [1/41]: loss_total=1.4168 / domain_loss_target=0.6966 / domain_loss_source=0.7172 / task_loss=0.0030 / domain_loss=0.7202 / alpha=0.9998 / lr=0.001000
# Test / Val: Average loss: 0.1652, Accuracy: 191/419 (45.58%)
#
# last correct =191 | best correct = 196
# epoch = 48...in EWC DANN execution function
# Epoch [48/50] Step [1/41]: loss_total=1.4167 / domain_loss_target=0.7036 / domain_loss_source=0.7118 / task_loss=0.0012 / domain_loss=0.7131 / alpha=0.9998 / lr=0.001000
# Test / Val: Average loss: 0.1676, Accuracy: 192/419 (45.82%)
#
# last correct =192 | best correct = 196
# epoch = 49...in EWC DANN execution function
# Epoch [49/50] Step [1/41]: loss_total=1.4301 / domain_loss_target=0.7004 / domain_loss_source=0.7090 / task_loss=0.0207 / domain_loss=0.7297 / alpha=0.9999 / lr=0.001000
# Test / Val: Average loss: 0.1559, Accuracy: 192/419 (45.82%)
#
# last correct =192 | best correct = 196
# epoch = 50...in EWC DANN execution function
# Epoch [50/50] Step [1/41]: loss_total=1.4245 / domain_loss_target=0.6823 / domain_loss_source=0.7119 / task_loss=0.0303 / domain_loss=0.7422 / alpha=0.9999 / lr=0.001000
# Test / Val: Average loss: 0.1569, Accuracy: 195/419 (46.54%)
#
# last correct =195 | best correct = 196
# Best model loaded
# Test / Val: Average loss: 0.1616, Accuracy: 196/419 (46.78%)
#
# Test / Val: Average loss: 0.6136, Accuracy: 5/34 (14.71%)
#
# alpha list
#  [0.0, 0.0024390195537999926, 0.004878010089213847, 0.007316942589236097, 0.009755788039622848, 0.012194517430273333, 0.01463310175660859, 0.017071512020952362, 0.01950971923390843, 0.021947694415740848, 0.024385408597748626, 0.026822832823643727, 0.02925993815092398, 0.03169669565224753, 0.034133076416805075, 0.036569051551688325, 0.03900459218325936, 0.04143966945851729, 0.04387425454646143, 0.04630831863945506, 0.048741832954582565, 0.05117476873500948, 0.05360709725133517, 0.0560387898029453, 0.05846981771936077, 0.060900152361583304, 0.06332976512343902, 0.06575862743291672, 0.06818671075350435, 0.07061398658552243, 0.0730404264674509, 0.0754660019772555, 0.07789068473370886, 0.08031444639770635, 0.08273725867357906, 0.08515909331040339, 0.08757992210330268, 0.08999971689474906, 0.09241844957585577, 0.0948360920876683, 0.0996679946249559, 0.10208219879371794, 0.10449520108230437, 0.10690697370058766, 0.10931748891600157, 0.11172671905479481, 0.11413463650327582, 0.11654121370905557, 0.11894642318227966, 0.12135023749685914, 0.12375262929169173, 0.1261535712718771, 0.1285530362099272, 0.13095099694696843, 0.13334742639393804, 0.1357422975327729, 0.1381355834175917, 0.1405272571758709, 0.14291729200961223, 0.14530566119650334, 0.14769233809107174, 0.15007729612583098, 0.15246050881241868, 0.15484194974272758, 0.15722159259002866, 0.1595994111100869, 0.16197537914226734, 0.16434947061063587, 0.16672165952504958, 0.16909191998223982, 0.1714602261668874, 0.17382655235268762, 0.17619087290340985, 0.17855316227394558, 0.18091339501134884, 0.18327154575586935, 0.18562758924197387, 0.18798150029936256, 0.19033325385397148, 0.19268282492897115, 0.19737532022490423, 0.19971819498718246, 0.20205878835447, 0.20439707585072475, 0.20673303310292113, 0.20906663584198082, 0.21139785990369409, 0.2137266812296299, 0.21605307586804057, 0.2183770199747499, 0.22069848981403872, 0.22301746175951465, 0.22533391229497646, 0.22764781801526368, 0.229959155627101, 0.2322679019499292, 0.2345740339167266, 0.23687752857482147, 0.23917836308669216, 0.24147651473075937, 0.2437719609021658, 0.2460646791135459, 0.24835464699578735, 0.2506418422987773, 0.2529262428921437, 0.2552078267659825, 0.25748657203157443, 0.25976245692209265, 0.26203545979329834, 0.26430555912422626, 0.2665727335178598, 0.26883696170179494, 0.27109822252889204, 0.27335649497792036, 0.2756117581541879, 0.2778639912901628, 0.28011317374608224, 0.2823592850105532, 0.2846023047011379, 0.2868422125649326, 0.2913126124515908, 0.2935430646213546, 0.2957703252592059, 0.297994374768181, 0.3002151936840811, 0.30243276267597374, 0.3046470625466806, 0.30685807423325695, 0.30906577880745867, 0.3112701574761976, 0.31347119158198833, 0.31566886260338034, 0.31786315215538274, 0.3200540419898765, 0.3222415139960153, 0.3244255502006148, 0.32660613276853456, 0.3287832440030434, 0.33095686634617905, 0.3331269823790943, 0.3352935748223911, 0.3374566265364476, 0.33961612052173007, 0.3417720399190973, 0.3439243680100921, 0.3460730882172218, 0.34821818410423155, 0.35035963937636105, 0.3524974378805956, 0.3546315636059041, 0.3567620006834664, 0.3588887333868902, 0.36101174613241915, 0.3631310234791263, 0.3652465501291011, 0.36735831092762417, 0.3694662908633304, 0.3715704750683646, 0.3736708488185232, 0.37576739753338884, 0.379948962255225, 0.38203394982134187, 0.38411505547065294, 0.3861922653433052, 0.388265565723815, 0.39033494304112826, 0.39240038386867404, 0.3944618749244053, 0.39651940307083056, 0.3985729553150359, 0.40062251880869826, 0.4026680808480858, 0.40470962887405193, 0.40674715047201726, 0.40878063337194503, 0.410810065448302, 0.4128354347200147, 0.4148567293504144, 0.41687393764717084, 0.41888704806222066, 0.42089604919168266, 0.4229009297757662, 0.4249016786986701, 0.4268982849884708, 0.4288907378170044, 0.4308790264997373, 0.4328631404956287, 0.4348430694069849, 0.4368188029793043, 0.43879033110111365, 0.44075764380379523, 0.44272073126140654, 0.44467958379049155, 0.44663419184988173, 0.448 ...

# %% [markdown]
# ### DANN EWC Plotting and Validation

# %%
dict_ewc_dann_losses['test_loss_source'], dict_ewc_dann_losses['test_loss_target']
# Out:
# (0.16160213008416296, 0.6136141244102927)

# %%
plot_loss_curves(dict_ewc_dann_losses,mode='train_losses')
plot_loss_curves(dict_ewc_dann_losses,mode='val_losses')
plot_loss_curves(dict_ewc_dann_losses,mode='list_alpha')
plot_loss_curves(dict_ewc_dann_losses,mode='lr')

# %% [markdown]
# ### Saving DANN EWC Model

# %%
# ewc_dann_model_name = 'ewc_dann_sfew_expw_30_01.pt'
ewc_dann_model_name = f'ewc_dann_{source_name}_{target_name}_{str(time.strftime("%d_%m"))}.pt' #"ewc_dann_sfew_expw_" + str(time.strftime("%d_%m")) + ".pt"
print(ewc_dann_model_name)

from da_cv_fer.data_config import DataConfig
dataconfig_2 = DataConfig()
MODEL_DIR = dataconfig_2.MODEL_DIR


EWC_DANN_MODEL_DIR =  Path(os.path.join(MODEL_DIR, f'ewc_dann_{source_name}_{target_name}'))
# try:
#     EWC_DANN_SFEW_EXPW_DIR = Path(dataconfig_2.EWC_DANN_SFEW_EXPW_DIR)
# except:
#     EWC_DANN_SFEW_EXPW_DIR =Path(dataconfig_2.MODEL_DIR,"ewc_dann_sfew_expw")


if not EWC_DANN_MODEL_DIR.exists():
    # Create the directory
    EWC_DANN_MODEL_DIR.mkdir(parents=True, exist_ok=True)
    print(f'Directory {EWC_DANN_MODEL_DIR} created successfully.')
else:
    print(f'Directory {EWC_DANN_MODEL_DIR} already exists.')

try:
    torch.save(ewc_dann_model.state_dict(), Path(EWC_DANN_MODEL_DIR,ewc_dann_model_name))
    print(f'{ewc_dann_model_name} SAVED at {Path(EWC_DANN_MODEL_DIR,ewc_dann_model_name)}!')
except:
    print(f'Problem in saving {ewc_dann_model_name}, NOT SAVED!')
# Out:
# ewc_dann_sfew_expw_04_02.pt
# Directory /content/gdrive/MyDrive/CV_FER/models/ewc_dann_sfew_expw already exists.
# ewc_dann_sfew_expw_04_02.pt SAVED at /content/gdrive/MyDrive/CV_FER/models/ewc_dann_sfew_expw/ewc_dann_sfew_expw_04_02.pt!
