# %% [markdown]
# <a href="https://colab.research.google.com/github/scaairesearch/da_cv_fer/blob/main/experiment_model_improvement_v7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Objective
#  - creating versions for non_dann, dann and dann_ewc
#  - Previously from v3
#   - Improve accuracy of base model - classification task
#   - use basic pretrained models to check accuracy - https://www.robots.ox.ac.uk/~albanie/pytorch-models.html - VGG vgg_vd_face_sfew (weights)
#
# Observations
#   - Previously from v3
#     - can achieve more than 51% accuracy
#     - lr of 0.001 gives good accuarcy
#
# Next Steps
#   - lr finder
#   - best model save
#   - SE inclusion
#
# Models
#   - 56%
#   - sota for non-dann

# %% [markdown]
# ## Initializations
# Cloning Repo, Dependencies installation, Libraries import and Config Initialization

# %% [markdown]
# ### Cloning Repo, Installing dependencies

# %%
# !git clone https://github.com/scaairesearch/da_cv_fer
import os
os.getcwd()
os.chdir('da_cv_fer')
# Out:
# Cloning into 'da_cv_fer'...
# remote: Enumerating objects: 446, done.
# remote: Counting objects: 100% (237/237), done.
# remote: Compressing objects: 100% (156/156), done.
# remote: Total 446 (delta 127), reused 157 (delta 81), pack-reused 209
# Receiving objects: 100% (446/446), 30.03 MiB | 28.29 MiB/s, done.
# Resolving deltas: 100% (241/241), done.

# %%
# !pip install -q -r requirements.txt # -q is for quiet install
# for some reason the below does not get installed with requirements
# !pip install -q opendatasets
# !pip install -q facenet_pytorch
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.7/133.7 kB 3.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 32.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 8.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.0/143.0 kB 21.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 23.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 kB 21.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.7/301.7 kB 38.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 86.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 88.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 33.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.7/225.7 kB 28.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.4/173.4 kB 23.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.3/45.3 kB 6.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 103.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.5/61.5 kB 8.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.3/313.3 kB 38.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.2/154.2 kB 22.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 807.0/807.0 kB 64.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 90.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.1/133.1 kB 19.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.0/104.0 kB 15.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 77.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 103.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 15.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 86.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 86.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.2/62.2 MB 27.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 8.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 103.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 112.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 385.2/385.2 kB 48.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.6/283.6 kB 35.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.1/103.1 kB 15.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 502.5/502.5 kB 57.7 MB/s eta 0:00:00
# ERROR: Could not find a version that satisfies the requirement pywin32==306 (from versions: none)
# ERROR: No matching distribution found for pywin32==306

# %%
# Installs from files
from da_cv_fer.data_config import DataConfig
# from da_cv_fer.ds_sfew import DatasetSFEW
from da_cv_fer.ds_sfew_crop import DatasetSFEWCROP
# from da_cv_fer.ds_expw_crop import EXPWCROP
# from da_cv_fer.ds_expw import EXPW
from da_cv_fer.utils import *
# from da_cv_fer.model_DANN import DANN
# from da_cv_fer.model_DANN_Bespoke import DANNBespoke
from da_cv_fer.run_config import RunConfig
# from da_cv_fer.train import *
import os
import zipfile

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau

from tqdm import tqdm # for beautiful model training updates

import matplotlib.pyplot as plt # for plots

import time
from pathlib import Path

from copy import deepcopy
import numpy as np

# %% [markdown]
# ### Initializing Configs

# %%
#initializing dataconfig, it tells us about dataset configuration and directory structure
dataconfig = DataConfig()

# %% [markdown]
# ##  Dataset - Source
# - SFEW Dataset
# - Creating Dataloader object

# %%
# Mounting Google drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ### Creating Dataloader

# %%
sfew = DatasetSFEWCROP()
sfew_train_loader, sfew_val_loader = sfew.get_dataloader()
print(f' length of SFEW dataset : {len(sfew_train_loader.dataset)}')
# Out:
#  self.BASE_PATH -dataset,
#  self.EXTRACT_DIR-dataset/sfew,
#  self.ZIP_FILE_PATH - dataset/SFEW_2.zip
# Directory dataset/sfew created successfully.
# No files (including zip file) found in dataset/sfew.Copying file
# Starting File copying from /content/gdrive/MyDrive/CV_FER/dataset/SFEW_2.zip to dataset/sfew
# File copied successfully from /content/gdrive/MyDrive/CV_FER/dataset/SFEW_2.zip to dataset/sfew
# Initiating extraction of dataset/sfew/SFEW_2.zip to dataset/sfew
# ...completed for dataset/sfew/SFEW_2.zip
# dataset/sfew/Train Surprise.zip Surprise
# ...completed for dataset/sfew/Train/Surprise.zip
# dataset/sfew/Train Neutral.zip Neutral
# ...completed for dataset/sfew/Train/Neutral.zip
# dataset/sfew/Train Disgust.zip Disgust
# ...completed for dataset/sfew/Train/Disgust.zip
# dataset/sfew/Train Fear.zip Fear
# ...completed for dataset/sfew/Train/Fear.zip
# dataset/sfew/Train Happy.zip Happy
# ...completed for dataset/sfew/Train/Happy.zip
# dataset/sfew/Train Sad.zip Sad
# ...completed for dataset/sfew/Train/Sad.zip
# dataset/sfew/Train Angry.zip Angry
# ...completed for dataset/sfew/Train/Angry.zip
# dataset/sfew/Val Surprise.zip Surprise
# ...completed for dataset/sfew/Val/Surprise.zip
# dataset/sfew/Val Neutral.zip Neutral
# ...completed for dataset/sfew/Val/Neutral.zip
# dataset/sfew/Val Disgust.zip Disgust
# ...completed for dataset/sfew/Val/Disgust.zip
# dataset/sfew/Val Fear.zip Fear
# ...completed for dataset/sfew/Val/Fear.zip
# dataset/sfew/Val Happy.zip Happy
# ...completed for dataset/sfew/Val/Happy.zip
# dataset/sfew/Val Sad.zip Sad
# ...completed for dataset/sfew/Val/Sad.zip
# dataset/sfew/Val Angry.zip Angry
# ...completed for dataset/sfew/Val/Angry.zip
# Directory created: dataset/sfew/Train_Crop
# Directory created: dataset/sfew/Val_Crop
# 198 cropped images created in Happy
# 178 cropped images created in Angry
# 96 cropped images created in Surprise
# 150 cropped images created in Neutral
# 172 cropped images created in Sad
# 98 cropped images created in Fear
# 66 cropped images created in Disgust
# 73 cropped images created in Happy
# 77 cropped images created in Angry
# 57 cropped images created in Surprise
# 86 cropped images created in Neutral
# 73 cropped images created in Sad
# 47 cropped images created in Fear
# 23 cropped images created in Disgust
# ----------mean_ds = [0.2197, 0.1858, 0.1569], std_dev_ds = [0.181, 0.1635, 0.1511]----------
#  length of SFEW dataset : 913

# %% [markdown]
# ### Example Images

# %%
show_batch(sfew_train_loader,sfew.labels,4, normalized = False)

# %%
sfew_loader = {'name': 'sfew',
               'train':sfew_train_loader,
               'val':sfew_val_loader
               }
data_loader = {'source' : sfew_loader}
source_name = data_loader['source']['name']

# %% [markdown]
# ## Model Initialization

# %% [markdown]
# ### Simple Model_V5
# - including dann
# - including grl
# - including GAP

# %%
import torch
import torch.nn as nn
from torch.autograd import Function
import torch.nn.functional as F


class Vgg_vd_face_sfew_dag(nn.Module):

    def __init__(self):
        super(Vgg_vd_face_sfew_dag, self).__init__()
        self.meta = {'mean': [129.186279296875, 104.76238250732422, 93.59396362304688],
                     'std': [1, 1, 1],
                     'imageSize': [224, 224, 3]}
        self.conv1_1 = nn.Conv2d(3, 64, kernel_size=[3, 3], stride=(1, 1), padding=(1, 1))
        self.relu1_1 = nn.ReLU()
        self.conv1_2 = nn.Conv2d(64, 64, kernel_size=[3, 3], stride=(1, 1), padding=(1, 1))
        self.relu1_2 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(kernel_size=[2, 2], stride=[2, 2], padding=0, dilation=1, ceil_mode=False)
        self.conv2_1 = nn.Conv2d(64, 128, kernel_size=[3, 3], stride=(1, 1), padding=(1, 1))
        self.relu2_1 = nn.ReLU()
        self.conv2_2 = nn.Conv2d(128, 128, kernel_size=[3, 3], stride=(1, 1), padding=(1, 1))
        self.relu2_2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(kernel_size=[2, 2], stride=[2, 2], padding=0, dilation=1, ceil_mode=False)
        self.conv3_1 = nn.Conv2d(128, 256, kernel_size=[3, 3], stride=(1, 1), padding=(1, 1))
        self.relu3_1 = nn.ReLU()
        self.conv3_2 = nn.Conv2d(256, 256, kernel_size=[3, 3], stride=(1, 1), padding=(1, 1))
        self.relu3_2 = nn.ReLU()
        self.conv3_3 = nn.Conv2d(256, 256, kernel_size=[3, 3], stride=(1, 1), padding=(1, 1))
        self.relu3_3 = nn.ReLU()
        self.pool3 = nn.MaxPool2d(kernel_size=[2, 2], stride=[2, 2], padding=0, dilation=1, ceil_mode=False)
        self.conv4_1 = nn.Conv2d(256, 512, kernel_size=[3, 3], stride=(1, 1), padding=(1, 1))
        self.relu4_1 = nn.ReLU()
        self.conv4_2 = nn.Conv2d(512, 512, kernel_size=[3, 3], stride=(1, 1), padding=(1, 1))
        self.relu4_2 = nn.ReLU()
        self.conv4_3 = nn.Conv2d(512, 512, kernel_size=[3, 3], stride=(1, 1), padding=(1, 1))
        self.relu4_3 = nn.ReLU()
        self.pool4 = nn.MaxPool2d(kernel_size=[2, 2], stride=[2, 2], padding=0, dilation=1, ceil_mode=False)
        self.conv5_1 = nn.Conv2d(512, 512, kernel_size=[3, 3], stride=(1, 1), padding=(1, 1))
        self.relu5_1 = nn.ReLU()
        self.conv5_2 = nn.Conv2d(512, 512, kernel_size=[3, 3], stride=(1, 1), padding=(1, 1))
        self.relu5_2 = nn.ReLU()
        self.conv5_3 = nn.Conv2d(512, 512, kernel_size=[3, 3], stride=(1, 1), padding=(1, 1))
        self.relu5_3 = nn.ReLU()
        self.pool5 = nn.MaxPool2d(kernel_size=[2, 2], stride=[2, 2], padding=0, dilation=1, ceil_mode=False)
        self.fc6 = nn.Conv2d(512, 4096, kernel_size=[7, 7], stride=(1, 1))
        self.relu6 = nn.ReLU()
        self.fc7 = nn.Linear(in_features=4096, out_features=4096, bias=True)
        self.relu7 = nn.ReLU()
        self.fc8 = nn.Linear(in_features=4096, out_features=7, bias=True)

    def forward(self, data):
        x1 = self.conv1_1(data)
        x2 = self.relu1_1(x1)
        x3 = self.conv1_2(x2)
        x4 = self.relu1_2(x3)
        x5 = self.pool1(x4)
        x6 = self.conv2_1(x5)
        x7 = self.relu2_1(x6)
        x8 = self.conv2_2(x7)
        x9 = self.relu2_2(x8)
        x10 = self.pool2(x9)
        x11 = self.conv3_1(x10)
        x12 = self.relu3_1(x11)
        x13 = self.conv3_2(x12)
        x14 = self.relu3_2(x13)
        x15 = self.conv3_3(x14)
        x16 = self.relu3_3(x15)
        x17 = self.pool3(x16)
        x18 = self.conv4_1(x17)
        x19 = self.relu4_1(x18)
        x20 = self.conv4_2(x19)
        x21 = self.relu4_2(x20)
        x22 = self.conv4_3(x21)
        x23 = self.relu4_3(x22)
        x24 = self.pool4(x23)
        x25 = self.conv5_1(x24)
        x26 = self.relu5_1(x25)
        x27 = self.conv5_2(x26)
        x28 = self.relu5_2(x27)
        x29 = self.conv5_3(x28)
        x30 = self.relu5_3(x29)
        x31 = self.pool5(x30)
        x32 = self.fc6(x31) # this is a conv layer, this is the output we need
        x33_preflatten = self.relu6(x32)
        x33 = x33_preflatten.view(x33_preflatten.size(0), -1)
        x34 = self.fc7(x33)
        x35 = self.relu7(x34)
        prediction = self.fc8(x35)
        return prediction


def vgg_vd_face_sfew_dag(weights_path=None, **kwargs):
    """
    load imported model instance

    Args:
        weights_path (str): If set, loads model weights from the given path
    """
    model = Vgg_vd_face_sfew_dag()
    if weights_path:
        state_dict = torch.load(weights_path)
        model.load_state_dict(state_dict)
    return model

# %%
model_pretrained = vgg_vd_face_sfew_dag(weights_path="/content/gdrive/MyDrive/CV_FER/weights/vgg_vd_face_sfew_dag.pth")

# %%
model_pretrained
# Out:
# Vgg_vd_face_sfew_dag(
#   (conv1_1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu1_1): ReLU()
#   (conv1_2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu1_2): ReLU()
#   (pool1): MaxPool2d(kernel_size=[2, 2], stride=[2, 2], padding=0, dilation=1, ceil_mode=False)
#   (conv2_1): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu2_1): ReLU()
#   (conv2_2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu2_2): ReLU()
#   (pool2): MaxPool2d(kernel_size=[2, 2], stride=[2, 2], padding=0, dilation=1, ceil_mode=False)
#   (conv3_1): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu3_1): ReLU()
#   (conv3_2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu3_2): ReLU()
#   (conv3_3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu3_3): ReLU()
#   (pool3): MaxPool2d(kernel_size=[2, 2], stride=[2, 2], padding=0, dilation=1, ceil_mode=False)
#   (conv4_1): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu4_1): ReLU()
#   (conv4_2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu4_2): ReLU()
#   (conv4_3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu4_3): ReLU()
#   (pool4): MaxPool2d(kernel_size=[2, 2], stride=[2, 2], padding=0, dilation=1, ceil_mode=False)
#   (conv5_1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu5_1): ReLU()
#   (conv5_2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu5_2): ReLU()
#   (conv5_3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu5_3): ReLU()
#   (pool5): MaxPool2d(kernel_size=[2, 2], stride=[2, 2], padding=0, dilation=1, ceil_mode=False)
#   (fc6): Conv2d(512, 4096, kernel_size=(7, 7), stride=(1, 1))
#   (relu6): ReLU()
#   (fc7): Linear(in_features=4096, out_features=4096, bias=True)
#   (relu7): ReLU()
#   (fc8): Linear(in_features=4096, out_features=7, bias=True)
# )

# %%
list(model_pretrained.children())[-4:-1]
# Out:
# [ReLU(), Linear(in_features=4096, out_features=4096, bias=True), ReLU()]

# %%
import torch.nn as nn
import torch
from torch.autograd import Function
import torch.nn.functional as F

class GradientReversalFn(Function):
    @staticmethod
    def forward(ctx, x, alpha):
        ctx.alpha = alpha

        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        output = grad_output.neg() * ctx.alpha

        return output, None

class DANN_VGG(nn.Module):
    def __init__(self,
                 model_pretrained = model_pretrained,
                 num_classes=7,
                 dropout_rate = 0.1,
                 ):
        super(DANN_VGG, self).__init__()
        #---------------------Feature Extractor Network------------------------#
        self.feature_extractor = nn.Sequential(*list(model_pretrained.children())[:-4])

        #---------------------Class Classifier------------------------#
        list_class_classifer = list(model_pretrained.children())[-4:]
        list_class_classifer.insert(2, nn.Dropout(dropout_rate))
        # self.class_classifier = nn.Sequential(*list(model_pretrained.children())[-4:])
        self.class_classifier = nn.Sequential(*list_class_classifer)



        #---------------------Domain Classifier------------------------#

        self.domain_classifier = nn.Sequential(nn.ReLU(),
                                               nn.Linear(4096, 4096),
                                               nn.Dropout(dropout_rate),
                                               nn.ReLU(),
                                               nn.Linear(4096, 2)
                                               )

        # Initialize the 4096,4096 to pre-trained
        pretrained_weights = model_pretrained.fc7.weight
        pretrained_biases = model_pretrained.fc7.bias
        with torch.no_grad():
          self.domain_classifier[1].weight.copy_(pretrained_weights)
          self.domain_classifier[1].bias.copy_(pretrained_biases)


    def forward(self, input_data, alpha = 0.0):
        features = self.feature_extractor(input_data)
        # print("features.shape......", features.shape)
        features = features.view(-1,features.size(1))
        # print("features.shape after view......", features.shape)

        reverse_features = GradientReversalFn.apply(features,alpha)

        class_output = self.class_classifier(features)
        domain_output = self.domain_classifier(reverse_features)

        return class_output, domain_output, features

# %%
model = DANN_VGG(model_pretrained = model_pretrained, num_classes=7)
from torchsummary import summary  #for model summary and params
print(model)
# Out:
# DANN_VGG(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=[2, 2], stride=[2, 2], padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU()
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU()
#     (9): MaxPool2d(kernel_size=[2, 2], stride=[2, 2], padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU()
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU()
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU()
#     (16): MaxPool2d(kernel_size=[2, 2], stride=[2, 2], padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU()
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU()
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU()
#     (23): MaxPool2d(kernel_size=[2, 2], stride=[2, 2], padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU()
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU()
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU()
#     (30): MaxPool2d(kernel_size=[2, 2], stride=[2, 2], padding=0, dilation=1, ceil_mode=False)
#     (31): Conv2d(512, 4096, kernel_size=(7, 7), stride=(1, 1))
#   )
#   (class_classifier): Sequential(
#     (0): ReLU()
#     (1): Linear(in_features=4096, out_features=4096, bias=True)
#     (2): Dropout(p=0.1, inplace=False)
#     (3): ReLU()
#     (4): Linear(in_features=4096, out_features=7, bias=True)
#   )
#   (domain_classifier): Sequential(
#     (0): ReLU()
#     (1): Linear(in_features=4096, out_features=4096, bias=True)
#     (2): Dropout(p=0.1, inplace=False)
#     (3): ReLU()
#     (4): Linear(in_features=4096, out_features=2, bias=True)
#   )
# )

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
print(device)
# Out:
# cuda

# %%
from torchsummary import summary

summary(model.to(device), (3, 224, 224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 224, 224]           1,792
#               ReLU-2         [-1, 64, 224, 224]               0
#             Conv2d-3         [-1, 64, 224, 224]          36,928
#               ReLU-4         [-1, 64, 224, 224]               0
#          MaxPool2d-5         [-1, 64, 112, 112]               0
#             Conv2d-6        [-1, 128, 112, 112]          73,856
#               ReLU-7        [-1, 128, 112, 112]               0
#             Conv2d-8        [-1, 128, 112, 112]         147,584
#               ReLU-9        [-1, 128, 112, 112]               0
#         MaxPool2d-10          [-1, 128, 56, 56]               0
#            Conv2d-11          [-1, 256, 56, 56]         295,168
#              ReLU-12          [-1, 256, 56, 56]               0
#            Conv2d-13          [-1, 256, 56, 56]         590,080
#              ReLU-14          [-1, 256, 56, 56]               0
#            Conv2d-15          [-1, 256, 56, 56]         590,080
#              ReLU-16          [-1, 256, 56, 56]               0
#         MaxPool2d-17          [-1, 256, 28, 28]               0
#            Conv2d-18          [-1, 512, 28, 28]       1,180,160
#              ReLU-19          [-1, 512, 28, 28]               0
#            Conv2d-20          [-1, 512, 28, 28]       2,359,808
#              ReLU-21          [-1, 512, 28, 28]               0
#            Conv2d-22          [-1, 512, 28, 28]       2,359,808
#              ReLU-23          [-1, 512, 28, 28]               0
#         MaxPool2d-24          [-1, 512, 14, 14]               0
#            Conv2d-25          [-1, 512, 14, 14]       2,359,808
#              ReLU-26          [-1, 512, 14, 14]               0
#            Conv2d-27          [-1, 512, 14, 14]       2,359,808
#              ReLU-28          [-1, 512, 14, 14]               0
#            Conv2d-29          [-1, 512, 14, 14]       2,359,808
#              ReLU-30          [-1, 512, 14, 14]               0
#         MaxPool2d-31            [-1, 512, 7, 7]               0
#            Conv2d-32           [-1, 4096, 1, 1]     102,764,544
#              ReLU-33                 [-1, 4096]               0
#            Linear-34                 [-1, 4096]      16,781,312
#           Dropout-35                 [-1, 4096]               0
#              ReLU-36                 [-1, 4096]               0
#            Linear-37                    [-1, 7]          28,679
#              ReLU-38                 [-1, 4096]               0
#            Linear-39                 [-1, 4096]      16,781,312
#           Dropout-40                 [-1, 4096]               0
#              ReLU-41                 [-1, 4096]               0
#            Linear-42                    [-1, 2]           8,194
# ================================================================
# Total params: 151,078,729
# Trainable params: 151,078,729
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 218.68
# Params size (MB): 576.32
# Estimated Total Size (MB): 795.57
# ----------------------------------------------------------------

# %%
# !pip install torch-summary

# %%
# from torchsummary import summary
# summary(model, (3, 224, 224), col_names = ["input_size", "output_size", "num_params", "kernel_size", "mult_adds"], verbose =2 )

# %% [markdown]
# ## Checking accuracy before fine tuning

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
print(device)
# Out:
# cuda

# %%
model = model.to(device=device)

# %% [markdown]
# ### Test Function

# %%
def get_correct_preds(prediction, labels):
    """
    Function to return total number of correct predictions
    :param prediction: Model predictions on a given sample of data
    :param labels: Correct labels of a given sample of data
    :return: Number of correct predictions
    """
    return prediction.argmax(dim=1).eq(labels.argmax(dim=1)).sum().item()

# %%
def test_model_local(model, device, data_loader, mode= 'test',
               class_loss_function = nn.CrossEntropyLoss() ):
    model.eval() # evaluation mode

    # variables to track loss and accuracy
    test_loss = 0.0
    correct = 0

    # Disable gradient updation
    with torch.no_grad():
        # Iterate over each batch and fetch images and labels from the batch
        for batch_idx, batch in enumerate(data_loader):
            images, labels = batch[0].to(device), batch[1].to(device)

            class_output,_,_  = model((images*255)) # forward pass, output = {class}
            class_loss = class_loss_function(class_output,labels) # Calculate Loss

            test_loss += class_loss.item() # sum up batch loss

            # Sum up batch correct predictions
            correct += get_correct_preds(class_output, labels)

    # Calculate test loss for a epoch
    test_loss /= len(data_loader.dataset)

    print('Test / Val: Average loss: {:.4f}, Accuracy: {}/{} ({:.2f}%)\n'.format(test_loss, correct, len(data_loader.dataset),
        100. * correct / len(data_loader.dataset)))


    return correct, test_loss

# %% [markdown]
# #### Pre fine train metric

# %%
correct, test_loss = test_model_local(model, device, data_loader['source']['val'], mode= 'test')
correct, test_loss
# Out:
# Test / Val: Average loss: 0.5718, Accuracy: 108/419 (25.78%)
# (108, 0.5718486815477613)

# %% [markdown]
# ### Train Function

# %% [markdown]
# #### Basic Training Function

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision.transforms import ToTensor
from torch.utils.data import DataLoader
from tqdm import tqdm
import torch.nn.functional as F

def train_model_local(model, train_loader, criterion, optimizer, device='cuda'):
    model.to(device)
    model.train()
    # for epoch in range(num_epochs):
    running_loss = 0.0
    correct = 0

    for inputs, labels,_ in train_loader:
        inputs = inputs * 255.0  # Convert inputs from [0, 1] to [0, 255]
        inputs = inputs.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()

        outputs,_,_ = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * inputs.size(0)
        correct += get_correct_preds(outputs, labels)


    epoch_loss = running_loss / len(train_loader.dataset)
    length_dataset = len(train_loader.dataset)
    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {epoch_loss:.4f}, Accuracy : {correct}/{length_dataset} Or {100. * correct / length_dataset: .2f} %')

    return

# %% [markdown]
# #### Training Function with LR Scheduler

# %%
def train_model_local_lr(model,device, data_loader, optimizer, epoch,
                class_loss_function = nn.CrossEntropyLoss() ):
    print(f'epoch = {epoch+1}...in training function')
    model.to(device)
    model.train() # setting model to training


    pbar = tqdm(data_loader) # putting the dataloader in progress bar

    processed = 0 # to understand accuracy, used in denominator
    epoch_loss = 0.0
    correct = 0

    for batch_idx, batch in enumerate(pbar):
        batch[0] = batch[0] * 255.0  # Convert inputs from [0, 1] to [0, 255]
        images, labels = batch[0].to(device), batch[1].to(device) # batch of images and labels


        optimizer.zero_grad() # setting gradients to zero to avoid accumulation

        class_output, _ , _ = model(images) # forward pass, output = {class, domain, feature}

        class_loss = class_loss_function(class_output,labels) # Calculate Loss
        epoch_loss += class_loss.item()
        # Sum up batch correct predictions
        correct += get_correct_preds(class_output, labels)

        class_loss.backward() #backpropogation, creating gradients

        optimizer.step() # updating the params

        processed += len(images)
        curr_lr = optimizer.param_groups[0]['lr']

        pbar.set_description(desc= f'Loss={class_loss.item()} Accuracy={correct}/{processed}({100*correct/processed:0.2f}%) Epoch Avg loss={epoch_loss/processed:0.8f} LR={curr_lr:0.6f}')

    return float("{:.8f}".format(epoch_loss/processed)),  curr_lr

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# %% [markdown]
# ### Execution without Learning Rate

# %%
# num_epochs=55
# for epoch in range(num_epochs):
#   train_model_local(model = model, train_loader = data_loader['source']['train'], criterion = criterion, optimizer=optimizer)
#   test_model_local(model, device, data_loader['source']['val'], class_loss_function= criterion, mode= 'test')
# print('Training finished.')

# %% [markdown]
# ### Execution with LR

# %%
runconfig = RunConfig()
device = runconfig.device

model = DANN_VGG(model_pretrained = model_pretrained, num_classes=7).to(device=device)
best_model = DANN_VGG(model_pretrained = model_pretrained, num_classes=7).to(device=device)

#learning rate
lr =  0.001 #float(runconfig.inital_lr)

# Epochs
EPOCHS = runconfig.NUM_EPOCHS
# EPOCHS = 2 #override
print("EPOCHS", EPOCHS)

# ReduceLRonPlateau Scheduler Params
scheduler_patience = 8 #runconfig.scheduler_patience
scheduler_factor = runconfig.scheduler_factor
scheduler_threshold = 25 #runconfig.scheduler_threshold

# Early stopping params
early_stop_patience = 10 #runconfig.early_stop_patience
early_stop_difference = 15 #runconfig.early_stop_difference

# optimizer
optimizer = optim.SGD(model.parameters(), lr = lr, momentum = 0.9)

#optimizer with weight decay (L2 regularization)
# optimizer = optim.SGD(non_dann_model.parameters(), lr = lr, momentum = 0.9, weight_decay= 0.0001)

# Set up the ReduceLROnPlateau scheduler
scheduler = ReduceLROnPlateau(optimizer,
                              # mode='min',
                              mode='max',
                              factor=scheduler_factor,
                              patience=scheduler_patience,
                              threshold = scheduler_threshold,
                              threshold_mode='abs',
                              min_lr=1e-6,
                              verbose= True)

# Initialize variables to track the best validation loss and the best model state
best_val_loss = float('inf')
best_val_acc = 0
best_model_state = None

# loss functions
criterion_class = (runconfig.criterion_class).to(device=device)
# criterion_domain = (runconfig.criterion_domain).to(device=device)

# loss accumulation
train_losses = [] # to capture train losses over training epochs
val_losses = [] # to capture validation loss over epochs
lr_schedule = [] # to capture learning rate over epochs
epoch_converge = 0 #TODO: run config based
list_val_correct = [] # to capture validation accuracy over epochs
list_best_val_correct = [] # to capture best validtion accuracy over epochs
# Out:
# EPOCHS 150

# %%
# Training block
print('------ Training started for Non DANN Model ---- ')
print(f'starting LR : {lr}')
for epoch in range(EPOCHS):
    print("EPOCH:", epoch+1, " of ", EPOCHS)

    #Train Model
    avg_epoch_loss, curr_lr = train_model_local_lr (model = model,
                                          device = device,
                                          data_loader = data_loader['source']['train'],
                                          optimizer = optimizer,
                                          epoch = epoch,
                                          class_loss_function = criterion_class)
    train_losses.append(avg_epoch_loss)
    lr_schedule.append(curr_lr)

    #Validate Model
    correct, avg_epoch_val_loss = test_model_local(model= model,
                                    device= device,
                                    data_loader = data_loader['source']['val'],
                                    class_loss_function = criterion_class
                                    )

    val_losses.append(avg_epoch_val_loss)
    list_val_correct.append(correct)

    #Adding Scheduler #TODO: ADD SCHEDULER
    scheduler.step(correct) #applying scheduler on accuracy proxy, i.e. correct

    # # Check if the current model has the best validation loss
    # print(f'Last Epoch Val Loss = {avg_epoch_val_loss} | Best Val Loss = {best_val_loss}' )
    # if avg_epoch_val_loss < best_val_loss:
    #   best_val_loss = avg_epoch_val_loss
    #   # save the current model state as the best model state
    #   best_model_state = deepcopy(non_dann_model.state_dict())
    #   print(f'Updated the best model with validation loss: {best_val_loss}\n')

    # check if the current model has the best accuracy
    print (f'last correct ={correct} | best correct = {best_val_acc}')
    if correct > best_val_acc:
      best_val_acc = correct
      # save the current model state as the best model state
      best_model_state = deepcopy(model.state_dict())
      print(f'Updated the best model with correct: {correct}\n')

    list_best_val_correct.append(best_val_acc)

    # early stopping
    # if early_stopping_difference(val_losses,
    #                              patience = early_stop_patience,
    #                              difference= early_stop_difference):
    #   print (f'-------Early Stopping at epoch {epoch+1}---')
    #   epoch_converge = epoch+1
    #   break

    if early_stopping_difference(list_val_correct,
                                 patience = early_stop_patience,
                                 difference= early_stop_difference):
      print (f'-------Early Stopping at epoch {epoch+1}---')
      epoch_converge = epoch+1
      break

    if early_stopping_difference(list_best_val_correct,
                                 patience = 2*early_stop_patience,
                                 difference= 0):
      print (f'-------Early Stopping at epoch {epoch+1}---')
      epoch_converge = epoch+1
      break



    ## showing misclassification images after every 10 epochs
    if epoch % 10 == 0:
      list_misclassified_images = get_misclassified_images_list(model= model,
                                                                device = device,
                                                                test_loader = data_loader['source']['val'],
                                                                num_image = 10)
      plot_misclassified_images(list_misclassified_images)

## using params of best model to update model
if best_model_state: # only update if best model has been saved, else the last one would be picked up
  # best_non_dann_model.load_state_dict(best_model_state)
  best_model.load_state_dict(best_model_state)
  print('Best model loaded')


print(f'Validation results with {source_name}')

correct, test_loss_source = test_model_local(model= best_model, #best_non_dann_model, #non_dann_model,
                                    device= device,
                                    data_loader = data_loader['source']['val'], # source val loader
                                    class_loss_function = criterion_class)





dict_non_dann_losses = {'train_losses' : train_losses,
                                       'val_losses': val_losses,
                                       'test_loss_source' : test_loss_source,
                                      #  'test_loss_target' : test_loss_target,
                                       'epoch_convergence' : epoch_converge,
                                       'lr': lr_schedule}
# Out:
# ------ Training started for Non DANN Model ----
# starting LR : 0.001
# EPOCH: 1  of  150
# epoch = 1...in training function
# Loss=2.4378647804260254 Accuracy=377/913(41.29%) Epoch Avg loss=0.09798591 LR=0.001000: 100%|██████████| 58/58 [00:24<00:00,  2.33it/s]
# Test / Val: Average loss: 0.1032, Accuracy: 176/419 (42.00%)
#
# last correct =176 | best correct = 0
# Updated the best model with correct: 176
# EPOCH: 2  of  150
# epoch = 2...in training function
# Loss=2.357987880706787 Accuracy=438/913(47.97%) Epoch Avg loss=0.09374026 LR=0.001000: 100%|██████████| 58/58 [00:25<00:00,  2.31it/s]
# Test / Val: Average loss: 0.0990, Accuracy: 192/419 (45.82%)
#
# last correct =192 | best correct = 176
# Updated the best model with correct: 192
#
# EPOCH: 3  of  150
# epoch = 3...in training function
# Loss=1.0884196758270264 Accuracy=446/913(48.85%) Epoch Avg loss=0.09083566 LR=0.001000: 100%|██████████| 58/58 [00:24<00:00,  2.33it/s]
# Test / Val: Average loss: 0.1085, Accuracy: 190/419 (45.35%)
#
# last correct =190 | best correct = 192
# EPOCH: 4  of  150
# epoch = 4...in training function
# Loss=3.6510496139526367 Accuracy=495/913(54.22%) Epoch Avg loss=0.08430055 LR=0.001000: 100%|██████████| 58/58 [00:25<00:00,  2.31it/s]
# Test / Val: Average loss: 0.1176, Accuracy: 167/419 (39.86%)
#
# last correct =167 | best correct = 192
# EPOCH: 5  of  150
# epoch = 5...in training function
# Loss=2.098769187927246 Accuracy=401/913(43.92%) Epoch Avg loss=0.09997266 LR=0.001000: 100%|██████████| 58/58 [00:24<00:00,  2.32it/s]
# Test / Val: Average loss: 0.1119, Accuracy: 172/419 (41.05%)
#
# last correct =172 | best correct = 192
# EPOCH: 6  of  150
# epoch = 6...in training function
# Loss=0.9280574917793274 Accuracy=420/913(46.00%) Epoch Avg loss=0.09346119 LR=0.001000: 100%|██████████| 58/58 [00:24<00:00,  2.33it/s]
# Test / Val: Average loss: 0.1025, Accuracy: 173/419 (41.29%)
#
# last correct =173 | best correct = 192
# EPOCH: 7  of  150
# epoch = 7...in training function
# Loss=0.022141631692647934 Accuracy=481/913(52.68%) Epoch Avg loss=0.08163036 LR=0.001000: 100%|██████████| 58/58 [00:25<00:00,  2.29it/s]
# Test / Val: Average loss: 0.0993, Accuracy: 208/419 (49.64%)
#
# last correct =208 | best correct = 192
# Updated the best model with correct: 208
#
# EPOCH: 8  of  150
# epoch = 8...in training function
# Loss=1.3087677955627441 Accuracy=567/913(62.10%) Epoch Avg loss=0.07105491 LR=0.001000: 100%|██████████| 58/58 [00:25<00:00,  2.27it/s]
# Test / Val: Average loss: 0.1036, Accuracy: 191/419 (45.58%)
#
# last correct =191 | best correct = 208
# EPOCH: 9  of  150
# epoch = 9...in training function
# Loss=0.20404700934886932 Accuracy=572/913(62.65%) Epoch Avg loss=0.06763498 LR=0.001000: 100%|██████████| 58/58 [00:25<00:00,  2.27it/s]
# Test / Val: Average loss: 0.1114, Accuracy: 207/419 (49.40%)
#
# last correct =207 | best correct = 208
# EPOCH: 10  of  150
# epoch = 10...in training function
# Loss=0.30756884813308716 Accuracy=595/913(65.17%) Epoch Avg loss=0.06469875 LR=0.001000: 100%|██████████| 58/58 [00:25<00:00,  2.23it/s]
# Test / Val: Average loss: 0.1017, Accuracy: 211/419 (50.36%)
#
# last correct =211 | best correct = 208
# Updated the best model with correct: 211
#
# EPOCH: 11  of  150
# epoch = 11...in training function
# Loss=5.095411777496338 Accuracy=607/913(66.48%) Epoch Avg loss=0.06714390 LR=0.001000: 100%|██████████| 58/58 [00:25<00:00,  2.25it/s]
# Test / Val: Average loss: 0.1024, Accuracy: 198/419 (47.26%)
#
# last correct =198 | best correct = 211
# EPOCH: 12  of  150
# epoch = 12...in training function
# Loss=0.7296536564826965 Accuracy=561/913(61.45%) Epoch Avg loss=0.07071839 LR=0.001000: 100%|██████████| 58/58 [00:25<00:00,  2.27it/s]
# Test / Val: Average loss: 0.1118, Accuracy: 194/419 (46.30%)
#
# last correct =194 | best correct = 211
# EPOCH: 13  of  150
# epoch = 13...in training function
# Loss=1.4662926197052002 Accuracy=586/913(64.18%) Epoch Avg loss=0.06542850 LR=0.001000: 100%|██████████| 58/58 [00:25<00:00,  2.29it/s]
# Test / Val: Average loss: 0.1011, Accuracy: 194/419 (46.30%)
#
# last correct =194 | best correct = 211
# EPOCH: 14  of  150
# epoch = 14...in training function
# Loss=1.061523675918579 Accuracy=656/913(71.85%) Epoch Avg loss=0.05143904 LR=0.001000: 100%|██████████| 58/58 [00:25<00:00,  2.32it/s]
# Test / Val: Average loss: 0.1094, Accuracy: 211/419 (50.36%)
#
# last correct =211 | best correct = 211
# EPOCH: 15  of  150
# epoch = 15...in training function
# Loss=1.4165778160095215 Accuracy=597/913(65.39%) Epoch Avg loss=0.06527490 LR=0.001000: 100%|██████████| 58/58 [00:25<00:00,  2.30it/s]
# Test / Val: Average loss: 0.1063, Accuracy: 190/419 (45.35%)
#
# last correct =190 | best correct = 211
# EPOCH: 16  of  150
# epoch = 16...in training function
# Loss=0.5565500855445862 Accuracy=657/913(71.96%) Epoch Avg loss=0.05110445 LR=0.001000: 100%|██████████| 58/58 [00:25<00:00,  2.31it/s]
# Test / Val: Average loss: 0.1276, Accuracy: 208/419 (49.64%)
#
# last correct =208 | best correct = 211
# EPOCH: 17  of  150
# epoch = 17...in training function
# Loss=0.02243751659989357 Accuracy=718/913(78.64%) Epoch Avg loss=0.04328204 LR=0.000200: 100%|██████████| 58/58 [00:25<00:00,  2.31it/s]
# Test / Val: Average loss: 0.1159, Accuracy: 218/419 (52.03%)
#
# last correct =218 | best correct = 211
# Updated the best model with correct: 218
#
# EPOCH: 18  of  150
# epoch = 18...in training function
# Loss=-0.0 Accuracy=743/913(81.38%) Epoch Avg loss=0.03381849 LR=0.000200: 100%|██████████| 58/58 [00:25<00:00,  2.31it/s]
# Test / Val: Average loss: 0.1238, Accuracy: 222/419 (52.98%)
#
# last correct =222 | best correct = 218
# Updated the best model with correct: 222
#
# EPOCH: 19  of  150
# epoch = 19...in training function
# Loss=0.06814800202846527 Accuracy=766/913(83.90%) Epoch Avg loss=0.03227060 LR=0.000200: 100%|██████████| 58/58 [00:25<00:00,  2.31it/s]
# Test / Val: Average loss: 0.1196, Accuracy: 228/419 (54.42%)
#
# last correct =228 | best correct = 222
# Updated the best model with correct: 228
#
# EPOCH: 20  of  150
# epoch = 20...in training function
# Loss=0.015284435823559761 Accuracy=776/913(84.99%) Epoch Avg loss=0.02895003 LR=0.000200: 100%|██████████| 58/58 [00:25<00:00,  2.31it/s]
# Test / Val: Average loss: 0.1179, Accuracy: 226/419 (53.94%)
#
# last correct =226 | best correct = 228
# EPOCH: 21  of  150
# epoch = 21...in training function
# Loss=0.03536853566765785 Accuracy=790/913(86.53%) Epoch Avg loss=0.02585257 LR=0.000200: 100%|██████████| 58/58 [00:25<00:00,  2.31it/s]
# Test / Val: Average loss: 0.1221, Accuracy: 232/419 (55.37%)
#
# last correct =232 | best correct = 228
# Updated the best model with correct: 232
# EPOCH: 22  of  150
# epoch = 22...in training function
# Loss=0.003969884943217039 Accuracy=783/913(85.76%) Epoch Avg loss=0.02829224 LR=0.000200: 100%|██████████| 58/58 [00:25<00:00,  2.30it/s]
# Test / Val: Average loss: 0.1268, Accuracy: 215/419 (51.31%)
#
# last correct =215 | best correct = 232
# EPOCH: 23  of  150
# epoch = 23...in training function
# Loss=0.0004068977141287178 Accuracy=801/913(87.73%) Epoch Avg loss=0.02567566 LR=0.000200: 100%|██████████| 58/58 [00:26<00:00,  2.21it/s]
# Test / Val: Average loss: 0.1155, Accuracy: 227/419 (54.18%)
#
# last correct =227 | best correct = 232
# EPOCH: 24  of  150
# epoch = 24...in training function
# Loss=0.6946491599082947 Accuracy=804/913(88.06%) Epoch Avg loss=0.02318517 LR=0.000200: 100%|██████████| 58/58 [00:25<00:00,  2.25it/s]
# Test / Val: Average loss: 0.1304, Accuracy: 234/419 (55.85%)
#
# last correct =234 | best correct = 232
# Updated the best model with correct: 234
#
# EPOCH: 25  of  150
# epoch = 25...in training function
# Loss=0.016356086358428 Accuracy=798/913(87.40%) Epoch Avg loss=0.02481203 LR=0.000200: 100%|██████████| 58/58 [00:25<00:00,  2.25it/s]
# Test / Val: Average loss: 0.1179, Accuracy: 226/419 (53.94%)
#
# last correct =226 | best correct = 234
# EPOCH: 26  of  150
# epoch = 26...in training function
# Loss=4.172316494077677e-06 Accuracy=783/913(85.76%) Epoch Avg loss=0.02483880 LR=0.000200: 100%|██████████| 58/58 [00:26<00:00,  2.22it/s]
# Test / Val: Average loss: 0.1247, Accuracy: 232/419 (55.37%)
#
# last correct =232 | best correct = 234
# EPOCH: 27  of  150
# epoch = 27...in training function
# Loss=0.0002540027489885688 Accuracy=810/913(88.72%) Epoch Avg loss=0.02038060 LR=0.000200: 100%|██████████| 58/58 [00:25<00:00,  2.29it/s]
# Test / Val: Average loss: 0.1255, Accuracy: 227/419 (54.18%)
#
# last correct =227 | best correct = 234
# EPOCH: 28  of  150
# epoch = 28...in training function
# Loss=0.00026770823751576245 Accuracy=796/913(87.19%) Epoch Avg loss=0.02122641 LR=0.000200: 100%|██████████| 58/58 [00:25<00:00,  2.29it/s]
# Test / Val: Average loss: 0.1283, Accuracy: 236/419 (56.32%)
#
# last correct =236 | best correct = 234
# Updated the best model with correct: 236
#
# EPOCH: 29  of  150
# epoch = 29...in training function
# Loss=0.08212768286466599 Accuracy=806/913(88.28%) Epoch Avg loss=0.02389305 LR=0.000200: 100%|██████████| 58/58 [00:25<00:00,  2.31it/s]
# Test / Val: Average loss: 0.1208, Accuracy: 221/419 (52.74%)
#
# last correct =221 | best correct = 236
# EPOCH: 30  of  150
# epoch = 30...in training function
# Loss=0.03073836676776409 Accuracy=834/913(91.35%) Epoch Avg loss=0.01738491 LR=0.000200: 100%|██████████| 58/58 [00:25<00:00,  2.32it/s]
# Test / Val: Average loss: 0.1419, Accuracy: 229/419 (54.65%)
#
# last correct =229 | best correct = 236
# EPOCH: 31  of  150
# epoch = 31...in training function
# Loss=3.5072028636932373 Accuracy=824/913(90.25%) Epoch Avg loss=0.02200907 LR=0.000200: 100%|██████████| 58/58 [00:25<00:00,  2.30it/s]
# Test / Val: Average loss: 0.1361, Accuracy: 222/419 (52.98%)
#
# last correct =222 | best correct = 236
# EPOCH: 32  of  150
# epoch = 32...in training function
# Loss=0.00012420836719684303 Accuracy=819/913(89.70%) Epoch Avg loss=0.01999974 LR=0.000200: 100%|██████████| 58/58 [00:25<00:00,  2.27it/s]
# Test / Val: Average loss: 0.1337, Accuracy: 223/419 (53.22%)
#
# last correct =223 | best correct = 236
# -------Early Stopping at epoch 32---
# Best model loaded
# Validation results with sfew
# Test / Val: Average loss: 0.1262, Accuracy: 236/419 (56.32%)

# %% [markdown]
# ### Saving Non-Dann Model

# %%
target_name = 'expw'
MODEL_DIR = dataconfig.MODEL_DIR
NON_DANN_SFEW_DIR = dataconfig.NON_DANN_SFEW_DIR
SPECIFIC_MODEL_DIR = Path(os.path.join(MODEL_DIR, f'non_dann_{source_name}_{target_name}'))
print(MODEL_DIR, NON_DANN_SFEW_DIR, SPECIFIC_MODEL_DIR)
# Out:
# /content/gdrive/MyDrive/CV_FER/models /content/gdrive/MyDrive/CV_FER/models/non_dann_sfew /content/gdrive/MyDrive/CV_FER/models/non_dann_sfew_expw

# %%
model_name = f'non_dann_{source_name}_{target_name}_{str(time.strftime("%d_%m"))}.pt' #"non_dann_sfew_" +str(time.strftime("%d_%m"))+ ".pt"
# dataconfig = DataConfig()
# NON_DANN_SFEW_DIR = dataconfig.NON_DANN_SFEW_DIR
if not SPECIFIC_MODEL_DIR.exists():
    # Create the directory
    SPECIFIC_MODEL_DIR.mkdir(parents=True, exist_ok=True)
    print(f'Directory {SPECIFIC_MODEL_DIR} created successfully.')
else:
    print(f'Directory {SPECIFIC_MODEL_DIR} already exists.')

torch.save(best_model.state_dict(), Path(SPECIFIC_MODEL_DIR,model_name))
# Out:
# Directory /content/gdrive/MyDrive/CV_FER/models/non_dann_sfew_expw already exists.

# %% [markdown]
# ## Dataset - Target
#
# - EXPW dataset

# %%
# checking the mounted drive and mounting if not done
import os
if not os.path.exists('/content/gdrive'):
  from google.colab import drive
  drive.mount('/content/gdrive')
else:
    print("Google Drive is already mounted.")
# Out:
# Google Drive is already mounted.

# %% [markdown]
# ### Creating Dataloader for EXPW

# %%
from da_cv_fer.ds_expw_crop import EXPWCROP

expw_obj = EXPWCROP()

expw_train_ds, expw_val_ds = expw_obj.get_dataset()
expw_train_loader, expw_val_loader = expw_obj.get_dataloader()
print(f' length of EXPW dataset : {len(expw_train_loader.dataset)} , {len(expw_train_ds)}')
# Out:
# desitination file path = dataset/expwds/expwds.zip
# Directory dataset/expwds created successfully.
# Downloading expwds.zip to dataset/expwds
# 100%|██████████| 7.68G/7.68G [01:23<00:00, 99.0MB/s]
# File downloaded successfully from https://www.kaggle.com/datasets/mohammedaaltaha/expwds to dataset/expwds/expwds.zip
# Unzipped Files already exist in dataset/expwds, not extracted
# ---NOT CROPPING AT RUNTIME--
#  before splitting : image_label_dict 68096
# *** Starting creation of validation dataset based on RACE data ***
# pickle_file_path:  /content/gdrive/MyDrive/CV_FER/dataset/expw_raceds_image_dict.pkl
# size of dataset (list_img_label): 1000
# *** Completed creation of validation dataset based on RACE data ***
# ---NOT CROPPING AT RUNTIME--, flag_create_crop_contents value: False
# Directory created: dataset/expwds/cropped
# **** dataset/expwds/cropped is empty***
#
#  WARNING: It may take a long  time to crop the images, please be patient
#
# 17 were not able to crop
# 983 cropped images created in cropped
# ---NOT CROPPING AT RUNTIME--
#  before splitting : image_label_dict 68096
# *** Starting creation of validation dataset based on RACE data ***
# pickle_file_path:  /content/gdrive/MyDrive/CV_FER/dataset/expw_raceds_image_dict.pkl
# size of dataset (list_img_label): 8697
# *** Completed creation of validation dataset based on RACE data ***
# ---NOT CROPPING AT RUNTIME--, flag_create_crop_contents value: False
#  length of EXPW dataset : 983 , 983

# %%
if expw_train_loader is None:
  sfew_loader = {'name': 'sfew',
               'train':sfew_train_loader,
               'val':sfew_val_loader
               }
  data_loader = {'source' : sfew_loader}
  source_name = data_loader['source']['name']
  target_name = "expw"
else:
  sfew_loader = {'name': 'sfew',
                'train':sfew_train_loader,
                'val':sfew_val_loader
                }

  expw_loader = {'name': 'expw',
                'train':expw_train_loader,
                'val':expw_val_loader
                }

  data_loader = {'source' : sfew_loader,
                'target' : expw_loader}

  source_name = data_loader['source']['name']
  target_name = data_loader['target']['name']

# %% [markdown]
# ## Loading NON DANN Model for DANN and DANN EWC

# %%
today_model_name = f'non_dann_{source_name}_{target_name}_{str(time.strftime("%d_%m"))}.pt' # Typical - non_dann_sfew_expw_30_01.pt This may change, use specific model name if required4
print(f'today_model_name {today_model_name}')
custom_model_name= 'non_dann_sfew_expw_08_04.pt'
print(f'custom_model_name {custom_model_name}')
model_name = custom_model_name
# Out:
# today_model_name non_dann_sfew_expw_10_04.pt
# custom_model_name non_dann_sfew_expw_08_04.pt

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
print(device)
# Out:
# cuda

# %%
import torch
import torch.nn as nn
from torch.autograd import Function
import torch.nn.functional as F


class Vgg_vd_face_sfew_dag(nn.Module):

    def __init__(self):
        super(Vgg_vd_face_sfew_dag, self).__init__()
        self.meta = {'mean': [129.186279296875, 104.76238250732422, 93.59396362304688],
                     'std': [1, 1, 1],
                     'imageSize': [224, 224, 3]}
        self.conv1_1 = nn.Conv2d(3, 64, kernel_size=[3, 3], stride=(1, 1), padding=(1, 1))
        self.relu1_1 = nn.ReLU()
        self.conv1_2 = nn.Conv2d(64, 64, kernel_size=[3, 3], stride=(1, 1), padding=(1, 1))
        self.relu1_2 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(kernel_size=[2, 2], stride=[2, 2], padding=0, dilation=1, ceil_mode=False)
        self.conv2_1 = nn.Conv2d(64, 128, kernel_size=[3, 3], stride=(1, 1), padding=(1, 1))
        self.relu2_1 = nn.ReLU()
        self.conv2_2 = nn.Conv2d(128, 128, kernel_size=[3, 3], stride=(1, 1), padding=(1, 1))
        self.relu2_2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(kernel_size=[2, 2], stride=[2, 2], padding=0, dilation=1, ceil_mode=False)
        self.conv3_1 = nn.Conv2d(128, 256, kernel_size=[3, 3], stride=(1, 1), padding=(1, 1))
        self.relu3_1 = nn.ReLU()
        self.conv3_2 = nn.Conv2d(256, 256, kernel_size=[3, 3], stride=(1, 1), padding=(1, 1))
        self.relu3_2 = nn.ReLU()
        self.conv3_3 = nn.Conv2d(256, 256, kernel_size=[3, 3], stride=(1, 1), padding=(1, 1))
        self.relu3_3 = nn.ReLU()
        self.pool3 = nn.MaxPool2d(kernel_size=[2, 2], stride=[2, 2], padding=0, dilation=1, ceil_mode=False)
        self.conv4_1 = nn.Conv2d(256, 512, kernel_size=[3, 3], stride=(1, 1), padding=(1, 1))
        self.relu4_1 = nn.ReLU()
        self.conv4_2 = nn.Conv2d(512, 512, kernel_size=[3, 3], stride=(1, 1), padding=(1, 1))
        self.relu4_2 = nn.ReLU()
        self.conv4_3 = nn.Conv2d(512, 512, kernel_size=[3, 3], stride=(1, 1), padding=(1, 1))
        self.relu4_3 = nn.ReLU()
        self.pool4 = nn.MaxPool2d(kernel_size=[2, 2], stride=[2, 2], padding=0, dilation=1, ceil_mode=False)
        self.conv5_1 = nn.Conv2d(512, 512, kernel_size=[3, 3], stride=(1, 1), padding=(1, 1))
        self.relu5_1 = nn.ReLU()
        self.conv5_2 = nn.Conv2d(512, 512, kernel_size=[3, 3], stride=(1, 1), padding=(1, 1))
        self.relu5_2 = nn.ReLU()
        self.conv5_3 = nn.Conv2d(512, 512, kernel_size=[3, 3], stride=(1, 1), padding=(1, 1))
        self.relu5_3 = nn.ReLU()
        self.pool5 = nn.MaxPool2d(kernel_size=[2, 2], stride=[2, 2], padding=0, dilation=1, ceil_mode=False)
        self.fc6 = nn.Conv2d(512, 4096, kernel_size=[7, 7], stride=(1, 1))
        self.relu6 = nn.ReLU()
        self.fc7 = nn.Linear(in_features=4096, out_features=4096, bias=True)
        self.relu7 = nn.ReLU()
        self.fc8 = nn.Linear(in_features=4096, out_features=7, bias=True)

    def forward(self, data):
        x1 = self.conv1_1(data)
        x2 = self.relu1_1(x1)
        x3 = self.conv1_2(x2)
        x4 = self.relu1_2(x3)
        x5 = self.pool1(x4)
        x6 = self.conv2_1(x5)
        x7 = self.relu2_1(x6)
        x8 = self.conv2_2(x7)
        x9 = self.relu2_2(x8)
        x10 = self.pool2(x9)
        x11 = self.conv3_1(x10)
        x12 = self.relu3_1(x11)
        x13 = self.conv3_2(x12)
        x14 = self.relu3_2(x13)
        x15 = self.conv3_3(x14)
        x16 = self.relu3_3(x15)
        x17 = self.pool3(x16)
        x18 = self.conv4_1(x17)
        x19 = self.relu4_1(x18)
        x20 = self.conv4_2(x19)
        x21 = self.relu4_2(x20)
        x22 = self.conv4_3(x21)
        x23 = self.relu4_3(x22)
        x24 = self.pool4(x23)
        x25 = self.conv5_1(x24)
        x26 = self.relu5_1(x25)
        x27 = self.conv5_2(x26)
        x28 = self.relu5_2(x27)
        x29 = self.conv5_3(x28)
        x30 = self.relu5_3(x29)
        x31 = self.pool5(x30)
        x32 = self.fc6(x31) # this is a conv layer, this is the output we need
        x33_preflatten = self.relu6(x32)
        x33 = x33_preflatten.view(x33_preflatten.size(0), -1)
        x34 = self.fc7(x33)
        x35 = self.relu7(x34)
        prediction = self.fc8(x35)
        return prediction


def vgg_vd_face_sfew_dag(weights_path=None, **kwargs):
    """
    load imported model instance

    Args:
        weights_path (str): If set, loads model weights from the given path
    """
    model = Vgg_vd_face_sfew_dag()
    if weights_path:
        state_dict = torch.load(weights_path)
        model.load_state_dict(state_dict)
    return model


model_pretrained = vgg_vd_face_sfew_dag(weights_path="/content/gdrive/MyDrive/CV_FER/weights/vgg_vd_face_sfew_dag.pth")

# %%
class GradientReversalFn(Function):
    @staticmethod
    def forward(ctx, x, alpha):
        ctx.alpha = alpha

        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        output = grad_output.neg() * ctx.alpha

        return output, None

class DANN_VGG(nn.Module):
    def __init__(self,
                 model_pretrained = model_pretrained,
                 num_classes=7,
                 dropout_rate = 0.1,
                 ):
        super(DANN_VGG, self).__init__()
        #---------------------Feature Extractor Network------------------------#
        self.feature_extractor = nn.Sequential(*list(model_pretrained.children())[:-4])

        #---------------------Class Classifier------------------------#
        list_class_classifer = list(model_pretrained.children())[-4:]
        list_class_classifer.insert(2, nn.Dropout(dropout_rate))
        # self.class_classifier = nn.Sequential(*list(model_pretrained.children())[-4:])
        self.class_classifier = nn.Sequential(*list_class_classifer)



        #---------------------Domain Classifier------------------------#

        self.domain_classifier = nn.Sequential(nn.ReLU(),
                                               nn.Linear(4096, 4096),
                                               nn.Dropout(dropout_rate),
                                               nn.ReLU(),
                                               nn.Linear(4096, 2)
                                               )

        # Initialize the 4096,4096 to pre-trained
        pretrained_weights = model_pretrained.fc7.weight
        pretrained_biases = model_pretrained.fc7.bias
        with torch.no_grad():
          self.domain_classifier[1].weight.copy_(pretrained_weights)
          self.domain_classifier[1].bias.copy_(pretrained_biases)


    def forward(self, input_data, alpha = 0.0):
        features = self.feature_extractor(input_data)
        # print("features.shape......", features.shape)
        features = features.view(-1,features.size(1))
        # print("features.shape after view......", features.shape)

        reverse_features = GradientReversalFn.apply(features,alpha)

        class_output = self.class_classifier(features)
        domain_output = self.domain_classifier(reverse_features)

        return class_output, domain_output, features

# %%
# from data_config import DataConfig
dataconfig_1 = DataConfig()
MODEL_DIR = dataconfig_1.MODEL_DIR

MODEL_PATH = Path(os.path.join(MODEL_DIR, f'non_dann_{source_name}_{target_name}', model_name))

loaded_model_non_dann =  DANN_VGG(model_pretrained = model_pretrained, num_classes=7)  # skeleton copy
# best_model_dann =  DANN_VGG(model_pretrained = model_pretrained, num_classes=7)# skeleton copy
# best_model_dann_ewc =  DANN_VGG(model_pretrained = model_pretrained, num_classes=7)# skeleton copy

loaded_model_non_dann.load_state_dict(torch.load(MODEL_PATH,map_location=torch.device(device)))

model_dann = deepcopy(loaded_model_non_dann) # saves training time - check with all
model_dann_ewc = deepcopy(loaded_model_non_dann) # saves training time - check with all


# print(model_dann)

# %% [markdown]
# ## Test Function

# %%
def get_correct_preds(prediction, labels):
    """
    Function to return total number of correct predictions
    :param prediction: Model predictions on a given sample of data
    :param labels: Correct labels of a given sample of data
    :return: Number of correct predictions
    """
    return prediction.argmax(dim=1).eq(labels.argmax(dim=1)).sum().item()

def test_model_local(model, device, data_loader, mode= 'test',
               class_loss_function = nn.CrossEntropyLoss() ):
    model.eval() # evaluation mode

    # variables to track loss and accuracy
    test_loss = 0.0
    correct = 0

    # Disable gradient updation
    with torch.no_grad():
        # Iterate over each batch and fetch images and labels from the batch
        for batch_idx, batch in enumerate(data_loader):
            images, labels = batch[0].to(device), batch[1].to(device)

            class_output,_,_  = model((images*255)) # forward pass, output = {class}
            class_loss = class_loss_function(class_output,labels) # Calculate Loss

            test_loss += class_loss.item() # sum up batch loss

            # Sum up batch correct predictions
            correct += get_correct_preds(class_output, labels)

    # Calculate test loss for a epoch
    test_loss /= len(data_loader.dataset)

    print('Test / Val: Average loss: {:.4f}, Accuracy: {}/{} ({:.2f}%)\n'.format(test_loss, correct, len(data_loader.dataset),
        100. * correct / len(data_loader.dataset)))


    return correct, test_loss

# %% [markdown]
# ## DANN Execution: Training, Validating, Saving

# %% [markdown]
# ### DANN Execution Function

# %%
def execute_dann(model,
                 device,
                 source_train_loader, source_val_loader,
                 target_train_loader, target_val_loader,
                 optimizer,
                 n_epochs, # total number of epochs (different from individual epoch)
                 class_loss_function = nn.CrossEntropyLoss(),
                 domain_loss_function = nn.BCEWithLogitsLoss(),
                 scheduler = None,
                 early_stop_patience = None,
                 early_stop_difference = None
                 ):

    train_losses = [] # to capture train losses over training epochs
    val_losses = [] # to capture validation loss over epochs
    list_lr =[] # to capture lr over epochs
    list_val_correct = [] # to capture validation accuracy over epochs
    list_best_val_correct = [] # to capture best validtion accuracy over epochs


    epoch_converge = 0
    max_batches = min(len(source_train_loader), len(target_train_loader)) # Trying to check which is having less batches.
    model = model.to(device)

    # model.apply(weights_init) # TODO: skipping weights update - we can experimentation later on, and see if this helps
    list_alpha =[]


    # for best model
    best_model = deepcopy(model).to(device) # for best model
    best_val_loss = float('inf') # Initialize variables to track the best validation loss
    best_val_acc = 0 # Initialize variable to track best accuracy
    best_model_state = None # Initialize variables to track the best model state


    for epoch_idx in range(n_epochs):
        print(f'epoch = {epoch_idx+1}...in DANN execution function')
        source_iterator = iter(source_train_loader)
        target_iterator = iter (target_train_loader)
        epoch_task_loss = 0
        epoch_domain_loss =  0
        epoch_total_loss = 0
        processed = 0

        for batch_idx in range(max_batches-1):
            # p = float(batch_idx + epoch_idx * max_batches) / (n_epochs * max_batches)
            # alpha = 2. / (1. + np.exp(-10 * p)) - 1
            alpha = 1.0
            list_alpha.append(alpha)
            alpha = torch.tensor(alpha)

            model.train() # everytime ?
            optimizer.zero_grad() # flushing out the accumulated gradients

            #---------------------Source Dataset Training ------------------------#
            source_batch = next(source_iterator)
            source_batch[0] = source_batch[0] * 255.0  # Convert inputs from [0, 1] to [0, 255]

            source_images, source_labels = source_batch[0].to(device), source_batch[1].to(device) # getting images and labels, on device
            source_class_outputs, source_domain_outputs, _ = model(source_images, alpha=alpha) # forward pass, output = {class, domain, feature}


            loss_source_class = class_loss_function(source_class_outputs, source_labels) # calculating class loss

            source_domain_inputs = torch.tensor([1., 0.]*len(source_batch[0])).view(-1,2).to(device) # Source Image == [1., 0.]

            loss_source_domain = domain_loss_function(source_domain_outputs, source_domain_inputs) # calculating domain loss

            processed += len(source_batch[0])

            #---------------------Target Dataset Training ------------------------#
            target_batch = next (target_iterator)
            target_batch[0] = target_batch[0] * 255.0  # Convert inputs from [0, 1] to [0, 255]
            target_images = target_batch[0].to(device) # getting images, on device. There are no labels for target
            _, target_domain_outputs, _ = model(target_images, alpha=alpha) # forward pass, output = {class, domain, feature}

            target_domain_inputs = torch.tensor([0., 1.]*len(source_batch[0])).view(-1,2).to(device)  # Target Image == [0., 1.]
            # print(f' target domain input shape {target_domain_inputs.shape}, output shape {target_domain_outputs.shape}')

            loss_target_domain = domain_loss_function(target_domain_outputs,target_domain_inputs)  # calculating domain loss


            #---------------------Combining Loss ------------------------#
            total_loss = loss_source_class + (loss_source_domain + loss_target_domain) # changed the loss
            total_loss.backward() #backpropogation, creating gradients
            optimizer.step() # updating the params

            epoch_task_loss += loss_source_class.item()
            epoch_domain_loss += loss_source_domain.item() + loss_target_domain.item()
            epoch_total_loss += total_loss.item()

            curr_lr = optimizer.param_groups[0]['lr'] # current learning rate
            list_lr.append(curr_lr)

            # after 10 batches
            if (batch_idx % 10 == 0):
                print("Epoch[{}/{}] Step[{}/{}]: loss_total={:.4f} / domain_loss_target={:.4f} / domain_loss_source={:.4f} / task_loss={:.4f} / domain_loss={:.4f} / alpha={:.2f} / lr={:.6f}"
              .format(epoch_idx + 1,
                      n_epochs,
                      batch_idx + 1,
                      max_batches,
                      total_loss.item(),
                      loss_target_domain.item()
                      ,loss_source_domain.item()
                      ,loss_source_class.item()
                      ,loss_source_domain.item()+loss_source_class.item(),
                      alpha,
                      curr_lr
                      ))
        # After every epoch
        avg_train_task_loss =  float("{:.6f}".format(epoch_task_loss/processed))
        train_losses.append(avg_train_task_loss)

        # #Scheduler
        # if scheduler:
        #   scheduler.step(avg_train_task_loss) ## applying scheduler on training loss

        #Validate Model after every epoch
        correct, avg_val_task_loss = test_model_local(model= model,
                                                device= device,
                                                data_loader = source_val_loader,
                                                class_loss_function = class_loss_function)
        val_losses.append(avg_val_task_loss)

        # # Check if the current model has the best validation loss
        # print(f'Last Epoch Val Loss = {avg_val_task_loss} | Best Val Loss = {best_val_loss}' )
        # if avg_val_task_loss < best_val_loss:
        #   best_val_loss = avg_val_task_loss
        #   # save the current model state as the best model state
        #   best_model_state = deepcopy(model.state_dict())
        #   print(f'Updated the best model with validation loss: {best_val_loss}\n')

        list_val_correct.append(correct)

        #Adding Scheduler #TODO: ADD SCHEDULER
        if scheduler:
          scheduler.step(correct) #applying scheduler on accuracy proxy, i.e. correct


        # check if the current model has the best accuracy
        print (f'last correct ={correct} | best correct = {best_val_acc}')
        if correct > best_val_acc:
          best_val_acc = correct
          # save the current model state as the best model state
          best_model_state = deepcopy(model.state_dict())
          print(f'Updated the best model with correct: {correct}\n')

        list_best_val_correct.append(best_val_acc) # appending the best one for early stopping



        #TODO: Early Stopping
        if early_stop_patience and early_stop_difference: # early stopping required
          if early_stopping_difference(list_val_correct,
                                       patience = early_stop_patience,
                                       difference= early_stop_difference):
            print (f'-------Early Stopping at epoch {epoch_idx+1}---')
            epoch_converge = epoch+1
            break # break from epoch loop

        if early_stop_patience and early_stop_difference: # early stopping based on best accuracy
          if early_stopping_difference(val_losses,
                                       patience = 2*early_stop_patience,
                                       difference= 0):
            print (f'-------Early Stopping at epoch {epoch_idx+1}---')
            epoch_converge = epoch+1
            break # break from epoch loop

            ## showing misclassification images after every 10 epochs
        if epoch_idx % 10 == 0:
          list_misclassified_images = get_misclassified_images_list(model= model,
                                                                    device = device,
                                                                    test_loader = source_val_loader,
                                                                    num_image = 10)
          plot_misclassified_images(list_misclassified_images)


    # Testing when the training is over - completed or early stopped
    ## using params of best model to update model
    if best_model_state: # only update if best model has been saved, else the last one would be picked up
      model.load_state_dict(best_model_state)
      print('Best model loaded')

    correct, test_loss_source = test_model_local(model= model,
                            device= device,
                            data_loader = source_val_loader, # source val loader
                            class_loss_function = class_loss_function)

    correct, test_loss_target = test_model_local(model= model,
                            device= device,
                            data_loader = target_val_loader, # target val loader
                            class_loss_function = class_loss_function)

    dict_dann_losses = {'train_losses' : train_losses,
                        'val_losses': val_losses,
                        'test_loss_source' : test_loss_source,
                        'test_loss_target' : test_loss_target,
                        'epoch_convergence' : epoch_converge,
                        'list_alpha' : list_alpha,
                        'lr':list_lr}

    print(f'alpha list \n {list_alpha}')
    return model, dict_dann_losses

# %% [markdown]
# ### DANN Execution Config

# %%
runconfig = RunConfig()
lr_dann = runconfig.inital_lr
lr_dann = lr_dann
lr_dann = 0.001 # override
optimizer_dann = optim.SGD(model_dann.parameters(), lr = lr_dann, momentum = 0.9)
# n_epochs = runconfig.EPOCHS if int(dict_non_dann_losses['epoch_convergence']) == 0 else int(dict_non_dann_losses['epoch_convergence'])

n_epochs =  3 # override


# # ReduceLRonPlateau Scheduler Params
# scheduler_patience = runconfig.scheduler_patience
# scheduler_factor = runconfig.scheduler_factor
# scheduler_threshold = runconfig.scheduler_threshold
# Early stopping params
# early_stop_patience = runconfig.early_stop_patience
# early_stop_difference = runconfig.early_stop_difference

# ReduceLRonPlateau Scheduler Params
scheduler_patience = 8 #runconfig.scheduler_patience
scheduler_factor = runconfig.scheduler_factor
scheduler_threshold = 25 #runconfig.scheduler_threshold

# Early stopping params
early_stop_patience = 10 #runconfig.early_stop_patience
early_stop_difference = 15 #runconfig.early_stop_difference


# Set up the ReduceLROnPlateau scheduler
# scheduler = ReduceLROnPlateau(optimizer_dann,
#                               mode='min',
#                               factor=scheduler_factor,
#                               patience=scheduler_patience,
#                               threshold = scheduler_threshold,
#                               min_lr=1e-6,
#                               verbose= True)

# Set up the ReduceLROnPlateau scheduler
scheduler = ReduceLROnPlateau(optimizer_dann,
                              # mode='min',
                              mode='max',
                              factor=scheduler_factor,
                              patience=scheduler_patience,
                              threshold = scheduler_threshold,
                              threshold_mode='abs',
                              min_lr=1e-6,
                              verbose= True)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "

# %% [markdown]
# ### DANN Execution

# %%
print(f'------------training started for DANN Model ------------------')

dann_model_trained, dict_dann_losses = execute_dann(model=model_dann,
                                                    device=device,
                                                    source_train_loader = data_loader['source']['train'], #sfew_train_loader,
                                                    source_val_loader = data_loader['source']['val'], #sfew_val_loader,
                                                    target_train_loader = data_loader['target']['train'], #expw_train_loader,
                                                    target_val_loader = data_loader['target']['val'], #expw_val_loader,
                                                    optimizer = optimizer_dann,
                                                    n_epochs = n_epochs,
                                                    class_loss_function = runconfig.criterion_class,
                                                    domain_loss_function = runconfig.criterion_domain,
                                                    scheduler = scheduler,
                                                    early_stop_patience = early_stop_patience,
                                                    early_stop_difference = early_stop_difference
                                                    )
# Out:
# ------------training started for DANN Model ------------------
# epoch = 1...in DANN execution function
# Epoch[1/3] Step[1/58]: loss_total=1.9617 / domain_loss_target=0.6069 / domain_loss_source=0.6989 / task_loss=0.6559 / domain_loss=1.3548 / alpha=1.00 / lr=0.001000
# Epoch[1/3] Step[11/58]: loss_total=1.6246 / domain_loss_target=0.6998 / domain_loss_source=0.6847 / task_loss=0.2402 / domain_loss=0.9248 / alpha=1.00 / lr=0.001000
# Epoch[1/3] Step[21/58]: loss_total=2.6579 / domain_loss_target=0.6641 / domain_loss_source=0.6921 / task_loss=1.3016 / domain_loss=1.9937 / alpha=1.00 / lr=0.001000
# Epoch[1/3] Step[31/58]: loss_total=1.7927 / domain_loss_target=0.6571 / domain_loss_source=0.7849 / task_loss=0.3507 / domain_loss=1.1356 / alpha=1.00 / lr=0.001000
# Epoch[1/3] Step[41/58]: loss_total=1.8139 / domain_loss_target=0.6537 / domain_loss_source=0.7214 / task_loss=0.4388 / domain_loss=1.1602 / alpha=1.00 / lr=0.001000
# Epoch[1/3] Step[51/58]: loss_total=1.9861 / domain_loss_target=0.6494 / domain_loss_source=0.6517 / task_loss=0.6850 / domain_loss=1.3367 / alpha=1.00 / lr=0.001000
# Test / Val: Average loss: 0.1123, Accuracy: 195/419 (46.54%)
#
# last correct =195 | best correct = 0
# Updated the best model with correct: 195
# Streaming output truncated to the last 5000 lines.
# amazed_soldier_216.jpg : cropped image of not found, replacing with original image
# amazed_husband_275.jpg : cropped image of not found, replacing with original image
# astound_actor_659.jpg : cropped image of not found, replacing with original imageamazed_family_421.jpg : cropped image of not found, replacing with original image
#
# distressed_worker_336.jpg : cropped image of not found, replacing with original image
# amazed_grandfather_750.jpg : cropped image of not found, replacing with original image
# distressed_soldier_654.jpg : cropped image of not found, replacing with original image
# crying_american_531.jpg : cropped image of not found, replacing with original image
# amazed_old_926.jpg : cropped image of not found, replacing with original image
# astound_grandfather_483.jpg : cropped image of not found, replacing with original imageheartbroken_mother_381.jpg : cropped image of not found, replacing with original imageawe_american_601.jpg : cropped image of not found, replacing with original image
#
#
# awe_boss_500.jpg : cropped image of not found, replacing with original image
# awe_boy_375.jpg : cropped image of not found, replacing with original image
# fierce_president_303.jpg : cropped image of not found, replacing with original image
# amazed_teacher_812.jpg : cropped image of not found, replacing with original image
# unhappy_expression_220.jpg : cropped image of not found, replacing with original imageheartbroken_president_608.jpg : cropped image of not found, replacing with original image
#
# heartbroken_actor_635.jpg : cropped image of not found, replacing with original image
# awe_family_560.jpg : cropped image of not found, replacing with original image
# astound_man_664.jpg : cropped image of not found, replacing with original image
# astound_teacher_863.jpg : cropped image of not found, replacing with original image
# heartbroken_mother_671.jpg : cropped image of not found, replacing with original image
# angry_manager_413.jpg : cropped image of not found, replacing with original imagecrying_infant_101.jpg : cropped image of not found, replacing with original image
#
# angry_family_42.jpg : cropped image of not found, replacing with original imageamazed_people_151.jpg : cropped image of not found, replacing with original image
#
# amazed_man_511.jpg : cropped image of not found, replacing with original imageheartbroken_woman_389.jpg : cropped image of not found, replacing with original image
#
# astound_infant_714.jpg : cropped image of not found, replacing with original imageamazed_son_368.jpg : cropped image of not found, replacing with original image
#
# awe_american_93.jpg : cropped image of not found, replacing with original image
# heartbroken_soldier_926.jpg : cropped image of not found, replacing with original image
# boring_programmer_443.jpg : cropped image of not found, replacing with original imageangry_infant_64.jpg : cropped image of not found, replacing with original image
#
# amazed_father_256.jpg : cropped image of not found, replacing with original image
# fighting_woman_560.jpg : cropped image of not found, replacing with original image
# mad_infant_272.jpg : cropped image of not found, replacing with original image
# amazed_couple_348.jpg : cropped image of not found, replacing with original image
# amazed_teacher_765.jpg : cropped image of not found, replacing with original image
# angry_girl_143.jpg : cropped image of not found, replacing with original image
# mad_soldier_295.jpg : cropped image of not found, replacing with original image
# hostile_son_565.jpg : cropped image of not found, replacing with original image
# distressed_boss_574.jpg : cropped image of not found, replacing with original image
# crying_family_665.jpg : cropped image of not found, replacing with original image
# distressed_son_503.jpg : cropped image of not found, replacing with original image
# awe_yang_834.jpg : cropped image of not found, replacing with original image
# angry_father_454.jpg : cropped image of not found, replacing with original imageawe_African_295.jpg : cropped image of not found, replacing with original image
#
# awe_wife_378.jpg : cropped image of not found, replacing with original image
# disgust_wife_408.jpg : cropped image of not found, replacing with original imageastound_actor_922.jpg : cropped image of not found, replacing with original image
#
# amazed_student_514.jpg : cropped image of not found, replacing with original image
# distaste_couple_351.jpg : cropped image of not found, replacing with original image
# awe_lady_696.jpg : cropped image of not found, replacing with original image
# crying_soldier_293.jpg : cropped image of not found, replacing with original image
# frightened_yang_972.jpg : cropped image of not found, replacing with original image
# anxious_boy_409.jpg : cropped image of not found, replacing with original image
# angry_infant_211.jpg : cropped image of not found, replacing with original imageafraid_old_367.jpg : cropped image of not found, replacing with original image
#
# disgust_wife_584.jpg : cropped image of not found, replacing with original imageawe_president_296.jpg : cropped image of not found, replacing with original image
# amazed_old_405.jpg : cropped image of not found, replacing with original image
# awe_man_662.jpg : cropped image of not found, replacing with original image
#
# awe_son_316.jpg : cropped image of not found, replacing with original image
# amazed_president_23.jpg : cropped image of not found, replacing with original image
# annoyed_woman_358.jpg : cropped image of not found, replacing with original image
# awe_father_869.jpg : cropped image of not found, replacing with original image
# fierce_european_612.jpg : cropped image of not found, replacing with original image
# awe_president_99.jpg : cropped image of not found, replacing with original image
# awe_father_916.jpg : cropped image of not found, replacing with original image
# amazed_mother_367.jpg : cropped image of not found, replacing with original image
# mad_student_561.jpg : cropped image of not found, replacing with original image
# anxious_grandmother_295.jpg : cropped image of not found, replacing with original image
# hostile_man_537.jpg : cropped image of not found, replacing with original imagehostile_teacher_309.jpg : cropped image of not found, replacing with original image
#
# heartbroken_soldier_692.jpg : cropped image of not found, replacing with original imageawe_programmer_228.jpg : cropped image of not found, replacing with original image
#
# crying_actor_501.jpg : cropped image of not found, replacing with original image
# amazed_president_883.jpg : cropped image of not found, replacing with original image
# astound_grandfather_561.jpg : cropped image of not found, replacing with original image
# hostile_grandmother_799.jpg : cropped image of not found, replacing with original image
# awe_lady_447.jpg : cropped image of not found, replacing with original image
# hostile_worker_369.jpg : cropped image of not found, replacing with original image
# boring_mother_794.jpg : cropped image of not found, replacing with original imageawe_couple_218.jpg : cropped image of not found, replacing with original image
#
# angry_grandmother_868.jpg : cropped image of not found, replacing with original image
# awe_father_951.jpg : cropped image of not found, replacing with original image
# awe_asian_678.jpg : cropped image of not found, replacing with original image
# crying_grandmother_818.jpg : cropped image of not found, replacing with original imagefierce_family_421.jpg : cropped image of not found, replacing with original image
#
# astound_president_494.jpg : cropped image of not found, replacing with original imagehostile_husband_360.jpg : cropped image of not found, replacing with original image
#
# crying_black_50.jpg : cropped image of not found, replacing with original image
# amazed_woman_201.jpg : cropped image of not found, replacing with original image
# awe_president_529.jpg : cropped image of not found, replacing with original image
# angry_american_599.jpg : cropped image of not found, replacing with original imageawe_actor_679.jpg : cropped image of not found, replacing with original image
#
# distressed_president_271.jpg : cropped image of not found, replacing with original image
# astound_worker_726.jpg : cropped image of not found, replacing with original image
# awe_soldier_199.jpg : cropped image of not found, replacing with original image
# hostile_president_116.jpg : cropped image of not found, replacing with original image
# annoyed_soldier_628.jpg : cropped image of not found, replacing with original image
# fighting_actor_655.jpg : cropped image of not found, replacing with original imageamazed_woman_308.jpg : cropped image of not found, replacing with original image
#
# angry_old_208.jpg : cropped image of not found, replacing with original image
# fighting_mother_67.jpg : cropped image of not found, replacing with original image
# disgust_family_294.jpg : cropped image of not found, replacing with original image
# heartbroken_soldier_862.jpg : cropped image of not found, replacing with original imageangry_black_388.jpg : cropped image of not found, replacing with original image
#
# mad_husband_636.jpg : cropped image of not found, replacing with original image
# amazed_black_107.jpg : cropped image of not found, replacing with original image
# crying_programmer_459.jpg : cropped image of not found, replacing with original imageastound_programmer_789.jpg : cropped image of not found, replacing with original image
# heartbroken_yang_909.jpg : cropped image of not found, replacing with original image
#
# awe_African_121.jpg : cropped image of not found, replacing with original image
# awe_actor_656.jpg : cropped image of not found, replacing with original image
# astound_husband_737.jpg : cropped image of not found, replacing with original imagefighting_boss_209.jpg : cropped image of not found, replacing with original image
# hostile_lady_158.jpg : cropped image of not found, replacing with original image
# awe_boss_272.jpg : cropped image of not found, replacing with original image
#
# amazed_mother_922.jpg : cropped image of not found, replacing with original imageawe_manager_377.jpg : cropped image of not found, replacing with original image
#
# amazed_family_586.jpg : cropped image of not found, replacing with original image
# annoyed_soldier_804.jpg : cropped image of not found, replacing with original image
# amazed_worker_812.jpg : cropped image of not found, replacing with original image
# amazed_president_198.jpg : cropped image of not found, replacing with original image
# heartbroken_president_892.jpg : cropped image of not found, replacing with original image
# awe_teacher_192.jpg : cropped image of not found, replacing with original image
# heartbroken_american_300.jpg : cropped image of not found, replacing with original imageheartbroken_mother_742.jpg : cropped image of not found, replacing with original image
#
# fierce_people_354.jpg : cropped image of not found, replacing with original image
# astound_manager_61.jpg : cropped image of not found, replacing with original image
# hostile_expression_515.jpg : cropped image of not found, replacing with original image
# crying_boss_150.jpg : cropped image of not found, replacing with original image
# awe_actor_196.jpg : cropped image of not found, replacing with original image
# mad_boy_232.jpg : cropped image of not found, replacing with original imageawe_father_421.jpg : cropped image of not found, replacing with original imageafraid_boy_8.jpg : cropped image of not found, replacing with original image
#
#
# amazed_son_393.jpg : cropped image of not found, replacing with original imageastound_expression_136.jpg : cropped image of not found, replacing with original image
#
# fierce_teacher_85.jpg : cropped image of not found, replacing with original image
# excited_asian_324.jpg : cropped image of not found, replacing with original image
# amazed_infant_732.jpg : cropped image of not found, replacing with original image
# astound_grandmother_771.jpg : cropped image of not found, replacing with original imageamazed_yang_825.jpg : cropped image of not found, replacing with original image
#
# astound_woman_767.jpg : cropped image of not found, replacing with original image
# amazed_american_727.jpg : cropped image of not found, replacing with original image
# awe_boy_74.jpg : cropped image of not found, replacing with original image
# angry_father_53.jpg : cropped image of not found, replacing with original image
# amazed_family_476.jpg : cropped image of not found, replacing with original image
# astound_yang_905.jpg : cropped image of not found, replacing with original image
# amazed_actor_795.jpg : cropped image of not found, replacing with original image
# annoyed_chinese_165.jpg : cropped image of not found, replacing with original imageawe_face_593.jpg : cropped image of not found, replacing with original image
#
# amazed_president_318.jpg : cropped image of not found, replacing with original image
# distressed_student_546.jpg : cropped image of not found, replacing with original image
# shocked_expression_167.jpg : cropped image of not found, replacing with original imageawe_worker_560.jpg : cropped image of not found, replacing with original image
#
# distressed_soldier_334.jpg : cropped image of not found, replacing with original image
# amazed_worker_303.jpg : cropped image of not found, replacing with original image
# amazed_teacher_560.jpg : cropped image of not found, replacing with original image
# frightened_by_the_movie_mother_701.jpg : cropped image of not found, replacing with original image
# crying_boss_499.jpg : cropped image of not found, replacing with original image
# annoyed_African_928.jpg : cropped image of not found, replacing with original image
# heartbroken_son_524.jpg : cropped image of not found, replacing with original imageastound_student_186.jpg : cropped image of not found, replacing with original image
#
# mad_president_483.jpg : cropped image of not found, replacing with original image
# awe_grandfather_141.jpg : cropped image of not found, replacing with original image
# heartbroken_mother_682.jpg : cropped image of not found, replacing with original image
# amazed_worker_795.jpg : cropped image of not found, replacing with original image
# amazed_son_701.jpg : cropped image of not found, replacing with original image
# crying_student_26.jpg : cropped image of not found, replacing with original image
# awe_face_427.jpg : cropped image of not found, replacing with original image
# amazed_actor_578.jpg : cropped image of not found, replacing with original imagemad_infant_677.jpg : cropped image of not found, replacing with original image
#
# crying_woman_98.jpg : cropped image of not found, replacing with original imagehostile_president_215.jpg : cropped image of not found, replacing with original image
#
# amazed_soldier_545.jpg : cropped image of not found, replacing with original image
# frightened_by_the_movie_grandfather_252.jpg : cropped image of not found, replacing with original image
# distaste_president_503.jpg : cropped image of not found, replacing with original imagedistaste_manager_140.jpg : cropped image of not found, replacing with original image
#
# mad_face_117.jpg : cropped image of not found, replacing with original image
# astound_grandmother_905.jpg : cropped image of not found, replacing with original image
# fierce_couple_313.jpg : cropped image of not found, replacing with original image
# astound_student_850.jpg : cropped image of not found, replacing with original imagefighting_president_433.jpg : cropped image of not found, replacing with original image
#
# amazed_woman_236.jpg : cropped image of not found, replacing with original image
# annoyed_lady_767.jpg : cropped image of not found, replacing with original image
# heartbroken_man_83.jpg : cropped image of not found, replacing with original image
# fierce_woman_769.jpg : cropped image of not found, replacing with original imagedisgust_lady_247.jpg : cropped image of not found, replacing with original image
#
# amazed_old_4.jpg : cropped image of not found, replacing with original imageamazed_wife_412.jpg : cropped image of not found, replacing with original image
#
# amazed_american_416.jpg : cropped image of not found, replacing with original image
# crying_wife_668.jpg : cropped image of not found, replacing with original imageheartbroken_programmer_843.jpg : cropped image of not found, replacing with original imageannoyed_mother_720.jpg : cropped image of not found, replacing with original image
#
#
# awe_president_177.jpg : cropped image of not found, replacing with original image
# annoyed_president_509.jpg : cropped image of not found, replacing with original imageheartbroken_programmer_267.jpg : cropped image of not found, replacing with original image
#
# angry_american_415.jpg : cropped image of not found, replacing with original imageawe_president_615.jpg : cropped image of not found, replacing with original image
# astound_husband_215.jpg : cropped image of not found, replacing with original image
#
# expressionless_family_20.jpg : cropped image of not found, replacing with original image
# heartbroken_old_365.jpg : cropped image of not found, replacing with original image
# distressed_teacher_824.jpg : cropped image of not found, replacing with original image
# amazed_american_657.jpg : cropped image of not found, replacing with original image
# amazed_son_233.jpg : cropped image of not found, replacing with original image
# mad_old_61.jpg : cropped image of not found, replacing with original image
# amazed_asian_480.jpg : cropped image of not found, replacing with original image
# amazed_girl_302.jpg : cropped image of not found, replacing with original image
# amazed_european_654.jpg : cropped image of not found, replacing with original imageamazed_actor_41.jpg : cropped image of not found, replacing with original image
#
# hostile_chinese_676.jpg : cropped image of not found, replacing with original image
# amazed_chinese_705.jpg : cropped image of not found, replacing with original imageawe_grandfather_136.jpg : cropped image of not found, replacing with original image
#
# fighting_woman_391.jpg : cropped image of not found, replacing with original image
# disgust_face_189.jpg : cropped image of not found, replacing with original image
# mad_mother_739.jpg : cropped image of not found, replacing with original image
# astound_infant_718.jpg : cropped image of not found, replacing with original imagedistressed_boss_773.jpg : cropped image of not found, replacing with original image
#
# fierce_mother_22.jpg : cropped image of not found, replacing with original imageastound_woman_465.jpg : cropped image of not found, replacing with original image
#
# angry_grandmother_606.jpg : cropped image of not found, replacing with original imageamazed_couple_416.jpg : cropped image of not found, replacing with original image
#
# angry_grandfather_530.jpg : cropped image of not found, replacing with original image
# fierce_couple_599.jpg : cropped image of not found, replacing with original image
# angry_infant_308.jpg : cropped image of not found, replacing with original image
# distressed_chinese_907.jpg : cropped image of not found, replacing with original image
# frightened_lady_799.jpg : cropped image of not found, replacing with original imagesurprised_expression_468.jpg : cropped image of not found, replacing with original image
#
# awe_expression_659.jpg : cropped image of not found, replacing with original image
# annoyed_people_417.jpg : cropped image of not found, replacing with original image
# ecstatic_infant_382.jpg : cropped image of not found, replacing with original image
# amazed_African_192.jpg : cropped image of not found, replacing with original image
# crying_grandfather_800.jpg : cropped image of not found, replacing with original image
# amazed_yang_812.jpg : cropped image of not found, replacing with original image
# mad_programmer_822.jpg : cropped image of not found, replacing with original image
# amazed_African_19.jpg : cropped image of not found, replacing with original image
# crying_son_258.jpg : cropped image of not found, replacing with original imagecrying_boy_510.jpg : cropped image of not found, replacing with original image
#
# awe_asian_113.jpg : cropped image of not found, replacing with original imagecrying_president_476.jpg : cropped image of not found, replacing with original image
#
# annoyed_girl_234.jpg : cropped image of not found, replacing with original image
# astound_grandmother_636.jpg : cropped image of not found, replacing with original image
# frightened_by_the_movie_family_255.jpg : cropped image of not found, replacing with original image
# amazed_people_4.jpg : cropped image of not found, replacing with original image
# amazed_mother_584.jpg : cropped image of not found, replacing with original image
# angry_old_2.jpg : cropped image of not found, replacing with original image
# frightened_girl_186.jpg : cropped image of not found, replacing with original image
# amazed_yang_532.jpg : cropped image of not found, replacing with original image
# distressed_wife_346.jpg : cropped image of not found, replacing with original image
# fierce_grandfather_402.jpg : cropped image of not found, replacing with original image
# heartbroken_american_414.jpg : cropped image of not found, replacing with original imageafraid_African_214.jpg : cropped image of not found, replacing with original image
#
# awe_boss_251.jpg : cropped image of not found, replacing with original image
# hostile_grandmother_446.jpg : cropped image of not found, replacing with original image
# annoyed_american_585.jpg : cropped image of not found, replacing with original image
# angry_student_229.jpg : cropped image of not found, replacing with original image
# awe_manager_510.jpg : cropped image of not found, replacing with original imageannoyed_African_596.jpg : cropped image of not found, replacing with original image
#
# expressionless_president_191.jpg : cropped image of not found, replacing with original image
# awe_people_263.jpg : cropped image of not found, replacing with original image
# amazed_man_66.jpg : cropped image of not found, replacing with original image
# awe_president_815.jpg : cropped image of not found, replacing with original imagehostile_people_318.jpg : cropped image of not found, replacing with original image
#
# hostile_wife_255.jpg : cropped image of not found, replacing with original image
# astound_teacher_509.jpg : cropped image of not found, replacing with original image
# mad_bos_470.jpg : cropped image of not found, replacing with original image
# amazed_grandfather_827.jpg : cropped image of not found, replacing with original imageangry_student_752.jpg : cropped image of not found, replacing with original image
#
# awe_soldier_178.jpg : cropped image of not found, replacing with original image
# hostile_actor_590.jpg : cropped image of not found, replacing with original image
# awe_manager_371.jpg : cropped image of not found, replacing with original imagefighting_manager_845.jpg : cropped image of not found, replacing with original image
#
# crying_African_262.jpg : cropped image of not found, replacing with original image
# awe_wife_602.jpg : cropped image of not found, replacing with original imageamazed_manager_407.jpg : cropped image of not found, replacing with original image
#
# boring_soldier_329.jpg : cropped image of not found, replacing with original image
# anxious_African_983.jpg : cropped image of not found, replacing with original imageamazed_African_735.jpg : cropped image of not found, replacing with original image
#
# awe_son_726.jpg : cropped image of not found, replacing with original image
# fierce_African_187.jpg : cropped image of not found, replacing with original image
# astound_asian_487.jpg : cropped image of not found, replacing with original image
# awe_manager_511.jpg : cropped image of not found, replacing with original image
# awe_boss_718.jpg : cropped image of not found, replacing with original image
# awe_face_311.jpg : cropped image of not found, replacing with original image
# frightened_by_the_movie_expression_116.jpg : cropped image of not found, replacing with original image
# amazed_boy_252.jpg : cropped image of not found, replacing with original image
# heartbroken_student_435.jpg : cropped image of not found, replacing with original image
# awe_worker_533.jpg : cropped image of not found, replacing with original image
# astound_boy_385.jpg : cropped image of not found, replacing with original image
# awe_teacher_271.jpg : cropped image of not found, replacing with original image
# boring_asian_595.jpg : cropped image of not found, replacing with original image
# awe_mother_357.jpg : cropped image of not found, replacing with original image
# amazed_infant_503.jpg : cropped image of not found, replacing with original image
# awe_people_236.jpg : cropped image of not found, replacing with original image
# amazed_chinese_12.jpg : cropped image of not found, replacing with original image
# angry_actor_622.jpg : cropped image of not found, replacing with original image
# angry_european_197.jpg : cropped image of not found, replacing with original image
# amazed_manager_411.jpg : cropped image of not found, replacing with original imageawe_actor_817.jpg : cropped image of not found, replacing with original image
#
# mad_american_540.jpg : cropped image of not found, replacing with original imageawe_american_416.jpg : cropped image of not found, replacing with original image
#
# amazed_soldier_959.jpg : cropped image of not found, replacing with original imagefierce_worker_347.jpg : cropped image of not found, replacing with original image
#
# amazed_man_263.jpg : cropped image of not found, replacing with original image
# fighting_family_348.jpg : cropped image of not found, replacing with original image
# distaste_lady_521.jpg : cropped image of not found, replacing with original image
# heartbroken_president_119.jpg : cropped image of not found, replacing with original image
# awe_girl_716.jpg : cropped image of not found, replacing with original image
# awe_american_480.jpg : cropped image of not found, replacing with original image
# fighting_manager_66.jpg : cropped image of not found, replacing with original image
# amazed_american_76.jpg : cropped image of not found, replacing with original image
# amazed_grandmother_240.jpg : cropped image of not found, replacing with original image
# heartbroken_yang_690.jpg : cropped image of not found, replacing with original imageawe_grandmother_324.jpg : cropped image of not found, replacing with original image
#
# crying_actor_704.jpg : cropped image of not found, replacing with original image
# fighting_face_47.jpg : cropped image of not found, replacing with original imagedistressed_lady_35.jpg : cropped image of not found, replacing with original image
#
# disgust_face_319.jpg : cropped image of not found, replacing with original image
# awe_worker_292.jpg : cropped image of not found, replacing with original image
# awe_teacher_64.jpg : cropped image of not found, replacing with original image
# heartbroken_father_366.jpg : cropped image of not found, replacing with original image
# fighting_president_592.jpg : cropped image of not found, replacing with original image
# astound_european_242.jpg : cropped image of not found, replacing with original image
# frightened_by_the_movie_european_143.jpg : cropped image of not found, replacing with original image
# crying_mother_17.jpg : cropped image of not found, replacing with original image
# amazed_lady_157.jpg : cropped image of not found, replacing with original image
# heartbroken_american_749.jpg : cropped image of not found, replacing with original image
# distressed_soldier_144.jpg : cropped image of not found, replacing with original imageawe_son_757.jpg : cropped image of not found, replacing with original image
#
# distaste_black_875.jpg : cropped image of not found, replacing with original image
# amazed_infant_337.jpg : cropped image of not found, replacing with original imageamazed_president_516.jpg : cropped image of not found, replacing with original image
#
# awe_chinese_534.jpg : cropped image of not found, replacing with original image
# heartbroken_people_471.jpg : cropped image of not found, replacing with original image
# amazed_mother_618.jpg : cropped image of not found, replacing with original image
# crying_student_398.jpg : cropped image of not found, replacing with original image
# anxious_couple_321.jpg : cropped image of not found, replacing with original imageawe_programmer_269.jpg : cropped image of not found, replacing with original image
#
# hostile_manager_31.jpg : cropped image of not found, replacing with original image
# amazed_manager_111.jpg : cropped image of not found, replacing with original imageangry_son_383.jpg : cropped image of not found, replacing with original image
#
# awe_boy_374.jpg : cropped image of not found, replacing with original image
# angry_black_49.jpg : cropped image of not found, replacing with original image
# amazed_boy_122.jpg : cropped image of not found, replacing with original image
# astound_grandfather_710.jpg : cropped image of not found, replacing with original image
# fierce_face_143.jpg : cropped image of not found, replacing with original image
# crying_face_482.jpg : cropped image of not found, replacing with original image
# awe_grandmother_55.jpg : cropped image of not found, replacing with original image
# amazed_chinese_620.jpg : cropped image of not found, replacing with original image
# distressed_boy_155.jpg : cropped image of not found, replacing with original image
# crying_expression_297.jpg : cropped image of not found, replacing with original image
# awe_son_114.jpg : cropped image of not found, replacing with original image
# distressed_worker_528.jpg : cropped image of not found, replacing with original image
# awe_teacher_480.jpg : cropped image of not found, replacing with original imageastound_woman_523.jpg : cropped image of not found, replacing with original image
#
# distressed_expression_58.jpg : cropped image of not found, replacing with original image
# crying_asian_136.jpg : cropped image of not found, replacing with original image
# crying_chinese_173.jpg : cropped image of not found, replacing with original image
# crying_old_499.jpg : cropped image of not found, replacing with original image
# awe_actor_420.jpg : cropped image of not found, replacing with original imageannoyed_boy_231.jpg : cropped image of not found, replacing with original image
#
# amazed_soldier_434.jpg : cropped image of not found, replacing with original image
# hostile_old_251.jpg : cropped image of not found, replacing with original imagecrying_student_440.jpg : cropped image of not found, replacing with original image
#
# amazed_couple_125.jpg : cropped image of not found, replacing with original image
# heartbroken_African_332.jpg : cropped image of not found, replacing with original image
# boring_wife_902.jpg : cropped image of not found, replacing with original image
# amazed_chinese_422.jpg : cropped image of not found, replacing with original image
# awe_people_68.jpg : cropped image of not found, replacing with original imagecrying_teacher_642.jpg : cropped image of not found, replacing with original image
#
# awe_African_326.jpg : cropped image of not found, replacing with original image
# astound_manager_937.jpg : cropped image of not found, replacing with original image
# hostile_teacher_819.jpg : cropped image of not found, replacing with original image
# amazed_worker_956.jpg : cropped image of not found, replacing with original imagemad_actor_311.jpg : cropped image of not found, replacing with original image
#
# heartbroken_president_112.jpg : cropped image of not found, replacing with original image
# angry_girl_131.jpg : cropped image of not found, replacing with original image
# mad_wife_498.jpg : cropped image of not found, replacing with original image
# crying_wife_691.jpg : cropped image of not found, replacing with original imagedistressed_father_179.jpg : cropped image of not found, replacing with original image
#
# anxious_expression_373.jpg : cropped image of not found, replacing with original imageanxious_lady_23.jpg : cropped image of not found, replacing with original image
#
# angry_grandfather_105.jpg : cropped image of not found, replacing with original image
# awe_couple_215.jpg : cropped image of not found, replacing with original image
# astound_wife_306.jpg : cropped image of not found, replacing with original image
# amazed_teacher_45.jpg : cropped image of not found, replacing with original image
# heartbroken_actor_758.jpg : cropped image of not found, replacing with original image
# distressed_grandmother_816.jpg : cropped image of not found, replacing with original image
# crying_chinese_659.jpg : cropped image of not found, replacing with original image
# awe_worker_289.jpg : cropped image of not found, replacing with original imageawe_student_416.jpg : cropped image of not found, replacing with original image
#
# awe_old_754.jpg : cropped image of not found, replacing with original image
# amazed_African_293.jpg : cropped image of not found, replacing with original image
# fierce_student_62.jpg : cropped image of not found, replacing with original image
# amazed_black_166.jpg : cropped image of not found, replacing with original image
# annoyed_student_128.jpg : cropped image of not found, replacing with original image
# awe_husband_908.jpg : cropped image of not found, replacing with original image
# awe_grandmother_106.jpg : cropped image of not found, replacing with original imagemad_family_240.jpg : cropped image of not found, replacing with original image
# amazed_girl_372.jpg : cropped image of not found, replacing with original image
#
# disgust_european_382.jpg : cropped image of not found, replacing with original image
# heartbroken_infant_867.jpg : cropped image of not found, replacing with original image
# distaste_actor_495.jpg : cropped image of not found, replacing with original image
# amazed_wife_157.jpg : cropped image of not found, replacing with original image
# crying_husband_414.jpg : cropped image of not found, replacing with original image
# anxious_man_217.jpg : cropped image of not found, replacing with original image
# heartbroken_father_67.jpg : cropped image of not found, replacing with original imageawe_student_455.jpg : cropped image of not found, replacing with original image
#
# amazed_grandfather_894.jpg : cropped image of not found, replacing with original image
# expressionless_girl_511.jpg : cropped image of not found, replacing with original imagedistressed_couple_15.jpg : cropped image of not found, replacing with original image
# heartbroken_black_162.jpg : cropped image of not found, replacing with original image
# awe_expression_86.jpg : cropped image of not found, replacing with original image
#
# fighting_student_199.jpg : cropped image of not found, replacing with original image
# astound_manager_738.jpg : cropped image of not found, replacing with original imagedistressed_infant_337.jpg : cropped image of not found, replacing with original image
#
# awe_husband_465.jpg : cropped image of not found, replacing with original image
# amazed_son_959.jpg : cropped image of not found, replacing with original imageawe_couple_239.jpg : cropped image of not found, replacing with original image
#
# hostile_european_132.jpg : cropped image of not found, replacing with original image
# fighting_couple_88.jpg : cropped image of not found, replacing with original image
# disgust_american_307.jpg : cropped image of not found, replacing with original imagemad_student_451.jpg : cropped image of not found, replacing with original image
#
# astound_mother_376.jpg : cropped image of not found, replacing with original imagehostile_manager_233.jpg : cropped image of not found, replacing with original image
#
# fighting_couple_221.jpg : cropped image of not found, replacing with original imageastound_american_535.jpg : cropped image of not found, replacing with original image
# crying_actor_116.jpg : cropped image of not found, replacing with original image
#
# amazed_chinese_708.jpg : cropped image of not found, replacing with original image
# hostile_old_516.jpg : cropped image of not found, replacing with original imageamazed_yang_21.jpg : cropped image of not found, replacing with original image
#
# astound_people_178.jpg : cropped image of not found, replacing with original image
# distressed_actor_133.jpg : cropped image of not found, replacing with original image
# astound_asian_876.jpg : cropped image of not found, replacing with original image
# amazed_manager_17.jpg : cropped image of not found, replacing with original image
# anxious_father_360.jpg : cropped image of not found, replacing with original image
# mad_yang_57.jpg : cropped image of not found, replacing with original image
# heartbroken_lady_850.jpg : cropped image of not found, replacing with original image
# amazed_president_33.jpg : cropped image of not found, replacing with original image
# distressed_expression_582.jpg : cropped image of not found, replacing with original image
# amazed_couple_435.jpg : cropped image of not found, replacing with original image
# crying_black_174.jpg : cropped image of not found, replacing with original image
# heartbroken_asian_394.jpg : cropped image of not found, replacing with original image
# crying_grandmother_175.jpg : cropped image of not found, replacing with original image
# mad_president_241.jpg : cropped image of not found, replacing with original image
# heartbroken_actor_539.jpg : cropped image of not found, replacing with original image
# angry_girl_268.jpg : cropped image of not found, replacing with original image
# angry_couple_229.jpg : cropped image of not found, replacing with original imageheartbroken_teacher_11.jpg : cropped image of not found, replacing with original image
#
# annoyed_wife_654.jpg : cropped image of not found, replacing with original image
# excited_black_448.jpg : cropped image of not found, replacing with original image
# mad_people_329.jpg : cropped image of not found, replacing with original image
# astound_actor_159.jpg : cropped image of not found, replacing with original image
# crying_lady_521.jpg : cropped image of not found, replacing with original image
# angry_chinese_332.jpg : cropped image of not found, replacing with original image
# fighting_old_683.jpg : cropped image of not found, replacing with original image
# astound_boy_441.jpg : cropped image of not found, replacing with original image
# heartbroken_mother_490.jpg : cropped image of not found, replacing with original image
# astound_father_481.jpg : cropped image of not found, replacing with original image
# heartbroken_boss_437.jpg : cropped image of not found, replacing with original image
# annoyed_husband_842.jpg : cropped image of not found, replacing with original image
# awe_lady_546.jpg : cropped image of not found, replacing with original imagefrightened_girl_228.jpg : cropped image of not found, replacing with original image
#
# boring_son_309.jpg : cropped image of not found, replacing with original image
# frightened_by_the_movie_old_390.jpg : cropped image of not found, replacing with original imagecrying_president_574.jpg : cropped image of not found, replacing with original image
#
# awe_couple_73.jpg : cropped image of not found, replacing with original image
# amazed_european_44.jpg : cropped image of not found, replacing with original image
# amazed_lady_631.jpg : cropped image of not found, replacing with original image
# awe_yang_207.jpg : cropped image of not found, replacing with original image
# angry_expression_154.jpg : cropped image of not found, replacing with original image
# astound_family_489.jpg : cropped image of not found, replacing with original image
# mad_bos_295.jpg : cropped image of not found, replacing with original image
# awe_student_344.jpg : cropped image of not found, replacing with original imagefrightened_by_the_movie_son_991.jpg : cropped image of not found, replacing with original image
# amazed_family_69.jpg : cropped image of not found, replacing with original image
#
# amazed_infant_400.jpg : cropped image of not found, replacing with original image
# awe_teacher_427.jpg : cropped image of not found, replacing with original imageastound_lady_741.jpg : cropped image of not found, replacing with original image
#
# distressed_man_155.jpg : cropped image of not found, replacing with original image
# astound_boss_174.jpg : cropped image of not found, replacing with original imageawe_lady_556.jpg : cropped image of not found, replacing with original imageawe_teacher_429.jpg : cropped image of not found, replacing with original image
#
#
# fierce_manager_419.jpg : cropped image of not found, replacing with original imageawe_manager_697.jpg : cropped image of not found, replacing with original image
#
# hostile_boss_289.jpg : cropped image of not found, replacing with original image
# angry_asian_224.jpg : cropped image of not found, replacing with original image
# annoyed_lady_296.jpg : cropped image of not found, replacing with original image
# awe_soldier_18.jpg : cropped image of not found, replacing with original image
# angry_girl_279.jpg : cropped image of not found, replacing with original image
# annoyed_girl_40.jpg : cropped image of not found, replacing with original imageamazed_couple_126.jpg : cropped image of not found, replacing with original image
#
# awe_wife_671.jpg : cropped image of not found, replacing with original image
# amazed_woman_267.jpg : cropped image of not found, replacing with original image
# fighting_grandmother_105.jpg : cropped image of not found, replacing with original image
# astound_american_751.jpg : cropped image of not found, replacing with original image
# astound_programmer_21.jpg : cropped image of not found, replacing with original image
# awe_actor_844.jpg : cropped image of not found, replacing with original imageamazed_face_558.jpg : cropped image of not found, replacing with original image
#
# amazed_father_835.jpg : cropped image of not found, replacing with original image
# awe_family_339.jpg : cropped image of not found, replacing with original image
# heartbroken_woman_52.jpg : cropped image of not found, replacing with original image
# annoyed_boss_219.jpg : cropped image of not found, replacing with original image
# fighting_american_647.jpg : cropped image of not found, replacing with original image
# crying_teacher_92.jpg : cropped image of not found, replacing with original image
# mad_president_798.jpg : cropped image of not found, replacing with original image
# amazed_boss_12.jpg : cropped image of not found, replacing with original image
# awe_man_152.jpg : cropped image of not found, replacing with original image
# fierce_president_604.jpg : cropped image of not found, replacing with original image
# angry_boss_446.jpg : cropped image of not found, replacing with original image
# heartbroken_asian_657.jpg : cropped image of not found, replacing with original image
# annoyed_programmer_242.jpg : cropped image of not found, replacing with original imageangry_manager_263.jpg : cropped image of not found, replacing with original image
#
# amazed_family_74.jpg : cropped image of not found, replacing with original image
# mad_asian_308.jpg : cropped image of not found, replacing with original image
# awe_soldier_228.jpg : cropped image of not found, replacing with original image
# angry_worker_335.jpg : cropped image of not found, replacing with original imageawe_father_815.jpg : cropped image of not found, replacing with original image
#
# astound_husband_507.jpg : cropped image of not found, replacing with original image
# hostile_grandfather_563.jpg : cropped image of not found, replacing with original imageamazed_family_673.jpg : cropped image of not found, replacing with original image
#
# mad_student_161.jpg : cropped image of not found, replacing with original image
# amazed_woman_344.jpg : cropped image of not found, replacing with original image
# heartbroken_grandmother_718.jpg : cropped image of not found, replacing with original image
# astound_manager_509.jpg : cropped image of not found, replacing with original image
# heartbroken_girl_274.jpg : cropped image of not found, replacing with original image
# awe_expression_350.jpg : cropped image of not found, replacing with original image
# distaste_grandmother_277.jpg : cropped image of not found, replacing with original imageawe_old_412.jpg : cropped image of not found, replacing with original image
# astound_grandfather_515.jpg : cropped image of not found, replacing with original image
#
# heartbroken_chinese_907.jpg : cropped image of not found, replacing with original image
# amazed_student_223.jpg : cropped image of not found, replacing with original image
# amazed_father_387.jpg : cropped image of not found, replacing with original imagefrightened_by_the_movie_black_272.jpg : cropped image of not found, replacing with original image
#
# astound_expression_183.jpg : cropped image of not found, replacing with original imageamazed_asian_227.jpg : cropped image of not found, replacing with original image
#
# heartbroken_people_829.jpg : cropped image of not found, replacing with original image
# amazed_asian_728.jpg : cropped image of not found, replacing with original image
# amazed_grandfather_742.jpg : cropped image of not found, replacing with original imageawe_worker_97.jpg : cropped image of not found, replacing with original image
#
# awe_husband_85.jpg : cropped image of not found, replacing with original image
# crying_asian_302.jpg : cropped image of not found, replacing with original imageangry_grandfather_419.jpg : cropped image of not found, replacing with original imageannoyed_African_730.jpg : cropped image of not found, replacing with original image
#
#
# astound_actor_739.jpg : cropped image of not found, replacing with original imageamazed_African_58.jpg : cropped image of not found, replacing with original imagedisgust_teacher_745.jpg : cropped image of not found, replacing with original image
#
#
# heartbroken_old_11.jpg : cropped image of not found, replacing with original image
# angry_husband_711.jpg : cropped image of not found, replacing with original imageboring_boss_58.jpg : cropped image of not found, replacing with original image
#
# amazed_girl_264.jpg : cropped image of not found, replacing with original imageangry_people_96.jpg : cropped image of not found, replacing with original image
#
# hostile_chinese_208.jpg : cropped image of not found, replacing with original imagehostile_grandmother_654.jpg : cropped image of not found, replacing with original image
#
# distressed_people_514.jpg : cropped image of not found, replacing with original imageamazed_programmer_36.jpg : cropped image of not found, replacing with original image
#
# amazed_mother_45.jpg : cropped image of not found, replacing with original image
# excited_boy_114.jpg : cropped image of not found, replacing with original image
# fear_old_252.jpg : cropped image of not found, replacing with original imagefighting_president_542.jpg : cropped image of not found, replacing with original image
#
# angry_worker_274.jpg : cropped image of not found, replacing with original image
# ...
# hostile_boss_70.jpg : cropped image of not found, replacing with original image
# mad_european_214.jpg : cropped image of not found, replacing with original image
# awe_actor_451.jpg : cropped image of not found, replacing with original image
# amazed_wife_611.jpg : cropped image of not found, replacing with original image
# crying_black_663.jpg : cropped image of not found, replacing with original image
# awe_worker_329.jpg : cropped image of not found, replacing with original image
# fierce_european_268.jpg : cropped image of not found, replacing with original image
# awe_couple_234.jpg : cropped image of not found, replacing with original image
# crying_soldier_271.jpg : cropped image of not found, replacing with original image
# angry_actor_592.jpg : cropped image of not found, replacing with original image
# amazed_president_439.jpg : cropped image of not found, replacing with original image
# heartbroken_yang_233.jpg : cropped image of not found, replacing with original image
# mad_student_620.jpg : cropped image of not found, replacing with original image
# fighting_grandmother_444.jpg : cropped image of not found, replacing with original image
# amazed_american_297.jpg : cropped image of not found, replacing with original image
# fierce_family_170.jpg : cropped image of not found, replacing with original image
# distressed_girl_143.jpg : cropped image of not found, replacing with original image
# astound_woman_871.jpg : cropped image of not found, replacing with original imageamazed_family_262.jpg : cropped image of not found, replacing with original image
#
# amazed_chinese_139.jpg : cropped image of not found, replacing with original image
# awe_teacher_115.jpg : cropped image of not found, replacing with original image
# annoyed_son_162.jpg : cropped image of not found, replacing with original imagecrying_girl_1.jpg : cropped image of not found, replacing with original image
#
# crying_couple_615.jpg : cropped image of not found, replacing with original image
# astound_worker_991.jpg : cropped image of not found, replacing with original image
# amazed_expression_148.jpg : cropped image of not found, replacing with original image
# awe_actor_288.jpg : cropped image of not found, replacing with original imageamazed_president_15.jpg : cropped image of not found, replacing with original imagecrying_mother_739.jpg : cropped image of not found, replacing with original image
#
#
# annoyed_actor_77.jpg : cropped image of not found, replacing with original image
# astound_husband_291.jpg : cropped image of not found, replacing with original image
# awe_student_775.jpg : cropped image of not found, replacing with original image
# amazed_lady_386.jpg : cropped image of not found, replacing with original imageamazed_yang_939.jpg : cropped image of not found, replacing with original image
#
# amazed_manager_124.jpg : cropped image of not found, replacing with original image
# hostile_wife_765.jpg : cropped image of not found, replacing with original image
# awe_wife_580.jpg : cropped image of not found, replacing with original image
# crying_couple_378.jpg : cropped image of not found, replacing with original image
# awe_american_186.jpg : cropped image of not found, replacing with original image
# astound_family_175.jpg : cropped image of not found, replacing with original image
# astound_couple_512.jpg : cropped image of not found, replacing with original image
# heartbroken_family_628.jpg : cropped image of not found, replacing with original image
# awe_boy_695.jpg : cropped image of not found, replacing with original image
# awe_actor_325.jpg : cropped image of not found, replacing with original image
# astound_old_282.jpg : cropped image of not found, replacing with original imageamazed_worker_403.jpg : cropped image of not found, replacing with original image
#
# annoyed_president_184.jpg : cropped image of not found, replacing with original image
# fighting_american_676.jpg : cropped image of not found, replacing with original imagefrightened_by_the_movie_teacher_359.jpg : cropped image of not found, replacing with original image
#
# astound_grandmother_84.jpg : cropped image of not found, replacing with original image
# fighting_actor_789.jpg : cropped image of not found, replacing with original imageannoyed_people_309.jpg : cropped image of not found, replacing with original image
#
# hostile_student_437.jpg : cropped image of not found, replacing with original image
# hostile_president_119.jpg : cropped image of not found, replacing with original image
# afraid_woman_58.jpg : cropped image of not found, replacing with original image
# angry_people_118.jpg : cropped image of not found, replacing with original imageangry_manager_507.jpg : cropped image of not found, replacing with original image
#
# fierce_girl_395.jpg : cropped image of not found, replacing with original image
# distaste_chinese_262.jpg : cropped image of not found, replacing with original image
# awe_soldier_34.jpg : cropped image of not found, replacing with original image
# awe_black_271.jpg : cropped image of not found, replacing with original image
# awe_husband_656.jpg : cropped image of not found, replacing with original image
# frightened_by_the_movie_family_139.jpg : cropped image of not found, replacing with original image
# awe_american_656.jpg : cropped image of not found, replacing with original imageamazed_programmer_6.jpg : cropped image of not found, replacing with original image
#
# amazed_family_82.jpg : cropped image of not found, replacing with original image
# heartbroken_man_572.jpg : cropped image of not found, replacing with original image
# amazed_president_7.jpg : cropped image of not found, replacing with original image
# awe_american_633.jpg : cropped image of not found, replacing with original imagehostile_mother_95.jpg : cropped image of not found, replacing with original imageawe_infant_531.jpg : cropped image of not found, replacing with original image
#
#
# fighting_face_441.jpg : cropped image of not found, replacing with original image
# awe_boss_384.jpg : cropped image of not found, replacing with original image
# amazed_family_29.jpg : cropped image of not found, replacing with original image
# disgust_grandfather_125.jpg : cropped image of not found, replacing with original image
# astound_student_167.jpg : cropped image of not found, replacing with original image
# distressed_boy_364.jpg : cropped image of not found, replacing with original image
# awe_husband_799.jpg : cropped image of not found, replacing with original image
# crying_actor_103.jpg : cropped image of not found, replacing with original image
# angry_european_452.jpg : cropped image of not found, replacing with original image
# hostile_man_228.jpg : cropped image of not found, replacing with original imageangry_president_191.jpg : cropped image of not found, replacing with original imageangry_old_85.jpg : cropped image of not found, replacing with original image
# amazed_wife_759.jpg : cropped image of not found, replacing with original image
#
#
# distressed_couple_329.jpg : cropped image of not found, replacing with original image
# mad_manager_320.jpg : cropped image of not found, replacing with original imageastound_lady_725.jpg : cropped image of not found, replacing with original image
#
# crying_worker_544.jpg : cropped image of not found, replacing with original image
# awe_son_168.jpg : cropped image of not found, replacing with original image
# astound_asian_942.jpg : cropped image of not found, replacing with original image
# surprised_expression_430.jpg : cropped image of not found, replacing with original image
# astound_worker_624.jpg : cropped image of not found, replacing with original image
# amazed_actor_499.jpg : cropped image of not found, replacing with original image
# amazed_father_883.jpg : cropped image of not found, replacing with original imageawe_boy_765.jpg : cropped image of not found, replacing with original image
#
# distressed_lady_487.jpg : cropped image of not found, replacing with original image
# awe_family_200.jpg : cropped image of not found, replacing with original image
# disgust_president_379.jpg : cropped image of not found, replacing with original image
# disgust_face_262.jpg : cropped image of not found, replacing with original image
# heartbroken_infant_663.jpg : cropped image of not found, replacing with original image
# distaste_son_634.jpg : cropped image of not found, replacing with original image
# astound_boy_226.jpg : cropped image of not found, replacing with original image
# annoyed_people_257.jpg : cropped image of not found, replacing with original image
# amazed_girl_356.jpg : cropped image of not found, replacing with original imageastound_old_509.jpg : cropped image of not found, replacing with original image
#
# awe_family_890.jpg : cropped image of not found, replacing with original image
# distaste_face_874.jpg : cropped image of not found, replacing with original imageastound_actor_703.jpg : cropped image of not found, replacing with original imagecrying_African_228.jpg : cropped image of not found, replacing with original image
#
#
# awe_father_619.jpg : cropped image of not found, replacing with original image
# heartbroken_actor_905.jpg : cropped image of not found, replacing with original image
# fighting_soldier_445.jpg : cropped image of not found, replacing with original image
# anxious_programmer_977.jpg : cropped image of not found, replacing with original image
# amazed_yang_459.jpg : cropped image of not found, replacing with original image
# awe_actor_152.jpg : cropped image of not found, replacing with original imageamazed_man_124.jpg : cropped image of not found, replacing with original image
#
# surprised_expression_124.jpg : cropped image of not found, replacing with original image
# unhappy_expression_245.jpg : cropped image of not found, replacing with original imagecrying_son_240.jpg : cropped image of not found, replacing with original image
#
# heartbroken_soldier_604.jpg : cropped image of not found, replacing with original image
# amazed_yang_313.jpg : cropped image of not found, replacing with original image
# astound_boss_835.jpg : cropped image of not found, replacing with original image
# astound_worker_300.jpg : cropped image of not found, replacing with original imagehostile_european_7.jpg : cropped image of not found, replacing with original image
#
# crying_grandmother_297.jpg : cropped image of not found, replacing with original image
# frightened_face_13.jpg : cropped image of not found, replacing with original image
# astound_worker_690.jpg : cropped image of not found, replacing with original image
# astound_actor_573.jpg : cropped image of not found, replacing with original image
# amazed_couple_31.jpg : cropped image of not found, replacing with original image
# crying_yang_529.jpg : cropped image of not found, replacing with original image
# disgust_woman_508.jpg : cropped image of not found, replacing with original image
# awe_worker_535.jpg : cropped image of not found, replacing with original image
# astound_lady_818.jpg : cropped image of not found, replacing with original image
# awe_chinese_584.jpg : cropped image of not found, replacing with original image
# anxious_student_472.jpg : cropped image of not found, replacing with original image
# astound_infant_279.jpg : cropped image of not found, replacing with original image
# crying_couple_355.jpg : cropped image of not found, replacing with original imagefighting_actor_697.jpg : cropped image of not found, replacing with original image
#
# disgust_actor_383.jpg : cropped image of not found, replacing with original image
# distaste_expression_845.jpg : cropped image of not found, replacing with original image
# awe_mother_533.jpg : cropped image of not found, replacing with original image
# fierce_husband_199.jpg : cropped image of not found, replacing with original image
# heartbroken_husband_65.jpg : cropped image of not found, replacing with original imageheartbroken_family_631.jpg : cropped image of not found, replacing with original image
#
# angry_programmer_439.jpg : cropped image of not found, replacing with original imagefrightened_by_the_movie_face_489.jpg : cropped image of not found, replacing with original image
#
# awe_infant_886.jpg : cropped image of not found, replacing with original image
# amazed_mother_206.jpg : cropped image of not found, replacing with original imagemad_man_105.jpg : cropped image of not found, replacing with original imageawe_boy_873.jpg : cropped image of not found, replacing with original image
#
#
# astound_family_274.jpg : cropped image of not found, replacing with original imageannoyed_chinese_413.jpg : cropped image of not found, replacing with original imageamazed_girl_140.jpg : cropped image of not found, replacing with original image
#
#
# awe_wife_438.jpg : cropped image of not found, replacing with original imagefrightened_by_the_movie_girl_322.jpg : cropped image of not found, replacing with original image
#
# astound_teacher_533.jpg : cropped image of not found, replacing with original image
# anxious_African_480.jpg : cropped image of not found, replacing with original imageastound_son_876.jpg : cropped image of not found, replacing with original image
#
# awe_grandfather_421.jpg : cropped image of not found, replacing with original image
# crying_couple_65.jpg : cropped image of not found, replacing with original image
# frightened_by_the_movie_american_193.jpg : cropped image of not found, replacing with original image
# awe_face_604.jpg : cropped image of not found, replacing with original image
# awe_son_931.jpg : cropped image of not found, replacing with original image
# amazed_mother_646.jpg : cropped image of not found, replacing with original image
# annoyed_grandmother_821.jpg : cropped image of not found, replacing with original image
# crying_soldier_644.jpg : cropped image of not found, replacing with original image
# expressionless_husband_838.jpg : cropped image of not found, replacing with original image
# hostile_asian_550.jpg : cropped image of not found, replacing with original image
# distressed_father_254.jpg : cropped image of not found, replacing with original image
# ecstatic_girl_76.jpg : cropped image of not found, replacing with original image
# fighting_actor_102.jpg : cropped image of not found, replacing with original image
# afraid_woman_44.jpg : cropped image of not found, replacing with original image
# awe_couple_875.jpg : cropped image of not found, replacing with original image
# crying_family_364.jpg : cropped image of not found, replacing with original image
# fierce_lady_379.jpg : cropped image of not found, replacing with original image
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-b7de1b6da158> in <cell line: 3>()
#       1 print(f'------------training started for DANN Model ------------------')
#       2
# ----> 3 dann_model_trained, dict_dann_losses = execute_dann(model=model_dann,
#       4                                                     device=device,
#       5                                                     source_train_loader = data_loader['source']['train'], #sfew_train_loader,
#
# <ipython-input-18-c0c09b694514> in execute_dann(model, device, source_train_loader, source_val_loader, target_train_loader, target_val_loader, optimizer, n_epochs, class_loss_function, domain_loss_function, scheduler, early_stop_patience, early_stop_difference)
#     187                             class_loss_function = class_loss_function)
#     188
# --> 189     correct, test_loss_target = test_model_local(model= model,
#     190                             device= device,
#     191                             data_loader = target_val_loader, # target val loader
#
# <ipython-input-17-3d0de0556456> in test_model_local(model, device, data_loader, mode, class_loss_function)
#      25             class_loss = class_loss_function(class_output,labels) # Calculate Loss
#      26
# ---> 27             test_loss += class_loss.item() # sum up batch loss
#      28
#      29             # Sum up batch correct predictions
#
# KeyboardInterrupt:

# %% [markdown]
# ### DANN Saving

# %%
dann_model_name = f'dann_{source_name}_{target_name}_{str(time.strftime("%d_%m"))}.pt' # "dann_sfew_expw_" + str(time.strftime("%d_%m")) + ".pt"
print(dann_model_name)

# from data_config import DataConfig
dataconfig_1 = DataConfig()
MODEL_DIR = dataconfig_1.MODEL_DIR

DANN_MODEL_DIR =  Path(os.path.join(MODEL_DIR, f'dann_{source_name}_{target_name}'))


if not DANN_MODEL_DIR.exists():
    # Create the directory
    DANN_MODEL_DIR.mkdir(parents=True, exist_ok=True)
    print(f'Directory {DANN_MODEL_DIR} created successfully.')
else:
    print(f'Directory {DANN_MODEL_DIR} already exists.')


try:
    torch.save(dann_model_trained.state_dict(), Path(DANN_MODEL_DIR,dann_model_name))
    print(f'{dann_model_name} SAVED at {Path(DANN_MODEL_DIR,dann_model_name)}!')
except:
    print(f'Problem in saving {dann_model_name}, NOT SAVED!')
# Out:
# dann_sfew_expw_10_04.pt
# Directory /content/gdrive/MyDrive/CV_FER/models/dann_sfew_expw already exists.
# dann_sfew_expw_10_04.pt SAVED at /content/gdrive/MyDrive/CV_FER/models/dann_sfew_expw/dann_sfew_expw_10_04.pt!

# %% [markdown]
# ## EWC DANN Execution: Training, Validating, Saving

# %%
model_dann_ewc
# Out:
# DANN_VGG(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=[2, 2], stride=[2, 2], padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU()
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU()
#     (9): MaxPool2d(kernel_size=[2, 2], stride=[2, 2], padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU()
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU()
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU()
#     (16): MaxPool2d(kernel_size=[2, 2], stride=[2, 2], padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU()
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU()
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU()
#     (23): MaxPool2d(kernel_size=[2, 2], stride=[2, 2], padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU()
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU()
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU()
#     (30): MaxPool2d(kernel_size=[2, 2], stride=[2, 2], padding=0, dilation=1, ceil_mode=False)
#     (31): Conv2d(512, 4096, kernel_size=(7, 7), stride=(1, 1))
#   )
#   (class_classifier): Sequential(
#     (0): ReLU()
#     (1): Linear(in_features=4096, out_features=4096, bias=True)
#     (2): Dropout(p=0.1, inplace=False)
#     (3): ReLU()
#     (4): Linear(in_features=4096, out_features=7, bias=True)
#   )
#   (domain_classifier): Sequential(
#     (0): ReLU()
#     (1): Linear(in_features=4096, out_features=4096, bias=True)
#     (2): Dropout(p=0.1, inplace=False)
#     (3): ReLU()
#     (4): Linear(in_features=4096, out_features=2, bias=True)
#   )
# )

# %% [markdown]
# ### EWC Code
# - Regularization Penalty

# %%
from torch.autograd import Variable
from torch.autograd import Function
from da_cv_fer.run_config import RunConfig

runconfig = RunConfig()
def variable(t: torch.Tensor, use_cuda=True, **kwargs):
    if torch.cuda.is_available() and use_cuda:
        t = t.cuda()
    return Variable(t, **kwargs)

class EWC(object):
    def __init__(self, model: nn.Module,
                 data_loader: torch.utils.data.DataLoader
                #  dataset: list
                 ,device=device
                 , class_loss_function = runconfig.criterion_class):

        self.model = model
        # print("----------MODEL--------\n",self.model)
        self.dataset = data_loader
        self.device = device
        self.class_loss_function = class_loss_function

        # creating dictionary of params which required grad
        self.params = {n: p for n, p in self.model.named_parameters() if p.requires_grad}

        self._means = {}
        # for n, p in deepcopy(self.params).items():
        for n, p in self.params.items():

            self._means[n] = variable(p.data)

        # print("--------self._means----------------\n", self._means)

        self._precision_matrices = self._diag_fisher()

    def _diag_fisher(self):
        precision_matrices = {}
        for n, p in deepcopy(self.params).items():
            p.data.zero_()
            precision_matrices[n] = variable(p.data)
        # print("--------PRECISION MATRICES----------------\n", precision_matrices)

        self.model.eval()
        for batch in self.dataset:
            self.model.zero_grad()
            batch[0] = batch[0]* 255.0
            images, labels  = variable(batch[0].to(device)), variable(batch[1].to(device))
            class_ouputs, _ , _ = self.model(images) # class_output, domain_output, features
            task_loss =  self.class_loss_function(class_ouputs,labels)
            task_loss.backward() # only calculating the gradients, not updating it
            # print("--------task loss----------------\n", task_loss)

            for n, p in self.model.named_parameters():
              # if type(p.grad)
              if isinstance(p.grad, type(None)):
                pass # parameter value would remain as it is
              else:
                # print(n,":", type(p.grad))
                precision_matrices[n].data += p.grad.data ** 2 / len(self.dataset)

        precision_matrices = {n: p for n, p in precision_matrices.items()}
        return precision_matrices

    def penalty(self, model: nn.Module):
        loss = 0
        for n, p in model.named_parameters():
            _loss = self._precision_matrices[n] * (p - self._means[n]) ** 2
            loss += _loss.sum()
        return loss

# %% [markdown]
# ### EWC DANN Execution Function

# %%
def execute_dann_ewc(model,
                     device,
                     source_train_loader, source_val_loader,
                     target_train_loader, target_val_loader,
                     optimizer,
                     n_epochs, # total number of epochs (different from individual epoch)
                     class_loss_function = nn.CrossEntropyLoss(),
                     domain_loss_function = nn.BCEWithLogitsLoss(),
                     EWC_LAMBDA = 0.4, # to understand regularlization
                     scheduler = None,
                     early_stop_patience = None,
                     early_stop_difference = None
                     ):

    train_losses = [] # to capture train losses over training epochs
    val_losses = [] # to capture validation loss over epochs
    list_lr = [] # to capture lr changes across epochs
    list_val_correct = [] # to capture validation accuracy over epochs
    list_best_val_correct = [] # to capture best validtion accuracy over epochs


    epoch_converge = 0
    max_batches = min(len(source_train_loader), len(target_train_loader)) # Trying to check which is having less batches.
    existing_model = deepcopy(model) # copies params from existing model to another one https://discuss.pytorch.org/t/copying-weights-from-one-net-to-another/1492/2
    model = model.to(device)
    # model.apply(weights_init) # TODO: skipping weights update - we can experimentation later on, and see if this helps
    list_alpha =[]
    #TODO: Scheduler
    # scheduler = ReduceLROnPlateau(optimizer, factor = 0.1, patience = 5, threshold =  0.0005, verbose = True)

    ewc_object = EWC(existing_model.to(device),
                     data_loader=source_train_loader,
                     device=device,
                     class_loss_function=class_loss_function) # instantiating EWC object, we would use this object for understanding penalty


    # for best model
    best_model = deepcopy(model).to(device) # for best model
    best_val_loss = float('inf') # Initialize variables to track the best validation loss
    best_model_state = None # Initialize variables to track the best model state
    best_val_acc = 0 # Initialize variables to track the best accuracy


    for epoch_idx in range(n_epochs):
        print(f'epoch = {epoch_idx+1}...in EWC DANN execution function')
        source_iterator = iter(source_train_loader)
        target_iterator = iter(target_train_loader)
        epoch_task_loss = 0
        epoch_domain_loss =  0
        epoch_total_loss = 0
        processed = 0

        for batch_idx in range(max_batches-1):
            # p = float(batch_idx + epoch_idx * max_batches) / (n_epochs * max_batches)
            # alpha = 2. / (1. + np.exp(-10 * p)) - 1
            alpha = 1.0
            list_alpha.append(alpha)
            alpha = torch.tensor(alpha)


            model.train() # everytime ?
            optimizer.zero_grad() # flushing out the accumulated gradients

            #---------------------Source Dataset Training ------------------------#
            source_batch = next(source_iterator)
            source_batch[0] = source_batch[0] * 255.0  # Convert inputs from [0, 1] to [0, 255]

            source_images, source_labels = source_batch[0].to(device), source_batch[1].to(device) # getting images and labels, on device
            source_class_outputs, source_domain_outputs, _ = model(source_images, alpha=alpha) # forward pass, output = {class, domain, feature}

            # Calculating source class loss, regularlized by EWC
            loss_source_class = class_loss_function(source_class_outputs, source_labels) + EWC_LAMBDA * ewc_object.penalty(model)# calculating class loss

            source_domain_inputs = torch.tensor([1., 0.]*len(source_batch[0])).view(-1,2).to(device) # Source Image == [1., 0.]

            loss_source_domain = domain_loss_function(source_domain_outputs, source_domain_inputs) # calculating domain loss

            processed += len(source_batch[0])

            #---------------------Target Dataset Training ------------------------#
            target_batch = next (target_iterator)
            target_batch[0] = target_batch[0] * 255.0  # Convert inputs from [0, 1] to [0, 255]

            target_images = target_batch[0].to(device) # getting images, on device. There are no labels for target
            _, target_domain_outputs, _ = model(target_images, alpha=alpha) # forward pass, output = {class, domain, feature}

            target_domain_inputs = torch.tensor([0., 1.]*len(source_batch[0])).view(-1,2).to(device) # Target Image == [0., 1.]

            loss_target_domain = domain_loss_function(target_domain_outputs,target_domain_inputs)  # calculating domain loss


            #---------------------Combining Loss ------------------------#
            total_loss = loss_source_class + loss_source_domain + loss_target_domain
            total_loss.backward() #backpropogation, creating gradients
            optimizer.step() # updating the params

            epoch_task_loss += loss_source_class.item()
            epoch_domain_loss += loss_source_domain.item() + loss_target_domain.item()
            epoch_total_loss += total_loss.item()

            curr_lr = optimizer.param_groups[0]['lr'] # current learning rate
            list_lr.append(curr_lr)


            # after 10 batches
            if (batch_idx % 50 == 0):
                print("Epoch [{}/{}] Step [{}/{}]: loss_total={:.4f} / domain_loss_target={:.4f} / domain_loss_source={:.4f} / task_loss={:.4f} / domain_loss={:.4f} / alpha={:.4f} / lr={:.6f}"
              .format(epoch_idx + 1,
                      n_epochs,
                      batch_idx + 1,
                      max_batches,
                      total_loss.item(),
                      loss_target_domain.item()
                      ,loss_source_domain.item()
                      ,loss_source_class.item()
                      ,loss_source_domain.item()+loss_source_class.item(),
                      alpha,
                      curr_lr
                      ))
        # After every epoch
        avg_train_task_loss =  float("{:.6f}".format(epoch_task_loss/processed))
        train_losses.append(avg_train_task_loss)

        # #Scheduler
        # if scheduler:
        #   scheduler.step(avg_train_task_loss) ## applying scheduler on training loss

        #Validate Model after every epoch
        correct, avg_val_task_loss = test_model_local(model= model,
                                                device= device,
                                                data_loader = source_val_loader,
                                                class_loss_function = class_loss_function)
        val_losses.append(avg_val_task_loss)
        list_val_correct.append(correct)

        # # Check if the current model has the best validation loss
        # print(f'Last Epoch Val Loss = {avg_val_task_loss} | Best Val Loss = {best_val_loss}' )
        # if avg_val_task_loss < best_val_loss:
        #   best_val_loss = avg_val_task_loss
        #   # save the current model state as the best model state
        #   best_model_state = deepcopy(model.state_dict())
        #   print(f'Updated the best model with validation loss: {best_val_loss}\n')


        #Scheduler
        if scheduler:
          scheduler.step(correct) ## applying scheduler on correct, proxy to accuracy

        # check if the current model has the best accuracy
        print (f'last correct ={correct} | best correct = {best_val_acc}')
        if correct > best_val_acc:
          best_val_acc = correct
          # save the current model state as the best model state
          best_model_state = deepcopy(model.state_dict())
          print(f'Updated the best model with correct: {correct}\n')

        list_best_val_correct.append(best_val_acc)

        #TODO: Early Stopping
        if early_stop_patience and early_stop_difference: # early stopping required
          if early_stopping_difference(list_val_correct,
                                       patience = early_stop_patience,
                                       difference= early_stop_difference):
            print (f'-------Early Stopping at epoch {epoch+1}---')
            epoch_converge = epoch+1
            break # break from epoch loop
        #TODO: Early Stopping
        if early_stop_patience and early_stop_difference: # early stopping required based on best accuracy
          if early_stopping_difference(list_best_val_correct,
                                       patience = 2* early_stop_patience,
                                       difference= 0):
            print (f'-------Early Stopping at epoch {epoch+1}---')
            epoch_converge = epoch+1
            break # break from epoch loop

    # Testing when the training is over - completed or early stopped

    ## using params of best model to update model
    if best_model_state: # only update if best model has been saved, else the last one would be picked up
      model.load_state_dict(best_model_state)
      print('Best model loaded')

    correct_source, test_loss_source = test_model_local(model= model,
                            device= device,
                            data_loader = source_val_loader, # source val loader
                            class_loss_function = class_loss_function)

    accuracy_source = correct_source / len(source_val_loader.dataset)

    correct_target, test_loss_target = test_model_local(model= model,
                            device= device,
                            data_loader = target_val_loader, # target val loader
                            class_loss_function = class_loss_function)

    accuracy_target = correct_target / len(target_val_loader.dataset)


    dict_ewc_dann_losses = {'train_losses' : train_losses,
                        'val_losses': val_losses,
                        'test_loss_source' : test_loss_source,
                        'test_loss_target' : test_loss_target,
                        'epoch_convergence' : epoch_converge,
                        'list_alpha' : list_alpha,
                        'test_accuracy_source' : accuracy_source,
                        'test_accuracy_target':accuracy_target,
                            'lr':list_lr}

    # print(f'alpha list \n {list_alpha}')
    return model, dict_ewc_dann_losses

# %% [markdown]
# ### EWC DANN Execution Config

# %%
runconfig = RunConfig()
lr_ewc_dann = runconfig.inital_lr #override
lr_ewc_dann = 0.001 #override

optimizer_ewc_dann = optim.SGD(model_dann_ewc.parameters(), lr = lr_ewc_dann, momentum = 0.9)
# n_epochs = runconfig.EPOCHS if int(dict_non_dann_losses['epoch_convergence']) == 0 else int(dict_non_dann_losses['epoch_convergence'])

# n_epochs = 40 # override
n_epochs =  3 # override

# # ReduceLRonPlateau Scheduler Params
# scheduler_patience = runconfig.scheduler_patience
# scheduler_factor = runconfig.scheduler_factor
# scheduler_threshold = runconfig.scheduler_threshold

# # Early stopping params
# early_stop_patience = runconfig.early_stop_patience
# early_stop_difference = runconfig.early_stop_difference


# ReduceLRonPlateau Scheduler Params
scheduler_patience = 8 #runconfig.scheduler_patience
scheduler_factor = runconfig.scheduler_factor
scheduler_threshold = 25 #runconfig.scheduler_threshold

# Early stopping params
early_stop_patience = 10 #runconfig.early_stop_patience
early_stop_difference = 15 #runconfig.early_stop_difference

# # Set up the ReduceLROnPlateau scheduler
# scheduler = ReduceLROnPlateau(optimizer_ewc_dann,
#                               mode='min',
#                               factor=scheduler_factor,
#                               patience=scheduler_patience,
#                               threshold = scheduler_threshold,
#                               min_lr=1e-6,
#                               verbose= True)

scheduler = ReduceLROnPlateau(optimizer_ewc_dann,
                              # mode='min',
                              mode='max',
                              factor=scheduler_factor,
                              patience=scheduler_patience,
                              threshold = scheduler_threshold,
                              threshold_mode='abs',
                              min_lr=1e-6,
                              verbose= True)

try:
    EWC_LAMBDA = runconfig.EWC_LAMBDA
except:
    EWC_LAMBDA = 0.4

print(EWC_LAMBDA)
# Out:
# 0.4

# %% [markdown]
# ### EWC DANN Execution

# %%
print(f'------------training started for EWC DANN Model ------------------')

ewc_dann_model , dict_ewc_dann_losses = execute_dann_ewc(model= model_dann_ewc,
                                                          device=device,
                                                          source_train_loader = data_loader['source']['train'], #sfew_train_loader,
                                                          source_val_loader = data_loader['source']['val'], #sfew_val_loader,
                                                          target_train_loader = data_loader['target']['train'], #expw_train_loader,
                                                          target_val_loader = data_loader['target']['val'], #expw_val_loader,
                                                          optimizer = optimizer_ewc_dann,
                                                          n_epochs = n_epochs,
                                                          class_loss_function = runconfig.criterion_class,
                                                          domain_loss_function = runconfig.criterion_domain,
                                                          EWC_LAMBDA=EWC_LAMBDA, # Hyperparameter about penalty relevance
                                                          scheduler = scheduler,
                                                          early_stop_patience = early_stop_patience,
                                                          early_stop_difference = early_stop_difference
                                                         )
# Out:
# ------------training started for EWC DANN Model ------------------
# epoch = 1...in EWC DANN execution function
# Epoch [1/3] Step [1/58]: loss_total=1.6164 / domain_loss_target=0.6956 / domain_loss_source=0.6914 / task_loss=0.2294 / domain_loss=0.9208 / alpha=1.0000 / lr=0.001000
# Epoch [1/3] Step [51/58]: loss_total=2.1655 / domain_loss_target=0.6401 / domain_loss_source=0.7167 / task_loss=0.8087 / domain_loss=1.5255 / alpha=1.0000 / lr=0.001000
# Test / Val: Average loss: 0.1015, Accuracy: 192/419 (45.82%)
#
# last correct =192 | best correct = 0
# Updated the best model with correct: 192
#
# epoch = 2...in EWC DANN execution function
# Epoch [2/3] Step [1/58]: loss_total=1.9255 / domain_loss_target=0.6096 / domain_loss_source=0.7228 / task_loss=0.5930 / domain_loss=1.3158 / alpha=1.0000 / lr=0.001000
# Epoch [2/3] Step [51/58]: loss_total=2.4613 / domain_loss_target=0.6572 / domain_loss_source=0.6738 / task_loss=1.1303 / domain_loss=1.8042 / alpha=1.0000 / lr=0.001000
# Test / Val: Average loss: 0.1150, Accuracy: 199/419 (47.49%)
#
# last correct =199 | best correct = 192
# Updated the best model with correct: 199
#
# epoch = 3...in EWC DANN execution function
# Epoch [3/3] Step [1/58]: loss_total=1.7476 / domain_loss_target=0.6899 / domain_loss_source=0.6800 / task_loss=0.3777 / domain_loss=1.0577 / alpha=1.0000 / lr=0.001000
# Epoch [3/3] Step [51/58]: loss_total=2.1876 / domain_loss_target=0.6819 / domain_loss_source=0.7089 / task_loss=0.7968 / domain_loss=1.5057 / alpha=1.0000 / lr=0.001000
# Test / Val: Average loss: 0.1129, Accuracy: 210/419 (50.12%)
#
# last correct =210 | best correct = 199
# Updated the best model with correct: 210
#
# Best model loaded
# Test / Val: Average loss: 0.1273, Accuracy: 210/419 (50.12%)
#
# angry_soldier_355.jpg : cropped image of not found, replacing with original imageawe_actor_227.jpg : cropped image of not found, replacing with original imageamazed_couple_113.jpg : cropped image of not found, replacing with original image
#
#
# astound_boy_114.jpg : cropped image of not found, replacing with original imageawe_chinese_534.jpg : cropped image of not found, replacing with original imagefighting_expression_277.jpg : cropped image of not found, replacing with original image
#
#
# distressed_actor_711.jpg : cropped image of not found, replacing with original image
# awe_manager_377.jpg : cropped image of not found, replacing with original image
# surprised_expression_25.jpg : cropped image of not found, replacing with original image
# amazed_president_681.jpg : cropped image of not found, replacing with original image
# distaste_soldier_333.jpg : cropped image of not found, replacing with original image
# ecstatic_grandfather_920.jpg : cropped image of not found, replacing with original image
# annoyed_boss_343.jpg : cropped image of not found, replacing with original image
# boring_infant_505.jpg : cropped image of not found, replacing with original image
# fighting_boy_284.jpg : cropped image of not found, replacing with original imageboring_european_188.jpg : cropped image of not found, replacing with original image
#
# heartbroken_African_530.jpg : cropped image of not found, replacing with original image
# fighting_grandfather_812.jpg : cropped image of not found, replacing with original image
# surprised_expression_91.jpg : cropped image of not found, replacing with original image
# angry_european_781.jpg : cropped image of not found, replacing with original image
# anxious_family_328.jpg : cropped image of not found, replacing with original imageastound_student_533.jpg : cropped image of not found, replacing with original image
#
# heartbroken_father_128.jpg : cropped image of not found, replacing with original image
# fierce_family_421.jpg : cropped image of not found, replacing with original image
# astound_people_661.jpg : cropped image of not found, replacing with original image
# astound_African_108.jpg : cropped image of not found, replacing with original image
# awe_actor_705.jpg : cropped image of not found, replacing with original image
# crying_family_124.jpg : cropped image of not found, replacing with original image
# awe_African_121.jpg : cropped image of not found, replacing with original image
# amazed_woman_592.jpg : cropped image of not found, replacing with original imageamazed_grandmother_338.jpg : cropped image of not found, replacing with original image
#
# awe_programmer_616.jpg : cropped image of not found, replacing with original image
# awe_face_477.jpg : cropped image of not found, replacing with original imageamazed_couple_327.jpg : cropped image of not found, replacing with original image
#
# astound_couple_428.jpg : cropped image of not found, replacing with original image
# heartbroken_american_340.jpg : cropped image of not found, replacing with original image
# astound_grandmother_485.jpg : cropped image of not found, replacing with original image
# amazed_programmer_431.jpg : cropped image of not found, replacing with original image
# amazed_son_819.jpg : cropped image of not found, replacing with original image
# amazed_chinese_154.jpg : cropped image of not found, replacing with original image
# heartbroken_actor_363.jpg : cropped image of not found, replacing with original image
# annoyed_woman_318.jpg : cropped image of not found, replacing with original image
# amazed_american_223.jpg : cropped image of not found, replacing with original image
# astound_expression_794.jpg : cropped image of not found, replacing with original imageamazed_worker_726.jpg : cropped image of not found, replacing with original image
#
# boring_couple_372.jpg : cropped image of not found, replacing with original image
# amazed_boy_3.jpg : cropped image of not found, replacing with original image
# awe_girl_608.jpg : cropped image of not found, replacing with original image
# distaste_actor_787.jpg : cropped image of not found, replacing with original imageamazed_manager_527.jpg : cropped image of not found, replacing with original image
#
# amazed_family_575.jpg : cropped image of not found, replacing with original image
# hostile_people_288.jpg : cropped image of not found, replacing with original image
# awe_actor_270.jpg : cropped image of not found, replacing with original image
# heartbroken_mother_245.jpg : cropped image of not found, replacing with original imageamazed_european_505.jpg : cropped image of not found, replacing with original image
#
# distressed_yang_90.jpg : cropped image of not found, replacing with original image
# boring_African_49.jpg : cropped image of not found, replacing with original image
# astound_asian_271.jpg : cropped image of not found, replacing with original image
# frightened_face_79.jpg : cropped image of not found, replacing with original image
# awe_boy_50.jpg : cropped image of not found, replacing with original image
# astound_girl_762.jpg : cropped image of not found, replacing with original image
# amazed_old_578.jpg : cropped image of not found, replacing with original imagecrying_boss_643.jpg : cropped image of not found, replacing with original image
#
# annoyed_soldier_789.jpg : cropped image of not found, replacing with original image
# heartbroken_son_182.jpg : cropped image of not found, replacing with original image
# amazed_father_687.jpg : cropped image of not found, replacing with original image
# amazed_African_313.jpg : cropped image of not found, replacing with original imageastound_asian_659.jpg : cropped image of not found, replacing with original image
#
# angry_manager_314.jpg : cropped image of not found, replacing with original image
# crying_president_211.jpg : cropped image of not found, replacing with original image
# angry_actor_45.jpg : cropped image of not found, replacing with original imageannoyed_chinese_413.jpg : cropped image of not found, replacing with original image
#
# fighting_man_470.jpg : cropped image of not found, replacing with original image
# heartbroken_mother_490.jpg : cropped image of not found, replacing with original image
# mad_teacher_39.jpg : cropped image of not found, replacing with original image
# fighting_worker_113.jpg : cropped image of not found, replacing with original image
# heartbroken_boss_268.jpg : cropped image of not found, replacing with original image
# crying_worker_277.jpg : cropped image of not found, replacing with original image
# fierce_people_124.jpg : cropped image of not found, replacing with original image
# frightened_by_the_movie_black_139.jpg : cropped image of not found, replacing with original imagefighting_boss_252.jpg : cropped image of not found, replacing with original image
#
# afraid_grandfather_26.jpg : cropped image of not found, replacing with original imageamazed_worker_943.jpg : cropped image of not found, replacing with original image
#
# annoyed_chinese_555.jpg : cropped image of not found, replacing with original imagehostile_programmer_425.jpg : cropped image of not found, replacing with original image
#
# astound_wife_119.jpg : cropped image of not found, replacing with original image
# amazed_student_491.jpg : cropped image of not found, replacing with original image
# fierce_boss_560.jpg : cropped image of not found, replacing with original image
# crying_actor_608.jpg : cropped image of not found, replacing with original image
# amazed_student_595.jpg : cropped image of not found, replacing with original image
# amazed_infant_57.jpg : cropped image of not found, replacing with original image
# frightened_man_189.jpg : cropped image of not found, replacing with original image
# excited_boy_114.jpg : cropped image of not found, replacing with original image
# astound_couple_807.jpg : cropped image of not found, replacing with original image
# amazed_expression_453.jpg : cropped image of not found, replacing with original imageamazed_father_900.jpg : cropped image of not found, replacing with original image
# awe_wife_288.jpg : cropped image of not found, replacing with original image
#
# astound_father_550.jpg : cropped image of not found, replacing with original image
# astound_yang_922.jpg : cropped image of not found, replacing with original image
# amazed_family_74.jpg : cropped image of not found, replacing with original imageawe_american_480.jpg : cropped image of not found, replacing with original image
#
# annoyed_father_337.jpg : cropped image of not found, replacing with original image
# awe_american_158.jpg : cropped image of not found, replacing with original image
# amazed_African_618.jpg : cropped image of not found, replacing with original image
# amazed_son_701.jpg : cropped image of not found, replacing with original image
# distressed_president_286.jpg : cropped image of not found, replacing with original image
# annoyed_couple_29.jpg : cropped image of not found, replacing with original imageawe_infant_540.jpg : cropped image of not found, replacing with original image
#
# awe_american_633.jpg : cropped image of not found, replacing with original image
# crying_boy_437.jpg : cropped image of not found, replacing with original image
# heartbroken_president_141.jpg : cropped image of not found, replacing with original image
# awe_american_727.jpg : cropped image of not found, replacing with original imageastound_manager_942.jpg : cropped image of not found, replacing with original image
#
# awe_old_665.jpg : cropped image of not found, replacing with original image
# annoyed_european_370.jpg : cropped image of not found, replacing with original imagemad_man_26.jpg : cropped image of not found, replacing with original image
#
# distressed_student_700.jpg : cropped image of not found, replacing with original image
# awe_grandmother_64.jpg : cropped image of not found, replacing with original image
# awe_boy_83.jpg : cropped image of not found, replacing with original image
# awe_lady_447.jpg : cropped image of not found, replacing with original image
# awe_boss_783.jpg : cropped image of not found, replacing with original image
# awe_wife_69.jpg : cropped image of not found, replacing with original image
# awe_girl_465.jpg : cropped image of not found, replacing with original image
# crying_boss_780.jpg : cropped image of not found, replacing with original image
# astound_people_44.jpg : cropped image of not found, replacing with original image
# crying_manager_145.jpg : cropped image of not found, replacing with original imagecrying_black_701.jpg : cropped image of not found, replacing with original image
#
# fierce_student_322.jpg : cropped image of not found, replacing with original image
# hostile_president_799.jpg : cropped image of not found, replacing with original imagefrightened_lady_799.jpg : cropped image of not found, replacing with original image
#
# amazed_european_902.jpg : cropped image of not found, replacing with original image
# amazed_american_727.jpg : cropped image of not found, replacing with original image
# heartbroken_american_783.jpg : cropped image of not found, replacing with original image
# hostile_boy_1.jpg : cropped image of not found, replacing with original image
# angry_boy_185.jpg : cropped image of not found, replacing with original image
# fighting_girl_55.jpg : cropped image of not found, replacing with original image
# fierce_husband_455.jpg : cropped image of not found, replacing with original image
# awe_mother_374.jpg : cropped image of not found, replacing with original image
# awe_husband_882.jpg : cropped image of not found, replacing with original image
# fighting_face_639.jpg : cropped image of not found, replacing with original imageheartbroken_man_281.jpg : cropped image of not found, replacing with original imageamazed_mother_45.jpg : cropped image of not found, replacing with original image
#
#
# crying_student_3.jpg : cropped image of not found, replacing with original image
# crying_asian_135.jpg : cropped image of not found, replacing with original image
# heartbroken_asian_6.jpg : cropped image of not found, replacing with original image
# amazed_father_827.jpg : cropped image of not found, replacing with original image
# heartbroken_lady_775.jpg : cropped image of not found, replacing with original image
# hostile_father_299.jpg : cropped image of not found, replacing with original image
# awe_programmer_143.jpg : cropped image of not found, replacing with original imageamazed_family_429.jpg : cropped image of not found, replacing with original image
#
# frightened_by_the_movie_man_487.jpg : cropped image of not found, replacing with original image
# amazed_black_311.jpg : cropped image of not found, replacing with original image
# fierce_old_455.jpg : cropped image of not found, replacing with original image
# fierce_yang_907.jpg : cropped image of not found, replacing with original image
# crying_old_499.jpg : cropped image of not found, replacing with original image
# fierce_African_791.jpg : cropped image of not found, replacing with original image
# awe_student_339.jpg : cropped image of not found, replacing with original image
# awe_president_589.jpg : cropped image of not found, replacing with original image
# anxious_grandmother_545.jpg : cropped image of not found, replacing with original image
# fighting_lady_716.jpg : cropped image of not found, replacing with original image
# mad_actor_784.jpg : cropped image of not found, replacing with original image
# astound_president_172.jpg : cropped image of not found, replacing with original imagedistressed_man_342.jpg : cropped image of not found, replacing with original image
#
# angry_husband_72.jpg : cropped image of not found, replacing with original image
# disgust_man_29.jpg : cropped image of not found, replacing with original image
# awe_boy_277.jpg : cropped image of not found, replacing with original image
# amazed_soldier_545.jpg : cropped image of not found, replacing with original image
# annoyed_lady_767.jpg : cropped image of not found, replacing with original imagefrightened_expression_161.jpg : cropped image of not found, replacing with original image
#
# awe_black_588.jpg : cropped image of not found, replacing with original image
# awe_teacher_2.jpg : cropped image of not found, replacing with original image
# distressed_grandmother_816.jpg : cropped image of not found, replacing with original image
# heartbroken_student_248.jpg : cropped image of not found, replacing with original image
# annoyed_grandfather_829.jpg : cropped image of not found, replacing with original image
# astound_husband_402.jpg : cropped image of not found, replacing with original imageamazed_son_469.jpg : cropped image of not found, replacing with original image
# awe_asian_486.jpg : cropped image of not found, replacing with original image
#
# crying_infant_71.jpg : cropped image of not found, replacing with original image
# crying_girl_1.jpg : cropped image of not found, replacing with original image
# amazed_mother_584.jpg : cropped image of not found, replacing with original image
# awe_wife_602.jpg : cropped image of not found, replacing with original image
# awe_yang_167.jpg : cropped image of not found, replacing with original image
# amazed_lady_378.jpg : cropped image of not found, replacing with original image
# amazed_son_696.jpg : cropped image of not found, replacing with original image
# heartbroken_yang_690.jpg : cropped image of not found, replacing with original image
# amazed_grandmother_85.jpg : cropped image of not found, replacing with original image
# astound_girl_449.jpg : cropped image of not found, replacing with original image
# astound_soldier_633.jpg : cropped image of not found, replacing with original image
# astound_chinese_888.jpg : cropped image of not found, replacing with original image
# awe_teacher_342.jpg : cropped image of not found, replacing with original imageamazed_husband_209.jpg : cropped image of not found, replacing with original image
#
# amazed_programmer_542.jpg : cropped image of not found, replacing with original imagedistressed_american_408.jpg : cropped image of not found, replacing with original image
#
# amazed_soldier_564.jpg : cropped image of not found, replacing with original image
# fierce_student_472.jpg : cropped image of not found, replacing with original image
# distressed_actor_769.jpg : cropped image of not found, replacing with original image
# mad_teacher_246.jpg : cropped image of not found, replacing with original imageheartbroken_old_694.jpg : cropped image of not found, replacing with original image
#
# fierce_man_113.jpg : cropped image of not found, replacing with original imagedistaste_lady_637.jpg : cropped image of not found, replacing with original image
#
# astound_face_10.jpg : cropped image of not found, replacing with original imagemad_american_832.jpg : cropped image of not found, replacing with original image
# annoyed_son_354.jpg : cropped image of not found, replacing with original image
#
# annoyed_european_857.jpg : cropped image of not found, replacing with original image
# amazed_european_164.jpg : cropped image of not found, replacing with original image
# angry_soldier_144.jpg : cropped image of not found, replacing with original image
# fighting_worker_792.jpg : cropped image of not found, replacing with original imageawe_programmer_588.jpg : cropped image of not found, replacing with original image
#
# amazed_chinese_706.jpg : cropped image of not found, replacing with original image
# astound_infant_385.jpg : cropped image of not found, replacing with original image
# awe_programmer_658.jpg : cropped image of not found, replacing with original image
# awe_father_533.jpg : cropped image of not found, replacing with original imageawe_husband_892.jpg : cropped image of not found, replacing with original image
#
# amazed_european_951.jpg : cropped image of not found, replacing with original image
# excited_boy_80.jpg : cropped image of not found, replacing with original image
# angry_grandmother_128.jpg : cropped image of not found, replacing with original image
# awe_grandfather_381.jpg : cropped image of not found, replacing with original image
# astound_girl_501.jpg : cropped image of not found, replacing with original image
# mad_African_338.jpg : cropped image of not found, replacing with original image
# astound_husband_521.jpg : cropped image of not found, replacing with original imagefighting_european_523.jpg : cropped image of not found, replacing with original imageannoyed_boss_147.jpg : cropped image of not found, replacing with original image
#
#
# distressed_lady_353.jpg : cropped image of not found, replacing with original imagedisgust_grandmother_586.jpg : cropped image of not found, replacing with original image
#
# disgust_programmer_570.jpg : cropped image of not found, replacing with original image
# serious_expression_412.jpg : cropped image of not found, replacing with original image
# astound_manager_360.jpg : cropped image of not found, replacing with original image
# amazed_teacher_806.jpg : cropped image of not found, replacing with original image
# amazed_president_269.jpg : cropped image of not found, replacing with original imageamazed_grandfather_570.jpg : cropped image of not found, replacing with original image
#
# awe_student_588.jpg : cropped image of not found, replacing with original image
# distaste_father_712.jpg : cropped image of not found, replacing with original image
# boring_soldier_639.jpg : cropped image of not found, replacing with original image
# fighting_european_818.jpg : cropped image of not found, replacing with original image
# amazed_worker_929.jpg : cropped image of not found, replacing with original imageanxious_asian_626.jpg : cropped image of not found, replacing with original imagecrying_mother_111.jpg : cropped image of not found, replacing with original image
#
#
# heartbroken_student_387.jpg : cropped image of not found, replacing with original image
# expressionless_president_191.jpg : cropped image of not found, replacing with original image
# astound_mother_349.jpg : cropped image of not found, replacing with original image
# heartbroken_president_725.jpg : cropped image of not found, replacing with original image
# boring_couple_163.jpg : cropped image of not found, replacing with original imagefierce_husband_547.jpg : cropped image of not found, replacing with original image
#
# crying_european_142.jpg : cropped image of not found, replacing with original image
# angry_president_838.jpg : cropped image of not found, replacing with original imageamazed_european_654.jpg : cropped image of not found, replacing with original imagedistressed_grandmother_421.jpg : cropped image of not found, replacing with original image
#
#
# crying_woman_484.jpg : cropped image of not found, replacing with original image
# astound_asian_374.jpg : cropped image of not found, replacing with original image
#
# awe_mother_932.jpg : cropped image of not found, replacing with original imageastound_teacher_835.jpg : cropped image of not found, replacing with original image
# amazed_grandmother_383.jpg : cropped image of not found, replacing with original image
# angry_man_214.jpg : cropped image of not found, replacing with original imageheartbroken_African_226.jpg : cropped image of not found, replacing with original image
#
# angry_president_547.jpg : cropped image of not found, replacing with original image
# fighting_actor_686.jpg : cropped image of not found, replacing with original image
# awe_girl_317.jpg : cropped image of not found, replacing with original image
# awe_family_544.jpg : cropped image of not found, replacing with original image
# awe_African_332.jpg : cropped image of not found, replacing with original image
# awe_couple_684.jpg : cropped image of not found, replacing with original image
# mad_student_161.jpg : cropped image of not found, replacing with original image
# angry_president_321.jpg : cropped image of not found, replacing with original imageawe_boy_523.jpg : cropped image of not found, replacing with original image
#
# astound_expression_667.jpg : cropped image of not found, replacing with original image
# hostile_old_764.jpg : cropped image of not found, replacing with original image
# heartbroken_son_501.jpg : cropped image of not found, replacing with original image
# amazed_man_66.jpg : cropped image of not found, replacing with original image
# fierce_student_534.jpg : cropped image of not found, replacing with original image
# angry_european_738.jpg : cropped image of not found, replacing with original imageastound_boss_167.jpg : cropped image of not found, replacing with original image
#
# frightened_programmer_324.jpg : cropped image of not found, replacing with original imageexpressionless_american_721.jpg : cropped image of not found, replacing with original image
#
# astound_infant_317.jpg : cropped image of not found, replacing with original image
# fierce_student_291.jpg : cropped image of not found, replacing with original image
# crying_face_523.jpg : cropped image of not found, replacing with original image
# amazed_couple_126.jpg : cropped image of not found, replacing with original image
# crying_actor_705.jpg : cropped image of not found, replacing with original image
# distressed_manager_913.jpg : cropped image of not found, replacing with original image
# awe_lady_352.jpg : cropped image of not found, replacing with original image
# amazed_american_538.jpg : cropped image of not found, replacing with original image
# crying_expression_528.jpg : cropped image of not found, replacing with original imageawe_european_743.jpg : cropped image of not found, replacing with original imageboring_yang_705.jpg : cropped image of not found, replacing with original image
#
#
# amazed_grandmother_372.jpg : cropped image of not found, replacing with original image
# amazed_grandmother_528.jpg : cropped image of not found, replacing with original imageastound_family_465.jpg : cropped image of not found, replacing with original image
#
# astound_father_470.jpg : cropped image of not found, replacing with original image
# awe_mother_236.jpg : cropped image of not found, replacing with original image
# heartbroken_lady_604.jpg : cropped image of not found, replacing with original image
# amazed_old_361.jpg : cropped image of not found, replacing with original image
# amazed_boss_376.jpg : cropped image of not found, replacing with original image
# amazed_woman_481.jpg : cropped image of not found, replacing with original image
# astound_student_903.jpg : cropped image of not found, replacing with original imageawe_girl_136.jpg : cropped image of not found, replacing with original image
#
# hostile_grandmother_141.jpg : cropped image of not found, replacing with original image
# heartbroken_wife_569.jpg : cropped image of not found, replacing with original image
# awe_worker_656.jpg : cropped image of not found, replacing with original image
# amazed_mother_480.jpg : cropped image of not found, replacing with original image
# boring_son_685.jpg : cropped image of not found, replacing with original image
# awe_actor_129.jpg : cropped image of not found, replacing with original imageamazed_expression_364.jpg : cropped image of not found, replacing with original image
# fighting_father_328.jpg : cropped image of not found, replacing with original image
#
# hostile_man_124.jpg : cropped image of not found, replacing with original imageastound_boy_798.jpg : cropped image of not found, replacing with original image
#
# heartbroken_grandfather_816.jpg : cropped image of not found, replacing with original image
# distressed_chinese_834.jpg : cropped image of not found, replacing with original image
# hostile_husband_226.jpg : cropped image of not found, replacing with original imagehostile_president_529.jpg : cropped image of not found, replacing with original image
#
# crying_european_307.jpg : cropped image of not found, replacing with original image
# awe_yang_123.jpg : cropped image of not found, replacing with original image
# hostile_american_806.jpg : cropped image of not found, replacing with original imageastound_actor_973.jpg : cropped image of not found, replacing with original image
#
# heartbroken_family_431.jpg : cropped image of not found, replacing with original image
# crying_boss_345.jpg : cropped image of not found, replacing with original image
# disgust_boss_409.jpg : cropped image of not found, replacing with original image
# awe_husband_927.jpg : cropped image of not found, replacing with original image
# boring_boss_58.jpg : cropped image of not found, replacing with original imagehostile_old_814.jpg : cropped image of not found, replacing with original image
#
# distressed_African_576.jpg : cropped image of not found, replacing with original image
# annoyed_president_161.jpg : cropped image of not found, replacing with original image
# hostile_son_17.jpg : cropped image of not found, replacing with original imagehostile_soldier_893.jpg : cropped image of not found, replacing with original image
#
# awe_black_639.jpg : cropped image of not found, replacing with original image
# crying_student_26.jpg : cropped image of not found, replacing with original image
# mad_worker_323.jpg : cropped image of not found, replacing with original image
# distaste_worker_871.jpg : cropped image of not found, replacing with original image
# amazed_actor_380.jpg : cropped image of not found, replacing with original image
# hostile_woman_497.jpg : cropped image of not found, replacing with original image
# distaste_student_671.jpg : cropped image of not found, replacing with original image
# amazed_family_77.jpg : cropped image of not found, replacing with original imageangry_lady_154.jpg : cropped image of not found, replacing with original imagehostile_european_529.jpg : cropped image of not found, replacing with original image
#
#
# mad_student_43.jpg : cropped image of not found, replacing with original image
# amazed_manager_511.jpg : cropped image of not found, replacing with original image
# distressed_boy_435.jpg : cropped image of not found, replacing with original image
# angry_woman_371.jpg : cropped image of not found, replacing with original image
# fierce_lady_379.jpg : cropped image of not found, replacing with original imagecrying_manager_59.jpg : cropped image of not found, replacing with original image
#
# awe_son_498.jpg : cropped image of not found, replacing with original imagedistressed_couple_835.jpg : cropped image of not found, replacing with original imageamazed_mother_190.jpg : cropped image of not found, replacing with original image
#
#
# disgust_face_422.jpg : cropped image of not found, replacing with original image
# awe_actor_891.jpg : cropped image of not found, replacing with original image
# heartbroken_manager_886.jpg : cropped image of not found, replacing with original image
# fierce_programmer_672.jpg : cropped image of not found, replacing with original imageangry_people_279.jpg : cropped image of not found, replacing with original image
#
# awe_face_115.jpg : cropped image of not found, replacing with original imageannoyed_woman_358.jpg : cropped image of not found, replacing with original image
#
# astound_american_832.jpg : cropped image of not found, replacing with original image
# amazed_son_436.jpg : cropped image of not found, replacing with original image
# fighting_mother_3.jpg : cropped image of not found, replacing with original imageawe_president_534.jpg : cropped image of not found, replacing with original image
#
# awe_face_45.jpg : cropped image of not found, replacing with original image
# awe_manager_190.jpg : cropped image of not found, replacing with original image
# distressed_actor_75.jpg : cropped image of not found, replacing with original image
# frightened_black_331.jpg : cropped image of not found, replacing with original image
# angry_manager_646.jpg : cropped image of not found, replacing with original image
# crying_student_296.jpg : cropped image of not found, replacing with original image
# frightened_by_the_movie_asian_710.jpg : cropped image of not found, replacing with original imagecrying_father_72.jpg : cropped image of not found, replacing with original image
#
# amazed_expression_376.jpg : cropped image of not found, replacing with original imagefierce_lady_63.jpg : cropped image of not found, replacing with original image
#
# disgust_president_324.jpg : cropped image of not found, replacing with original image
# fierce_manager_269.jpg : cropped image of not found, replacing with original image
# crying_lady_308.jpg : cropped image of not found, replacing with original image
# amazed_couple_191.jpg : cropped image of not found, replacing with original image
# awe_boy_243.jpg : cropped image of not found, replacing with original image
# amazed_people_151.jpg : cropped image of not found, replacing with original imageboring_european_807.jpg : cropped image of not found, replacing with original image
# angry_mother_311.jpg : cropped image of not found, replacing with original image
# astound_teacher_625.jpg : cropped image of not found, replacing with original image
#
# awe_programmer_209.jpg : cropped image of not found, replacing with original image
# astound_old_282.jpg : cropped image of not found, replacing with original image
# astound_husband_389.jpg : cropped image of not found, replacing with original imageamazed_husband_535.jpg : cropped image of not found, replacing with original image
#
# awe_couple_239.jpg : cropped image of not found, replacing with original image
# fighting_worker_592.jpg : cropped image of not found, replacing with original image
# disgust_infant_67.jpg : cropped image of not found, replacing with original image
# annoyed_manager_285.jpg : cropped image of not found, replacing with original image
# angry_president_651.jpg : cropped image of not found, replacing with original image
# heartbroken_actor_799.jpg : cropped image of not found, replacing with original image
# crying_face_482.jpg : cropped image of not found, replacing with original image
# amazed_grandfather_768.jpg : cropped image of not found, replacing with original image
# awe_actor_156.jpg : cropped image of not found, replacing with original image
# amazed_president_763.jpg : cropped image of not found, replacing with original image
# amazed_woman_201.jpg : cropped image of not found, replacing with original image
# boring_teacher_203.jpg : cropped image of not found, replacing with original image
# heartbroken_programmer_57.jpg : cropped image of not found, replacing with original image
# fierce_worker_572.jpg : cropped image of not found, replacing with original image
# ecstatic_old_164.jpg : cropped image of not found, replacing with original image
# amazed_worker_652.jpg : cropped image of not found, replacing with original image
# astound_president_908.jpg : cropped image of not found, replacing with original image
# hostile_girl_784.jpg : cropped image of not found, replacing with original imageamazed_family_734.jpg : cropped image of not found, replacing with original image
#
# annoyed_asian_149.jpg : cropped image of not found, replacing with original image
# awe_wife_225.jpg : cropped image of not found, replacing with original image
# amazed_lady_691.jpg : cropped image of not found, replacing with original image
# mad_father_605.jpg : cropped image of not found, replacing with original image
# amazed_programmer_8.jpg : cropped image of not found, replacing with original image
# distressed_wife_257.jpg : cropped image of not found, replacing with original image
# awe_boy_388.jpg : cropped image of not found, replacing with original image
# angry_actor_689.jpg : cropped image of not found, replacing with original image
# awe_face_68.jpg : cropped image of not found, replacing with original image
# fierce_mother_30.jpg : cropped image of not found, replacing with original imageawe_people_402.jpg : cropped image of not found, replacing with original image
#
# amazed_european_638.jpg : cropped image of not found, replacing with original image
# heartbroken_woman_649.jpg : cropped image of not found, replacing with original image
# mad_soldier_410.jpg : cropped image of not found, replacing with original image
# surprised_expression_400.jpg : cropped image of not found, replacing with original imagecrying_european_33.jpg : cropped image of not found, replacing with original image
#
# angry_manager_11.jpg : cropped image of not found, replacing with original imagefierce_boy_207.jpg : cropped image of not found, replacing with original imageheartbroken_expression_10.jpg : cropped image of not found, replacing with original image
#
#
# angry_infant_410.jpg : cropped image of not found, replacing with original imageamazed_girl_554.jpg : cropped image of not found, replacing with original imageawe_soldier_423.jpg : cropped image of not found, replacing with original image
#
#
# crying_programmer_643.jpg : cropped image of not found, replacing with original image
# heartbroken_African_155.jpg : cropped image of not found, replacing with original image
# disgust_woman_508.jpg : cropped image of not found, replacing with original image
# amazed_old_926.jpg : cropped image of not found, replacing with original image
# anxious_son_532.jpg : cropped image of not found, replacing with original image
# excited_black_88.jpg : cropped image of not found, replacing with original image
# awe_boy_127.jpg : cropped image of not found, replacing with original image
# hostile_actor_63.jpg : cropped image of not found, replacing with original image
# amazed_family_165.jpg : cropped image of not found, replacing with original image
# fighting_boy_228.jpg : cropped image of not found, replacing with original imagefrightened_by_the_movie_grandfather_78.jpg : cropped image of not found, replacing with original image
#
# mad_expression_174.jpg : cropped image of not found, replacing with original imageamazed_european_315.jpg : cropped image of not found, replacing with original image
#
# crying_woman_82.jpg : cropped image of not found, replacing with original image
# amazed_black_546.jpg : cropped image of not found, replacing with original image
# afraid_man_257.jpg : cropped image of not found, replacing with original image
# frightened_grandfather_489.jpg : cropped image of not found, replacing with original image
# awe_grandfather_383.jpg : cropped image of not found, replacing with original imagehostile_manager_177.jpg : cropped image of not found, replacing with original image
#
# awe_actor_603.jpg : cropped image of not found, replacing with original image
# amazed_chinese_80.jpg : cropped image of not found, replacing with original imagefrightened_by_the_movie_expression_116.jpg : cropped image of not found, replacing with original image
#
# astound_asian_381.jpg : cropped image of not found, replacing with original image
# shocked_expression_73.jpg : cropped image of not found, replacing with original image
# crying_husband_386.jpg : cropped image of not found, replacing with original image
# amazed_soldier_641.jpg : cropped image of not found, replacing with original image
# fighting_expression_642.jpg : cropped image of not found, replacing with original image
# crying_manager_540.jpg : cropped image of not found, replacing with original imageamazed_president_15.jpg : cropped image of not found, replacing with original image
#
# annoyed_boy_596.jpg : cropped image of not found, replacing with original image
# amazed_grandfather_922.jpg : cropped image of not found, replacing with original image
# crying_couple_615.jpg : cropped image of not found, replacing with original image
# fierce_president_686.jpg : cropped image of not found, replacing with original image
# astound_asian_130.jpg : cropped image of not found, replacing with original image
# mad_African_251.jpg : cropped image of not found, replacing with original image
# fighting_grandmother_318.jpg : cropped image of not found, replacing with original image
# awe_mother_266.jpg : cropped image of not found, replacing with original imageastound_girl_739.jpg : cropped image of not found, replacing with original imageannoyed_chinese_217.jpg : cropped image of not found, replacing with original image
#
#
# crying_teacher_642.jpg : cropped image of not found, replacing with original image
# hostile_expression_515.jpg : cropped image of not found, replacing with original image
# crying_old_116.jpg : cropped image of not found, replacing with original imageastound_teacher_736.jpg : cropped image of not found, replacing with original imagehostile_president_541.jpg : cropped image of not found, replacing with original image
#
#
# heartbroken_american_753.jpg : cropped image of not found, replacing with original image
# heartbroken_american_471.jpg : cropped image of not found, replacing with original image
# amazed_yang_796.jpg : cropped image of not found, replacing with original image
# astound_actor_896.jpg : cropped image of not found, replacing with original imagefierce_teacher_372.jpg : cropped image of not found, replacing with original image
#
# afraid_programmer_208.jpg : cropped image of not found, replacing with original image
# distressed_expression_83.jpg : cropped image of not found, replacing with original image
# awe_student_404.jpg : cropped image of not found, replacing with original image
# heartbroken_actor_905.jpg : cropped image of not found, replacing with original image
# hostile_yang_175.jpg : cropped image of not found, replacing with original image
# crying_old_642.jpg : cropped image of not found, replacing with original imageawe_worker_818.jpg : cropped image of not found, replacing with original image
#
# afraid_woman_58.jpg : cropped image of not found, replacing with original image
# distaste_wife_49.jpg : cropped image of not found, replacing with original imageamazed_lady_274.jpg : cropped image of not found, replacing with original image
#
# hostile_son_506.jpg : cropped image of not found, replacing with original image
# awe_man_9.jpg : cropped image of not found, replacing with original image
# annoyed_president_24.jpg : cropped image of not found, replacing with original image
# fighting_black_88.jpg : cropped image of not found, replacing with original image
# astound_wife_620.jpg : cropped image of not found, replacing with original image
# awe_expression_380.jpg : cropped image of not found, replacing with original image
# angry_worker_623.jpg : cropped image of not found, replacing with original image
# angry_student_383.jpg : cropped image of not found, replacing with original image
# amazed_wife_684.jpg : cropped image of not found, replacing with original image
# amazed_wife_690.jpg : cropped image of not found, replacing with original image
# awe_asian_326.jpg : cropped image of not found, replacing with original image
# awe_asian_145.jpg : cropped image of not found, replacing with original image
# mad_girl_254.jpg : cropped image of not found, replacing with original image
# awe_manager_86.jpg : cropped image of not found, replacing with original image
# amazed_family_214.jpg : cropped image of not found, replacing with original imagefighting_infant_515.jpg : cropped image of not found, replacing with original image
#
# annoyed_black_208.jpg : cropped image of not found, replacing with original image
# awe_student_488.jpg : cropped image of not found, replacing with original image
# fighting_asian_230.jpg : cropped image of not found, replacing with original image
# heartbroken_grandmother_822.jpg : cropped image of not found, replacing with original image
# fierce_manager_419.jpg : cropped image of not found, replacing with original image
# amazed_lady_370.jpg : cropped image of not found, replacing with original imagedisgust_teacher_745.jpg : cropped image of not found, replacing with original image
#
# fighting_couple_88.jpg : cropped image of not found, replacing with original image
# crying_boss_62.jpg : cropped image of not found, replacing with original image
# amazed_actor_81.jpg : cropped image of not found, replacing with original imageawe_actor_141.jpg : cropped image of not found, replacing with original image
#
# crying_son_45.jpg : cropped image of not found, replacing with original image
# crying_old_511.jpg : cropped image of not found, replacing with original image
# distressed_manager_832.jpg : cropped image of not found, replacing with original image
# amazed_chinese_712.jpg : cropped image of not found, replacing with original image
# distressed_boy_364.jpg : cropped image of not found, replacing with original image
# disgust_programmer_881.jpg : cropped image of not found, replacing with original image
# heartbroken_yang_474.jpg : cropped image of not found, replacing with original image
# amazed_boss_385.jpg : cropped image of not found, replacing with original imageawe_actor_637.jpg : cropped image of not found, replacing with original image
# heartbroken_woman_753.jpg : cropped image of not found, replacing with original image
#
# amazed_worker_998.jpg : cropped image of not found, replacing with original image
# astound_manager_451.jpg : cropped image of not found, replacing with original imagemad_lady_278.jpg : cropped image of not found, replacing with original image
#
# heartbroken_lady_850.jpg : cropped image of not found, replacing with original image
# angry_boy_669.jpg : cropped image of not found, replacing with original image
# distressed_son_81.jpg : cropped image of not found, replacing with original image
# anxious_girl_86.jpg : cropped image of not found, replacing with original image
# awe_lady_112.jpg : cropped image of not found, replacing with original image
# heartbroken_infant_196.jpg : cropped image of not found, replacing with original image
# amazed_grandfather_511.jpg : cropped image of not found, replacing with original imageheartbroken_mother_781.jpg : cropped image of not found, replacing with original image
#
# fierce_american_700.jpg : cropped image of not found, replacing with original image
# annoyed_actor_703.jpg : cropped image of not found, replacing with original image
# astound_student_235.jpg : cropped image of not found, replacing with original image
# heartbroken_woman_575.jpg : cropped image of not found, replacing with original image
# surprised_expression_412.jpg : cropped image of not found, replacing with original imagefighting_people_243.jpg : cropped image of not found, replacing with original image
#
# mad_African_178.jpg : cropped image of not found, replacing with original image
# awe_actor_222.jpg : cropped image of not found, replacing with original image
# heartbroken_father_558.jpg : cropped image of not found, replacing with original image
# distressed_soldier_334.jpg : cropped image of not found, replacing with original imageawe_worker_280.jpg : cropped image of not found, replacing with original image
#
# anxious_yang_453.jpg : cropped image of not found, replacing with original image
# fierce_people_386.jpg : cropped image of not found, replacing with original imageawe_asian_440.jpg : cropped image of not found, replacing with original image
#
# angry_woman_123.jpg : cropped image of not found, replacing with original image
# crying_black_325.jpg : cropped image of not found, replacing with original image
# amazed_yang_99.jpg : cropped image of not found, replacing with original image
# mad_mother_759.jpg : cropped image of not found, replacing with original imageamazed_family_69.jpg : cropped image of not found, replacing with original image
#
# heartbroken_manager_85.jpg : cropped image of not found, replacing with original image
# awe_husband_631.jpg : cropped image of not found, replacing with original image
# surprised_expression_587.jpg : cropped image of not found, replacing with original imageawe_manager_15.jpg : cropped image of not found, replacing with original image
#
# boring_black_490.jpg : cropped image of not found, replacing with original image
# crying_black_98.jpg : cropped image of not found, replacing with original image
# fierce_european_360.jpg : cropped image of not found, replacing with original image
# boring_man_170.jpg : cropped image of not found, replacing with original image
# amazed_lady_398.jpg : cropped image of not found, replacing with original imageawe_yang_540.jpg : cropped image of not found, replacing with original image
#
# distressed_father_408.jpg : cropped image of not found, replacing with original imageamazed_chinese_907.jpg : cropped image of not found, replacing with original image
#
# crying_old_611.jpg : cropped image of not found, replacing with original image
# distressed_woman_218.jpg : cropped image of not found, replacing with original imagefrightened_by_the_movie_lad_756.jpg : cropped image of not found, replacing with original image
#
# astound_president_936.jpg : cropped image of not found, replacing with original image
# angry_actor_90.jpg : cropped image of not found, replacing with original image
# ...
# crying_old_439.jpg : cropped image of not found, replacing with original image
# heartbroken_lady_335.jpg : cropped image of not found, replacing with original image
# fighting_infant_214.jpg : cropped image of not found, replacing with original image
# amazed_chinese_103.jpg : cropped image of not found, replacing with original image
# angry_lady_189.jpg : cropped image of not found, replacing with original imageawe_asian_593.jpg : cropped image of not found, replacing with original image
#
# amazed_student_606.jpg : cropped image of not found, replacing with original imagefierce_mother_736.jpg : cropped image of not found, replacing with original image
#
# amazed_boss_624.jpg : cropped image of not found, replacing with original image
# astound_asian_775.jpg : cropped image of not found, replacing with original image
# awe_american_450.jpg : cropped image of not found, replacing with original image
# awe_soldier_206.jpg : cropped image of not found, replacing with original image
# hostile_teacher_697.jpg : cropped image of not found, replacing with original image
# fighting_woman_626.jpg : cropped image of not found, replacing with original imagedisgust_actor_713.jpg : cropped image of not found, replacing with original image
#
# crying_grandmother_175.jpg : cropped image of not found, replacing with original imageheartbroken_programmer_478.jpg : cropped image of not found, replacing with original image
#
# amazed_manager_654.jpg : cropped image of not found, replacing with original imagehostile_girl_712.jpg : cropped image of not found, replacing with original image
#
# awe_husband_453.jpg : cropped image of not found, replacing with original image
# awe_lady_441.jpg : cropped image of not found, replacing with original image
# awe_soldier_145.jpg : cropped image of not found, replacing with original image
# amazed_family_93.jpg : cropped image of not found, replacing with original image
# amazed_soldier_955.jpg : cropped image of not found, replacing with original image
# frightened_old_179.jpg : cropped image of not found, replacing with original imageannoyed_wife_280.jpg : cropped image of not found, replacing with original image
#
# astound_asian_441.jpg : cropped image of not found, replacing with original image
# amazed_european_44.jpg : cropped image of not found, replacing with original image
# frightened_by_the_movie_programmer_303.jpg : cropped image of not found, replacing with original image
# amazed_boy_82.jpg : cropped image of not found, replacing with original image
# heartbroken_son_439.jpg : cropped image of not found, replacing with original image
# heartbroken_grandfather_153.jpg : cropped image of not found, replacing with original image
# awe_lady_611.jpg : cropped image of not found, replacing with original image
# awe_american_735.jpg : cropped image of not found, replacing with original image
# awe_teacher_115.jpg : cropped image of not found, replacing with original image
# anxious_chinese_640.jpg : cropped image of not found, replacing with original image
# angry_student_9.jpg : cropped image of not found, replacing with original imageamazed_African_710.jpg : cropped image of not found, replacing with original image
#
# mad_wife_349.jpg : cropped image of not found, replacing with original image
# amazed_chinese_661.jpg : cropped image of not found, replacing with original imageamazed_student_393.jpg : cropped image of not found, replacing with original image
#
# frightened_manager_575.jpg : cropped image of not found, replacing with original image
# hostile_student_232.jpg : cropped image of not found, replacing with original image
# astound_grandmother_251.jpg : cropped image of not found, replacing with original image
# awe_people_11.jpg : cropped image of not found, replacing with original image
# awe_soldier_457.jpg : cropped image of not found, replacing with original image
# distressed_people_6.jpg : cropped image of not found, replacing with original imagedistaste_grandmother_665.jpg : cropped image of not found, replacing with original image
#
# heartbroken_mother_419.jpg : cropped image of not found, replacing with original image
# hostile_manager_104.jpg : cropped image of not found, replacing with original image
# frightened_by_the_movie_european_350.jpg : cropped image of not found, replacing with original image
# fierce_president_498.jpg : cropped image of not found, replacing with original image
# crying_mother_314.jpg : cropped image of not found, replacing with original imageheartbroken_programmer_199.jpg : cropped image of not found, replacing with original image
#
# astound_actor_144.jpg : cropped image of not found, replacing with original imagehostile_boss_173.jpg : cropped image of not found, replacing with original image
#
# astound_student_186.jpg : cropped image of not found, replacing with original image
# annoyed_european_55.jpg : cropped image of not found, replacing with original image
# crying_husband_611.jpg : cropped image of not found, replacing with original image
# crying_infant_588.jpg : cropped image of not found, replacing with original image
# astound_husband_304.jpg : cropped image of not found, replacing with original imageawe_actor_88.jpg : cropped image of not found, replacing with original image
#
# amazed_soldier_716.jpg : cropped image of not found, replacing with original image
# heartbroken_face_603.jpg : cropped image of not found, replacing with original image
# amazed_yang_49.jpg : cropped image of not found, replacing with original image
# mad_girl_31.jpg : cropped image of not found, replacing with original image
# amazed_son_959.jpg : cropped image of not found, replacing with original image
# amazed_actor_359.jpg : cropped image of not found, replacing with original image
# fierce_soldier_493.jpg : cropped image of not found, replacing with original imageannoyed_student_682.jpg : cropped image of not found, replacing with original image
#
# awe_father_869.jpg : cropped image of not found, replacing with original image
# unhappy_expression_374.jpg : cropped image of not found, replacing with original imageawe_asian_731.jpg : cropped image of not found, replacing with original image
#
# crying_boss_690.jpg : cropped image of not found, replacing with original image
# astound_woman_60.jpg : cropped image of not found, replacing with original image
# heartbroken_man_776.jpg : cropped image of not found, replacing with original imageamazed_old_205.jpg : cropped image of not found, replacing with original imageawe_face_9.jpg : cropped image of not found, replacing with original image
# awe_family_208.jpg : cropped image of not found, replacing with original image
#
#
# amazed_boy_750.jpg : cropped image of not found, replacing with original imageawe_president_495.jpg : cropped image of not found, replacing with original image
#
# crying_man_114.jpg : cropped image of not found, replacing with original imageheartbroken_european_318.jpg : cropped image of not found, replacing with original image
#
# astound_family_873.jpg : cropped image of not found, replacing with original image
# awe_father_27.jpg : cropped image of not found, replacing with original imagecrying_people_620.jpg : cropped image of not found, replacing with original imageangry_programmer_783.jpg : cropped image of not found, replacing with original image
#
#
# astound_teacher_607.jpg : cropped image of not found, replacing with original imageastound_teacher_766.jpg : cropped image of not found, replacing with original image
#
# amazed_teacher_919.jpg : cropped image of not found, replacing with original image
# fighting_manager_135.jpg : cropped image of not found, replacing with original image
# crying_boss_734.jpg : cropped image of not found, replacing with original image
# awe_wife_338.jpg : cropped image of not found, replacing with original imageexcited_asian_324.jpg : cropped image of not found, replacing with original image
#
# fighting_wife_123.jpg : cropped image of not found, replacing with original image
# awe_people_30.jpg : cropped image of not found, replacing with original image
# awe_family_483.jpg : cropped image of not found, replacing with original image
# amazed_president_494.jpg : cropped image of not found, replacing with original imageamazed_man_450.jpg : cropped image of not found, replacing with original image
#
# fierce_student_656.jpg : cropped image of not found, replacing with original image
# mad_president_17.jpg : cropped image of not found, replacing with original image
# angry_face_456.jpg : cropped image of not found, replacing with original image
# amazed_father_361.jpg : cropped image of not found, replacing with original image
# awe_lady_24.jpg : cropped image of not found, replacing with original imagefrightened_by_the_movie_girl_193.jpg : cropped image of not found, replacing with original image
#
# annoyed_people_309.jpg : cropped image of not found, replacing with original image
# anxious_grandfather_889.jpg : cropped image of not found, replacing with original imageangry_wife_154.jpg : cropped image of not found, replacing with original image
# angry_grandfather_628.jpg : cropped image of not found, replacing with original image
#
# distressed_couple_369.jpg : cropped image of not found, replacing with original image
# awe_european_650.jpg : cropped image of not found, replacing with original image
# crying_face_97.jpg : cropped image of not found, replacing with original imageawe_woman_286.jpg : cropped image of not found, replacing with original image
#
# astound_european_113.jpg : cropped image of not found, replacing with original image
# heartbroken_actor_670.jpg : cropped image of not found, replacing with original image
# amazed_girl_204.jpg : cropped image of not found, replacing with original image
# amazed_teacher_812.jpg : cropped image of not found, replacing with original image
# amazed_lady_438.jpg : cropped image of not found, replacing with original image
# annoyed_girl_407.jpg : cropped image of not found, replacing with original image
# awe_worker_560.jpg : cropped image of not found, replacing with original image
# amazed_president_198.jpg : cropped image of not found, replacing with original image
# mad_actor_234.jpg : cropped image of not found, replacing with original image
# astound_student_499.jpg : cropped image of not found, replacing with original image
# awe_president_55.jpg : cropped image of not found, replacing with original imagedistressed_father_254.jpg : cropped image of not found, replacing with original image
#
# annoyed_lady_144.jpg : cropped image of not found, replacing with original image
# annoyed_African_928.jpg : cropped image of not found, replacing with original image
# mad_manager_203.jpg : cropped image of not found, replacing with original image
# crying_wife_771.jpg : cropped image of not found, replacing with original image
# awe_boss_498.jpg : cropped image of not found, replacing with original image
# distressed_wife_574.jpg : cropped image of not found, replacing with original image
# fierce_programmer_764.jpg : cropped image of not found, replacing with original image
# angry_teacher_274.jpg : cropped image of not found, replacing with original image
# heartbroken_husband_464.jpg : cropped image of not found, replacing with original image
# astound_worker_624.jpg : cropped image of not found, replacing with original image
# annoyed_African_151.jpg : cropped image of not found, replacing with original imagecrying_face_86.jpg : cropped image of not found, replacing with original imageamazed_teacher_302.jpg : cropped image of not found, replacing with original image
#
#
# annoyed_president_457.jpg : cropped image of not found, replacing with original image
# awe_manager_7.jpg : cropped image of not found, replacing with original imageawe_father_710.jpg : cropped image of not found, replacing with original image
#
# amazed_girl_331.jpg : cropped image of not found, replacing with original imageawe_teacher_578.jpg : cropped image of not found, replacing with original imageannoyed_woman_146.jpg : cropped image of not found, replacing with original image
#
#
# fierce_old_339.jpg : cropped image of not found, replacing with original image
# awe_soldier_143.jpg : cropped image of not found, replacing with original image
# amazed_manager_80.jpg : cropped image of not found, replacing with original image
# awe_father_263.jpg : cropped image of not found, replacing with original image
# amazed_student_627.jpg : cropped image of not found, replacing with original image
# frightened_by_the_movie_expression_479.jpg : cropped image of not found, replacing with original image
# awe_wife_627.jpg : cropped image of not found, replacing with original image
# amazed_president_719.jpg : cropped image of not found, replacing with original image
# awe_grandfather_174.jpg : cropped image of not found, replacing with original image
# crying_woman_360.jpg : cropped image of not found, replacing with original image
# astound_expression_100.jpg : cropped image of not found, replacing with original image
# expressionless_couple_223.jpg : cropped image of not found, replacing with original image
# awe_son_475.jpg : cropped image of not found, replacing with original image
# amazed_expression_148.jpg : cropped image of not found, replacing with original image
# heartbroken_worker_55.jpg : cropped image of not found, replacing with original imagecrying_wife_663.jpg : cropped image of not found, replacing with original image
# awe_woman_499.jpg : cropped image of not found, replacing with original image
#
# astound_black_725.jpg : cropped image of not found, replacing with original image
# awe_woman_262.jpg : cropped image of not found, replacing with original image
# astound_grandfather_42.jpg : cropped image of not found, replacing with original imageamazed_African_80.jpg : cropped image of not found, replacing with original image
#
# amazed_actor_728.jpg : cropped image of not found, replacing with original image
# distressed_soldier_654.jpg : cropped image of not found, replacing with original image
# annoyed_mother_2.jpg : cropped image of not found, replacing with original imageheartbroken_man_356.jpg : cropped image of not found, replacing with original image
# distressed_people_17.jpg : cropped image of not found, replacing with original image
#
# amazed_soldier_875.jpg : cropped image of not found, replacing with original imageangry_old_2.jpg : cropped image of not found, replacing with original image
#
# amazed_asian_186.jpg : cropped image of not found, replacing with original image
# fierce_wife_98.jpg : cropped image of not found, replacing with original image
# expressionless_actor_516.jpg : cropped image of not found, replacing with original image
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-1fced7b4b02c> in <cell line: 3>()
#       1 print(f'------------training started for EWC DANN Model ------------------')
#       2
# ----> 3 ewc_dann_model , dict_ewc_dann_losses = execute_dann_ewc(model= model_dann_ewc,
#       4                                                           device=device,
#       5                                                           source_train_loader = data_loader['source']['train'], #sfew_train_loader,
#
# <ipython-input-24-17f00ff05beb> in execute_dann_ewc(model, device, source_train_loader, source_val_loader, target_train_loader, target_val_loader, optimizer, n_epochs, class_loss_function, domain_loss_function, EWC_LAMBDA, scheduler, early_stop_patience, early_stop_difference)
#     188     accuracy_source = correct_source / len(source_val_loader.dataset)
#     189
# --> 190     correct_target, test_loss_target = test_model_local(model= model,
#     191                             device= device,
#     192                             data_loader = target_val_loader, # target val loader
#
# <ipython-input-17-3d0de0556456> in test_model_local(model, device, data_loader, mode, class_loss_function)
#      25             class_loss = class_loss_function(class_output,labels) # Calculate Loss
#      26
# ---> 27             test_loss += class_loss.item() # sum up batch loss
#      28
#      29             # Sum up batch correct predictions
#
# KeyboardInterrupt:

# %% [markdown]
# ### EWC DANN Saving

# %%
# ewc_dann_model_name = 'ewc_dann_sfew_expw_30_01.pt'
ewc_dann_model_name = f'ewc_dann_{source_name}_{target_name}_{str(time.strftime("%d_%m"))}.pt' #"ewc_dann_sfew_expw_" + str(time.strftime("%d_%m")) + ".pt"
print(ewc_dann_model_name)

from da_cv_fer.data_config import DataConfig
dataconfig_2 = DataConfig()
MODEL_DIR = dataconfig_2.MODEL_DIR


EWC_DANN_MODEL_DIR =  Path(os.path.join(MODEL_DIR, f'ewc_dann_{source_name}_{target_name}'))



if not EWC_DANN_MODEL_DIR.exists():
    # Create the directory
    EWC_DANN_MODEL_DIR.mkdir(parents=True, exist_ok=True)
    print(f'Directory {EWC_DANN_MODEL_DIR} created successfully.')
else:
    print(f'Directory {EWC_DANN_MODEL_DIR} already exists.')

try:
    torch.save(ewc_dann_model.state_dict(), Path(EWC_DANN_MODEL_DIR,ewc_dann_model_name))
    print(f'{ewc_dann_model_name} SAVED at {Path(EWC_DANN_MODEL_DIR,ewc_dann_model_name)}!')
except:
    print(f'Problem in saving {ewc_dann_model_name}, NOT SAVED!')
